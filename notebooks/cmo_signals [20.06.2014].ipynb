# %% [markdown]
# # CMO Signals

# %%
from concat_overlord.universes.standard import new_universe
from concat_overlord.standard import make_output
from fsprices.universe import Universe

# %% [markdown]
# ### Load CH-universe and data

# %%
funi = new_universe()

# %%
output = make_output(Universe([s for s in funi if s.country == 'CH']))

# %% [markdown]
# ### Import SignalReport

# %%
from blvresearch.concat.signals.signal_testing import SignalReport

# %% [markdown]
# ### Import get_signals function

# %%
from blvresearch.concat.signals.cmo_signals import get_signals

# %% [markdown]
# # Periods = 9

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, periods=9)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())
# Out:
# Strategy generated profit for 129 companies (0.6683937823834197)
# Strategy generated loss for 64 companies (0.3316062176165803)
# Strategy outperformed SP500 for 44 companies (0.22797927461139897)
# Average number of signals per entity: 9.5803
# Average return of winners was 0.3088
# Average return of losers was -0.2864
# Over the next 20 trading days after signals:
# * 0.6554 of signals were correct among winners
# * 0.471 of signals were incorrect among losers

# %% [markdown]
# # Periods = 20

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, periods=20)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())
# Out:
# Strategy generated profit for 68 companies (0.5074626865671642)
# Strategy generated loss for 66 companies (0.4925373134328358)
# Strategy outperformed SP500 for 18 companies (0.13432835820895522)
# Average number of signals per entity: 2.1194
# Average return of winners was 0.2606
# Average return of losers was -0.2275
# Over the next 20 trading days after signals:
# * 0.6624 of signals were correct among winners
# * 0.5039 of signals were incorrect among losers
