# %% [markdown]
# # Moving Average

# %%
from concat_overlord.universes.standard import new_universe
from concat_overlord.standard import make_output
from fsprices.universe import Universe

# %% [markdown]
# ### Load CH-universe and data

# %%
funi = new_universe()

# %%
output = make_output(Universe([s for s in funi if s.country == 'CH']))

# %% [markdown]
# ### Import SignalReport

# %%
from blvresearch.concat.signals.signal_testing import SignalReport

# %% [markdown]
# ### Import get_signals function

# %%
from blvresearch.concat.signals.moving_average import get_signals

# %% [markdown]
# # WIN = 50, CONF_WIN = 5

# %%
window = 50
confirmation_window = 5

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, window, confirmation_window)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 19.06.2014  EMA calculated based on cumulative alpha
# Out:
# Strategy generated profit for 122 companies (0.6321243523316062)
# Strategy generated loss for 71 companies (0.36787564766839376)
# Strategy outperformed SP500 for 37 companies (0.19170984455958548)
# Average number of signals per entity: 9.5285
# Average return of winners was 0.3062
# Average return of losers was -0.1713
# Over the next 20 trading days after signals:
# * 0.553 of signals were correct among winners
# * 0.6114 of signals were incorrect among losers

# %% [markdown]
# # WIN = 50, CONF_WIN = 10

# %%
window = 50
confirmation_window = 10

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, window, confirmation_window)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 19.06.2014  EMA calculated based on cumulative alpha
# Out:
# Strategy generated profit for 122 companies (0.6321243523316062)
# Strategy generated loss for 71 companies (0.36787564766839376)
# Strategy outperformed SP500 for 31 companies (0.16062176165803108)
# Average number of signals per entity: 5.8912
# Average return of winners was 0.2897
# Average return of losers was -0.1879
# Over the next 20 trading days after signals:
# * 0.5385 of signals were correct among winners
# * 0.5789 of signals were incorrect among losers

# %% [markdown]
# # WIN = 30, CONF_WIN = 5

# %%
window = 30
confirmation_window = 5

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, window, confirmation_window)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 19.06.2014  EMA calculated based on cumulative alpha
# Out:
# Strategy generated profit for 119 companies (0.616580310880829)
# Strategy generated loss for 74 companies (0.38341968911917096)
# Strategy outperformed SP500 for 33 companies (0.17098445595854922)
# Average number of signals per entity: 11.5285
# Average return of winners was 0.2958
# Average return of losers was -0.1719
# Over the next 20 trading days after signals:
# * 0.525 of signals were correct among winners
# * 0.5855 of signals were incorrect among losers

# %% [markdown]
# # WIN = 20, CONF_WIN = 3

# %%
window = 20
confirmation_window = 3

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, window, confirmation_window)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 19.06.2014  EMA calculated based on cumulative alpha
# Out:
# Strategy generated profit for 118 companies (0.6082474226804123)
# Strategy generated loss for 76 companies (0.3917525773195876)
# Strategy outperformed SP500 for 44 companies (0.2268041237113402)
# Average number of signals per entity: 19.0309
# Average return of winners was 0.3695
# Average return of losers was -0.2075
# Over the next 20 trading days after signals:
# * 0.4697 of signals were correct among winners
# * 0.659 of signals were incorrect among losers

# %% [markdown]
# # WIN = 10, CONF_WIN = 3

# %%
window = 10
confirmation_window = 3

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, window, confirmation_window)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 19.06.2014  EMA calculated based on cumulative alpha
# Out:
# Strategy generated profit for 120 companies (0.6185567010309279)
# Strategy generated loss for 74 companies (0.38144329896907214)
# Strategy outperformed SP500 for 45 companies (0.23195876288659795)
# Average number of signals per entity: 23.7938
# Average return of winners was 0.3945
# Average return of losers was -0.1932
# Over the next 20 trading days after signals:
# * 0.4736 of signals were correct among winners
# * 0.6524 of signals were incorrect among losers

# %% [markdown]
# # WIN = 100, CONF_WIN = 20

# %%
window = 100
confirmation_window = 20

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, window, confirmation_window)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 19.06.2014  EMA calculated based on cumulative alpha
# Out:
# Strategy generated profit for 110 companies (0.6077348066298343)
# Strategy generated loss for 71 companies (0.39226519337016574)
# Strategy outperformed SP500 for 23 companies (0.1270718232044199)
# Average number of signals per entity: 3.3867
# Average return of winners was 0.2998
# Average return of losers was -0.2039
# Over the next 20 trading days after signals:
# * 0.5599 of signals were correct among winners
# * 0.5362 of signals were incorrect among losers

# %% [markdown]
# # WIN = 200, CONF_WIN = 50

# %%
window = 200
confirmation_window = 50

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, window, confirmation_window)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 19.06.2014  EMA calculated based on cumulative alpha
# Out:
# Strategy generated profit for 95 companies (0.59375)
# Strategy generated loss for 65 companies (0.40625)
# Strategy outperformed SP500 for 17 companies (0.10625)
# Average number of signals per entity: 1.775
# Average return of winners was 0.264
# Average return of losers was -0.2272
# Over the next 20 trading days after signals:
# * 0.6528 of signals were correct among winners
# * 0.5429 of signals were incorrect among losers
