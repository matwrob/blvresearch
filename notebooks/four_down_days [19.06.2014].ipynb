# %% [markdown]
# # 4 Down Days

# %%
from concat_overlord.universes.standard import new_universe
from concat_overlord.standard import make_output
from fsprices.universe import Universe

# %% [markdown]
# ### Load CH-universe and data

# %%
funi = new_universe()

# %%
output = make_output(Universe([s for s in funi if s.country == 'CH']))

# %% [markdown]
# ### Import SignalReport

# %%
from blvresearch.concat.signals.signal_testing import SignalReport

# %% [markdown]
# ### Import get_signals function

# %%
from blvresearch.concat.signals.four_down_days import get_signals

# %% [markdown]
# # DOWN_DAYS = 4, UP_DAYS = 2

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, down_days=4, up_days=2)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())
# Out:
# Strategy generated profit for 107 companies (0.5544041450777202)
# Strategy generated loss for 86 companies (0.44559585492227977)
# Strategy outperformed SP500 for 27 companies (0.13989637305699482)
# Average number of signals per entity: 23.1088
# Average return of winners was 0.3135
# Average return of losers was -0.2953
# Over the next 20 trading days after signals:
# * 0.6602 of signals were correct among winners
# * 0.4438 of signals were incorrect among losers

# %% [markdown]
# # DOWN_DAYS = 6, UP_DAYS = 3

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, down_days=6, up_days=3)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())
# Out:
# Strategy generated profit for 76 companies (0.4444444444444444)
# Strategy generated loss for 95 companies (0.5555555555555556)
# Strategy outperformed SP500 for 11 companies (0.06432748538011696)
# Average number of signals per entity: 6.3743
# Average return of winners was 0.2991
# Average return of losers was -0.3173
# Over the next 20 trading days after signals:
# * 0.5824 of signals were correct among winners
# * 0.473 of signals were incorrect among losers

# %% [markdown]
# # DOWN_DAYS = 2, UP_DAYS = 1

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, down_days=2, up_days=1)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())
# Out:
# Strategy generated profit for 142 companies (0.7319587628865979)
# Strategy generated loss for 52 companies (0.26804123711340205)
# Strategy outperformed SP500 for 80 companies (0.41237113402061853)
# Average number of signals per entity: 119.6546
# Average return of winners was 0.5823
# Average return of losers was -0.2884
# Over the next 20 trading days after signals:
# * 0.6955 of signals were correct among winners
# * 0.3701 of signals were incorrect among losers
