# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Comparison of results for PRICE-based signals

# %%
from concat_overlord.universes.standard import new_universe
from concat_overlord.dbpools import CONCAT_STANDARD_USER
from concat_overlord.update_client import make_output
from blvprices.universe import Universe

# %% [markdown]
# ### Load CH-universe and data

# %%
funi = Universe('CONCAT_STANDARD')

# %%
output = make_output(Universe([s for s in funi if s.country == 'CH']))

# %% [markdown]
# ### Import SignalReport

# %%
from blvresearch.concat.signals.signal_testing import SignalReport

# %% [markdown]
# # Moving Average

# %%
from blvresearch.concat.signals.price_based.moving_average import get_movavg_signals

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_movavg_signals(v, window=20, confirmation_window=5)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 04.08.2014  without using remove_consecutive_values function
# Out:
# Strategy generated profit for 102 companies (0.576271186440678)
# Strategy generated loss for 75 companies (0.423728813559322)
# Strategy outperformed benchmark for 35 companies (0.1977401129943503)
# Average number of signals per entity: 27.0169
# Average return of winners was 0.3421
# Average return of losers was -0.2684
# Over the next 20 trading days after signals:
# * 0.5179 of signals were correct among winners
# * 0.5908 of signals were incorrect among losers

# %%
print(sr.get())  # 04.08.2014
# Out:
# Strategy generated profit for 102 companies (0.576271186440678)
# Strategy generated loss for 75 companies (0.423728813559322)
# Strategy outperformed benchmark for 35 companies (0.1977401129943503)
# Average number of signals per entity: 16.3729
# Average return of winners was 0.3421
# Average return of losers was -0.2684
# Over the next 20 trading days after signals:
# * 0.4897 of signals were correct among winners
# * 0.6333 of signals were incorrect among losers

# %%
print(sr.get())  # 30.07.2014
# Out:
# Strategy generated profit for 103 companies (0.5819209039548022)
# Strategy generated loss for 74 companies (0.4180790960451977)
# Strategy outperformed benchmark for 30 companies (0.1694915254237288)
# Average number of signals per entity: 16.5254
# Average return of winners was 0.341
# Average return of losers was -0.2813
# Over the next 20 trading days after signals:
# * 0.4912 of signals were correct among winners
# * 0.6351 of signals were incorrect among losers

# %%
print(sr.get())  # 24.07.2014
# Out:
# Strategy generated profit for 104 companies (0.5875706214689266)
# Strategy generated loss for 73 companies (0.4124293785310734)
# Strategy outperformed benchmark for 28 companies (0.15819209039548024)
# Average number of signals per entity: 16.4746
# Average return of winners was 0.3389
# Average return of losers was -0.2772
# Over the next 20 trading days after signals:
# * 0.4887 of signals were correct among winners
# * 0.6253 of signals were incorrect among losers

# %%
print(sr.get())  # 23.07.2014
# Out:
# Strategy generated profit for 108 companies (0.6101694915254238)
# Strategy generated loss for 69 companies (0.3898305084745763)
# Strategy outperformed benchmark for 29 companies (0.1638418079096045)
# Average number of signals per entity: 16.4407
# Average return of winners was 0.3299
# Average return of losers was -0.2991
# Over the next 20 trading days after signals:
# * 0.4867 of signals were correct among winners
# * 0.6289 of signals were incorrect among losers

# %% [markdown]
# # Dual Moving Average Crossover

# %%
from blvresearch.concat.signals.price_based.dmac import get_dmac_signals

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_dmac_signals(v, long_window=20, short_window=10, confirmation_window=5)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 04.08.2014  without using remove_consecutive_values function
# Out:
# Strategy generated profit for 109 companies (0.615819209039548)
# Strategy generated loss for 68 companies (0.384180790960452)
# Strategy outperformed benchmark for 49 companies (0.2768361581920904)
# Average number of signals per entity: 18.0056
# Average return of winners was 0.3423
# Average return of losers was -0.1932
# Over the next 20 trading days after signals:
# * 0.528 of signals were correct among winners
# * 0.589 of signals were incorrect among losers

# %%
print(sr.get())  # 04.08.2014
# Out:
# Strategy generated profit for 109 companies (0.615819209039548)
# Strategy generated loss for 68 companies (0.384180790960452)
# Strategy outperformed benchmark for 49 companies (0.2768361581920904)
# Average number of signals per entity: 15.4068
# Average return of winners was 0.3423
# Average return of losers was -0.1932
# Over the next 20 trading days after signals:
# * 0.5233 of signals were correct among winners
# * 0.6048 of signals were incorrect among losers

# %%
print(sr.get())  # 30.07.2014
# Out:
# Strategy generated profit for 106 companies (0.5988700564971752)
# Strategy generated loss for 71 companies (0.4011299435028249)
# Strategy outperformed benchmark for 44 companies (0.24858757062146894)
# Average number of signals per entity: 15.4407
# Average return of winners was 0.3576
# Average return of losers was -0.2001
# Over the next 20 trading days after signals:
# * 0.535 of signals were correct among winners
# * 0.6047 of signals were incorrect among losers

# %%
print(sr.get())  # 24.07.2014
# Out:
# Strategy generated profit for 102 companies (0.576271186440678)
# Strategy generated loss for 75 companies (0.423728813559322)
# Strategy outperformed benchmark for 35 companies (0.1977401129943503)
# Average number of signals per entity: 15.3785
# Average return of winners was 0.3768
# Average return of losers was -0.1988
# Over the next 20 trading days after signals:
# * 0.5285 of signals were correct among winners
# * 0.6055 of signals were incorrect among losers

# %%
print(sr.get())  # 23.07.2014
# Out:
# Strategy generated profit for 104 companies (0.5875706214689266)
# Strategy generated loss for 73 companies (0.4124293785310734)
# Strategy outperformed benchmark for 38 companies (0.21468926553672316)
# Average number of signals per entity: 15.3672
# Average return of winners was 0.3655
# Average return of losers was -0.2048
# Over the next 20 trading days after signals:
# * 0.529 of signals were correct among winners
# * 0.6115 of signals were incorrect among losers

# %% [markdown]
# # 4 Down Days

# %%
from blvresearch.concat.signals.price_based.four_down_days import get_4down_signals

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_4down_signals(v, down_days=4, up_days=2)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 04.08.2014  without using remove_consecutive_values function
# Out:
# Strategy generated profit for 77 companies (0.4350282485875706)
# Strategy generated loss for 100 companies (0.5649717514124294)
# Strategy outperformed benchmark for 34 companies (0.192090395480226)
# Average number of signals per entity: 72.6667
# Average return of winners was 0.332
# Average return of losers was -0.2647
# Over the next 20 trading days after signals:
# * 0.5455 of signals were correct among winners
# * 0.5341 of signals were incorrect among losers

# %%
print(sr.get())  # 04.08.2014
# Out:
# Strategy generated profit for 77 companies (0.4350282485875706)
# Strategy generated loss for 100 companies (0.5649717514124294)
# Strategy outperformed benchmark for 34 companies (0.192090395480226)
# Average number of signals per entity: 23.887
# Average return of winners was 0.332
# Average return of losers was -0.2647
# Over the next 20 trading days after signals:
# * 0.6481 of signals were correct among winners
# * 0.4403 of signals were incorrect among losers

# %%
print(sr.get())  # 30.07.2014
# Out:
# Strategy generated profit for 78 companies (0.4406779661016949)
# Strategy generated loss for 99 companies (0.559322033898305)
# Strategy outperformed benchmark for 34 companies (0.192090395480226)
# Average number of signals per entity: 23.9548
# Average return of winners was 0.3335
# Average return of losers was -0.2676
# Over the next 20 trading days after signals:
# * 0.6455 of signals were correct among winners
# * 0.4379 of signals were incorrect among losers

# %%
print(sr.get())  # 24.07.2014
# Out:
# Strategy generated profit for 79 companies (0.4463276836158192)
# Strategy generated loss for 98 companies (0.5536723163841808)
# Strategy outperformed benchmark for 27 companies (0.15254237288135594)
# Average number of signals per entity: 23.9605
# Average return of winners was 0.3362
# Average return of losers was -0.2677
# Over the next 20 trading days after signals:
# * 0.6474 of signals were correct among winners
# * 0.4337 of signals were incorrect among losers

# %%
print(sr.get())  # 23.07.2014
# Out:
# Strategy generated profit for 80 companies (0.4519774011299435)
# Strategy generated loss for 97 companies (0.5480225988700564)
# Strategy outperformed benchmark for 29 companies (0.1638418079096045)
# Average number of signals per entity: 24.0226
# Average return of winners was 0.3342
# Average return of losers was -0.2675
# Over the next 20 trading days after signals:
# * 0.6491 of signals were correct among winners
# * 0.4376 of signals were incorrect among losers

# %% [markdown]
# # RSI Agita

# %%
from blvresearch.concat.signals.price_based.rsi_agita import get_rsi_signals

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_rsi_signals(v, periods=14, buy_thrsh=35, sell_thrsh=55)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 04.08.2014  without using remove_consecutive_values function
# Out:
# Strategy generated profit for 106 companies (0.5988700564971752)
# Strategy generated loss for 71 companies (0.4011299435028249)
# Strategy outperformed benchmark for 51 companies (0.288135593220339)
# Average number of signals per entity: 263.8418
# Average return of winners was 0.3447
# Average return of losers was -0.3536
# Over the next 20 trading days after signals:
# * 0.4486 of signals were correct among winners
# * 0.5772 of signals were incorrect among losers

# %%
print(sr.get())  # 04.08.2014
# Out:
# Strategy generated profit for 106 companies (0.5988700564971752)
# Strategy generated loss for 71 companies (0.4011299435028249)
# Strategy outperformed benchmark for 51 companies (0.288135593220339)
# Average number of signals per entity: 24.3729
# Average return of winners was 0.3447
# Average return of losers was -0.3536
# Over the next 20 trading days after signals:
# * 0.7001 of signals were correct among winners
# * 0.4098 of signals were incorrect among losers

# %%
print(sr.get())  # 30.07.2014
# Out:
# Strategy generated profit for 110 companies (0.6214689265536724)
# Strategy generated loss for 67 companies (0.3785310734463277)
# Strategy outperformed benchmark for 49 companies (0.2768361581920904)
# Average number of signals per entity: 24.3729
# Average return of winners was 0.3429
# Average return of losers was -0.3671
# Over the next 20 trading days after signals:
# * 0.6983 of signals were correct among winners
# * 0.4161 of signals were incorrect among losers

# %%
print(sr.get())  # 24.07.2014
# Out:
# Strategy generated profit for 108 companies (0.6101694915254238)
# Strategy generated loss for 69 companies (0.3898305084745763)
# Strategy outperformed benchmark for 43 companies (0.24293785310734464)
# Average number of signals per entity: 24.4407
# Average return of winners was 0.3447
# Average return of losers was -0.3506
# Over the next 20 trading days after signals:
# * 0.7043 of signals were correct among winners
# * 0.4163 of signals were incorrect among losers

# %%
print(sr.get())  # 23.07.2014
# Out:
# Strategy generated profit for 110 companies (0.6214689265536724)
# Strategy generated loss for 67 companies (0.3785310734463277)
# Strategy outperformed benchmark for 43 companies (0.24293785310734464)
# Average number of signals per entity: 24.5706
# Average return of winners was 0.3511
# Average return of losers was -0.3556
# Over the next 20 trading days after signals:
# * 0.7085 of signals were correct among winners
# * 0.411 of signals were incorrect among losers

# %% [markdown]
# # CMO Signals

# %%
from blvresearch.concat.signals.price_based.cmo_signals import get_cmo_signals

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_cmo_signals(v, periods=9)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 04.08.2014  without using remove_consecutive_values function
# Out:
# Strategy generated profit for 131 companies (0.7401129943502824)
# Strategy generated loss for 46 companies (0.2598870056497175)
# Strategy outperformed benchmark for 65 companies (0.3672316384180791)
# Average number of signals per entity: 23.8475
# Average return of winners was 0.3134
# Average return of losers was -0.3586
# Over the next 20 trading days after signals:
# * 0.5775 of signals were correct among winners
# * 0.5558 of signals were incorrect among losers

# %%
print(sr.get())  # 04.08.2014
# Out:
# Strategy generated profit for 131 companies (0.7401129943502824)
# Strategy generated loss for 46 companies (0.2598870056497175)
# Strategy outperformed benchmark for 65 companies (0.3672316384180791)
# Average number of signals per entity: 10.226
# Average return of winners was 0.3134
# Average return of losers was -0.3586
# Over the next 20 trading days after signals:
# * 0.6451 of signals were correct among winners
# * 0.4735 of signals were incorrect among losers

# %%
print(sr.get())  # 30.07.2014
# Out:
# Strategy generated profit for 130 companies (0.7344632768361582)
# Strategy generated loss for 47 companies (0.2655367231638418)
# Strategy outperformed benchmark for 60 companies (0.3389830508474576)
# Average number of signals per entity: 10.2316
# Average return of winners was 0.3139
# Average return of losers was -0.3421
# Over the next 20 trading days after signals:
# * 0.6509 of signals were correct among winners
# * 0.4761 of signals were incorrect among losers

# %%
print(sr.get())  # 24.07.2014
# Out:
# Strategy generated profit for 131 companies (0.7401129943502824)
# Strategy generated loss for 46 companies (0.2598870056497175)
# Strategy outperformed benchmark for 47 companies (0.2655367231638418)
# Average number of signals per entity: 10.2599
# Average return of winners was 0.3097
# Average return of losers was -0.3536
# Over the next 20 trading days after signals:
# * 0.6501 of signals were correct among winners
# * 0.4714 of signals were incorrect among losers

# %%
print(sr.get())  # 23.07.2014
# Out:
# Strategy generated profit for 132 companies (0.7457627118644068)
# Strategy generated loss for 45 companies (0.2542372881355932)
# Strategy outperformed benchmark for 49 companies (0.2768361581920904)
# Average number of signals per entity: 10.2542
# Average return of winners was 0.3075
# Average return of losers was -0.3617
# Over the next 20 trading days after signals:
# * 0.6498 of signals were correct among winners
# * 0.4759 of signals were incorrect among losers
