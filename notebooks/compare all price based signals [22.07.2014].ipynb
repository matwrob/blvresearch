# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Comparison of results for PRICE-based signals

# %%
from concat_overlord.universes.standard import new_universe
from concat_overlord.dbpools import CONCAT_STANDARD_USER
from concat_overlord.update_client import make_output
from blvprices.universe import Universe

# %% [markdown]
# ### Load CH-universe and data

# %%
funi = Universe('CONCAT_STANDARD')

# %%
output = make_output(Universe([s for s in funi if s.country == 'CH']))

# %% [markdown]
# ### Import SignalReport

# %%
from blvresearch.concat.signals.signal_testing import SignalReport

# %% [markdown]
# # Moving Average

# %%
from blvresearch.concat.signals.price_based.moving_average import get_movavg_signals

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_movavg_signals(v, window=20, confirmation_window=3)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 22.07.2014
# Out:
# Strategy generated profit for 119 companies (0.672316384180791)
# Strategy generated loss for 58 companies (0.327683615819209)
# Strategy outperformed benchmark for 42 companies (0.23728813559322035)
# Average number of signals per entity: 20.4294
# Average return of winners was 0.3836
# Average return of losers was -0.2034
# Over the next 20 trading days after signals:
# * 0.4907 of signals were correct among winners
# * 0.6331 of signals were incorrect among losers

# %% [markdown]
# # Dual Moving Average Crossover

# %%
from blvresearch.concat.signals.price_based.dmac import get_dmac_signals

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_dmac_signals(v, long_window=10, short_window=5, confirmation_window=2)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 22.07.2014
# Out:
# Strategy generated profit for 105 companies (0.5932203389830508)
# Strategy generated loss for 72 companies (0.4067796610169492)
# Strategy outperformed benchmark for 42 companies (0.23728813559322035)
# Average number of signals per entity: 29.4972
# Average return of winners was 0.4071
# Average return of losers was -0.2393
# Over the next 20 trading days after signals:
# * 0.4579 of signals were correct among winners
# * 0.6474 of signals were incorrect among losers

# %% [markdown]
# # 4 Down Days

# %%
from blvresearch.concat.signals.price_based.four_down_days import get_4down_signals

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_4down_signals(v, down_days=4, up_days=2)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 22.07.2014
# Out:
# Strategy generated profit for 80 companies (0.4519774011299435)
# Strategy generated loss for 97 companies (0.5480225988700564)
# Strategy outperformed benchmark for 27 companies (0.15254237288135594)
# Average number of signals per entity: 23.9435
# Average return of winners was 0.3273
# Average return of losers was -0.2715
# Over the next 20 trading days after signals:
# * 0.6472 of signals were correct among winners
# * 0.4384 of signals were incorrect among losers

# %% [markdown]
# # RSI Agita

# %%
from blvresearch.concat.signals.price_based.rsi_agita import get_rsi_signals

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_rsi_signals(v, periods=14, buy_thrsh=30, sell_thrsh=50)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 22.07.2014
# Out:
# Strategy generated profit for 98 companies (0.5536723163841808)
# Strategy generated loss for 79 companies (0.4463276836158192)
# Strategy outperformed benchmark for 31 companies (0.1751412429378531)
# Average number of signals per entity: 19.2768
# Average return of winners was 0.306
# Average return of losers was -0.3264
# Over the next 20 trading days after signals:
# * 0.6811 of signals were correct among winners
# * 0.4159 of signals were incorrect among losers

# %% [markdown]
# # CMO Signals

# %%
from blvresearch.concat.signals.price_based.cmo_signals import get_cmo_signals

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_cmo_signals(v, periods=9)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())  # 22.07.2014
# Out:
# Strategy generated profit for 131 companies (0.7401129943502824)
# Strategy generated loss for 46 companies (0.2598870056497175)
# Strategy outperformed benchmark for 49 companies (0.2768361581920904)
# Average number of signals per entity: 10.209
# Average return of winners was 0.3078
# Average return of losers was -0.3504
# Over the next 20 trading days after signals:
# * 0.6535 of signals were correct among winners
# * 0.4737 of signals were incorrect among losers
