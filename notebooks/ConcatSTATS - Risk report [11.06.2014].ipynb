# %%
from dateutil.relativedelta import relativedelta
import datetime as dt

from concat_overlord.universes.standard import new_universe
from fsprices.universe import get_research_universe, Universe, Security
from fsprices.topcountry_model import get_many

# %%
TODAY = dt.datetime.today()
START =  TODAY - relativedelta(years=1)

# %%
funi = new_universe()

# %%
runi = get_research_universe(TODAY.year)
# Out:
# 0036X2-E B00N7M-S-CH -- ABB Ltd.
# 05RXVY-E B2BZ5H-S-PL -- TVN SA
# 05HZH5-E B3L0R6-S-CH -- Forbo Holding AG
# 05HZFP-E B6W3G0-S-CH -- Sika AG
# 05LXZV-E B809L1-S-CH -- Infranor Inter AG
# 05HXCN-E B9366V-S-CH -- Sonova Holding AG
# 05JK9B-E BJ1RB4-S-CH -- Nobel Biocare Holding AG
# 06Z1MZ-E BNFPQV-S-CH -- u-blox Holding AG
# 05ZTWT-E BNHJ2F-S-CH -- ams AG
# 05HXJX-E BNLZPP-S-CH -- Helvetia Holding AG
# 05HPQV-E BPR5TQ-S-CH -- Kuoni Reisen Holding AG
# 05HJCP-E BT09PM-S-CH -- Bâloise-Holding AG
# 0BDHV2-E BV5GNK-S-CH -- ALSO Holding AG
# 05TXMX-E BWL62M-S-PL -- Zespol Elektrowni Patnow Adamow Konin SA
# 05J1B1-E BZVNKT-S-CH -- Basler Kantonalbank
# 05J9J7-E C33VKS-S-CH -- Starrag Group Holding AG
# 05JPVQ-E C7S4S6-S-CH -- Tornos Holding AG
# 060JP0-E C7TC2B-S-CH -- Ypsomed Holding AG
# 05HX07-E CD5GS4-S-CH -- EMS-Chemie Holding AG
#   ...
#     (228)

# %%
output = make_output(pl_ch_uni)

# %%
output
# Out:
# {05J115-E THBKPG-S-CH -- BELIMO Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             19  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J9J7-E C33VKS-S-CH -- Starrag Group Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 423 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          423  non-null values
#  alpha            423  non-null values
#  bench            423  non-null values
#  beta             423  non-null values
#  r2               423  non-null values
#  abs_ret          423  non-null values
#  news             26  non-null values
#  important_day    423  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  001XTQ-E CW2HZR-S-CH -- Von Roll Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             20  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HWGP-E RT6KLW-S-PL -- Bank Pekao SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             73  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  066L0W-E J3NYD6-S-CH -- USI Group Holdings AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 157 entries, 2012-11-12 16:30:00+00:00 to 2014-06-03 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          157  non-null values
#  alpha            157  non-null values
#  bench            157  non-null values
#  beta             157  non-null values
#  r2               157  non-null values
#  abs_ret          157  non-null values
#  news             12  non-null values
#  important_day    157  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  0BDHV2-E BV5GNK-S-CH -- ALSO Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 418 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          418  non-null values
#  alpha            418  non-null values
#  bench            418  non-null values
#  beta             418  non-null values
#  r2               418  non-null values
#  abs_ret          418  non-null values
#  news             31  non-null values
#  important_day    418  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HX79-E R9CCSX-S-PL -- Bank Zachodni WBK SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 496 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          496  non-null values
#  alpha            496  non-null values
#  bench            496  non-null values
#  beta             496  non-null values
#  r2               496  non-null values
#  abs_ret          496  non-null values
#  news             103  non-null values
#  important_day    496  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J9PG-E PC16ZT-S-CH -- Vetropack Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             14  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  003KK4-E F3P6BT-S-CH -- SHL Telemedicine Ltd.: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 406 entries, 2012-06-12 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          406  non-null values
#  alpha            406  non-null values
#  bench            406  non-null values
#  beta             406  non-null values
#  r2               406  non-null values
#  abs_ret          406  non-null values
#  news             34  non-null values
#  important_day    406  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  0018W7-E HY3GFB-S-CH -- Ascom Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             105  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J09G-E P6LY4Z-S-CH -- Romande Energie Holding SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 470 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          470  non-null values
#  alpha            470  non-null values
#  bench            470  non-null values
#  beta             470  non-null values
#  r2               470  non-null values
#  abs_ret          470  non-null values
#  news             23  non-null values
#  important_day    470  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05GGL5-E XLT27Z-S-CH -- Zurich Insurance Group AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             238  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  003J1Y-E TBRGP3-S-CH -- Compagnie Financière Richemont SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             182  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HZK6-E KFJ5CJ-S-CH -- Intershop Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             18  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HZH5-E B3L0R6-S-CH -- Forbo Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             41  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JC3P-E VNNWVH-S-CH -- CALIDA Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 492 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          492  non-null values
#  alpha            492  non-null values
#  bench            492  non-null values
#  beta             492  non-null values
#  r2               492  non-null values
#  abs_ret          492  non-null values
#  news             30  non-null values
#  important_day    492  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J42V-E HD2HGV-S-CH -- Mikron Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 496 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          496  non-null values
#  alpha            496  non-null values
#  bench            496  non-null values
#  beta             496  non-null values
#  r2               496  non-null values
#  abs_ret          496  non-null values
#  news             18  non-null values
#  important_day    496  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  00B0YP-E QF3C90-S-CH -- gategroup Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             53  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05FWJ1-E LM0SMJ-S-CH -- Banque Cantonale Vaudoise: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             41  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05TXLB-E FK5QPQ-S-PL -- Grupa Azoty SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             68  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  07JYWP-E F9D3RV-S-CH -- Datacolor AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 168 entries, 2012-07-16 15:30:00+00:00 to 2014-06-05 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          168  non-null values
#  alpha            168  non-null values
#  bench            168  non-null values
#  beta             168  non-null values
#  r2               168  non-null values
#  abs_ret          168  non-null values
#  news             39  non-null values
#  important_day    168  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  00C79S-E LTN9LD-S-CH -- GAM Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             60  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HWWX-E QQ0N35-S-CH -- Kühne + Nagel International AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             114  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JK9B-E BJ1RB4-S-CH -- Nobel Biocare Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             115  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06H3GF-E Q1T7D9-S-CH -- Coltene Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             18  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05MBK2-E FMH4SM-S-CH -- Emmi AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             49  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HYWM-E TN113Z-S-PL -- mBank SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 496 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          496  non-null values
#  alpha            496  non-null values
#  bench            496  non-null values
#  beta             496  non-null values
#  r2               496  non-null values
#  abs_ret          496  non-null values
#  news             38  non-null values
#  important_day    496  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06H5DY-E LJPM2X-S-CH -- HOCHDORF Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 495 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          495  non-null values
#  alpha            495  non-null values
#  bench            495  non-null values
#  beta             495  non-null values
#  r2               495  non-null values
#  abs_ret          495  non-null values
#  news             21  non-null values
#  important_day    495  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JM5V-E LLVHJK-S-CH -- Compagnie Financière Tradition SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 493 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          493  non-null values
#  alpha            493  non-null values
#  bench            493  non-null values
#  beta             493  non-null values
#  r2               493  non-null values
#  abs_ret          493  non-null values
#  news             37  non-null values
#  important_day    493  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06ZD5Q-E RCKQ85-S-CH -- Gottex Fund Management Holdings Ltd.: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 493 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          493  non-null values
#  alpha            493  non-null values
#  bench            493  non-null values
#  beta             493  non-null values
#  r2               493  non-null values
#  abs_ret          493  non-null values
#  news             34  non-null values
#  important_day    493  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HL3L-E HHBMBR-S-CH -- Clariant AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             215  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J57L-E JPTGC7-S-CH -- Metall Zug AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 496 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          496  non-null values
#  alpha            496  non-null values
#  bench            496  non-null values
#  beta             496  non-null values
#  r2               496  non-null values
#  abs_ret          496  non-null values
#  news             31  non-null values
#  important_day    496  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06074W-E KNCRV1-S-PL -- PBG SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             58  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HXS3-E HBY9BT-S-CH -- Kaba Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             78  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JD2B-E CZCLPK-S-CH -- AEVIS Holding SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 398 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          398  non-null values
#  alpha            398  non-null values
#  bench            398  non-null values
#  beta             398  non-null values
#  r2               398  non-null values
#  abs_ret          398  non-null values
#  news             26  non-null values
#  important_day    398  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J10Q-E R95T5P-S-CH -- HUBER+SUHNER AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             75  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HXCN-E B9366V-S-CH -- Sonova Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             121  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  08K48S-E SSJ8ZX-S-CH -- Zug Estates Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 242 entries, 2013-06-17 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          242  non-null values
#  alpha            242  non-null values
#  bench            242  non-null values
#  beta             242  non-null values
#  r2               242  non-null values
#  abs_ret          242  non-null values
#  news             11  non-null values
#  important_day    242  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  062PCB-E JH6JCS-S-CH -- Newron Pharmaceuticals SpA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             41  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HZQ4-E MWM9SJ-S-CH -- Galenica AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             51  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JBKC-E QQ5Y64-S-CH -- Loeb Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 369 entries, 2012-06-11 15:30:00+00:00 to 2014-06-05 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          369  non-null values
#  alpha            369  non-null values
#  bench            369  non-null values
#  beta             369  non-null values
#  r2               369  non-null values
#  abs_ret          369  non-null values
#  news             11  non-null values
#  important_day    369  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HJQ3-E LGFX0C-S-CH -- Lonza Group AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             154  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  0036WD-E DF3GY7-S-CH -- INFICON Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             29  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JF44-E NYPFYL-S-CH -- BVZ Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 311 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          311  non-null values
#  alpha            311  non-null values
#  bench            311  non-null values
#  beta             311  non-null values
#  r2               311  non-null values
#  abs_ret          311  non-null values
#  news             11  non-null values
#  important_day    311  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JFB5-E PZBVQM-S-PL -- Rafako SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             38  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HWXD-E T1P9F7-S-CH -- Swiss International Air Lines AG: Empty DataFrame
#  Columns: [rel_ret, alpha, bench, beta, r2, abs_ret, news, important_day]
#  Index: [],
#  05TYH9-E MBR74M-S-PL -- Eurocash SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             30  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J266-E PHQDX2-S-CH -- Dätwyler Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             26  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05KXKC-E NT0JKL-S-PL -- Mostostal Warszawa SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 493 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          493  non-null values
#  alpha            493  non-null values
#  bench            493  non-null values
#  beta             493  non-null values
#  r2               493  non-null values
#  abs_ret          493  non-null values
#  news             27  non-null values
#  important_day    493  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  0699Q3-E PRL3PS-S-CH -- Implenia AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             61  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J13K-E M60NM2-S-CH -- Bucher Industries AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             113  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HYW8-E MS5TPL-S-CH -- BKW FMB Energie AG: Empty DataFrame
#  Columns: [rel_ret, alpha, bench, beta, r2, abs_ret, news, important_day]
#  Index: [],
#  05HJS6-E VMMRKB-S-CH -- Pargesa Holding SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             34  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JMX9-E K908K7-S-CH -- Accu Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 155 entries, 2012-10-26 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          155  non-null values
#  alpha            155  non-null values
#  bench            155  non-null values
#  beta             155  non-null values
#  r2               155  non-null values
#  abs_ret          155  non-null values
#  news             12  non-null values
#  important_day    155  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JCX0-E W3FNT0-S-CH -- Hügli Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 484 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          484  non-null values
#  alpha            484  non-null values
#  bench            484  non-null values
#  beta             484  non-null values
#  r2               484  non-null values
#  abs_ret          484  non-null values
#  news             16  non-null values
#  important_day    484  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HYW0-E TG6CKF-S-CH -- PSP Swiss Property AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             47  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J1BT-E LD5BF4-S-CH -- Swisslog Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             39  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06K54J-E GB095Q-S-CH -- OC Oerlikon Corp. AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             149  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05VRQ0-E PVZDMQ-S-PL -- Bogdanka Lubelski Wegiel SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             50  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05R7WH-E DLNYX3-S-CH -- SCHMOLZ + BICKENBACH AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             103  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HYZL-E SX5DLY-S-CH -- Bobst Group SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 494 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          494  non-null values
#  alpha            494  non-null values
#  bench            494  non-null values
#  beta             494  non-null values
#  r2               494  non-null values
#  abs_ret          494  non-null values
#  news             27  non-null values
#  important_day    494  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  07K684-E F4PXVL-S-CH -- Alpiq Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             110  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HYVW-E LX2GYY-S-CH -- Georg Fischer AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             56  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JPVQ-E C7S4S6-S-CH -- Tornos Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 494 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          494  non-null values
#  alpha            494  non-null values
#  bench            494  non-null values
#  beta             494  non-null values
#  r2               494  non-null values
#  abs_ret          494  non-null values
#  news             44  non-null values
#  important_day    494  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HMFN-E FXJ5WF-S-CH -- Repower AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 475 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          475  non-null values
#  alpha            475  non-null values
#  bench            475  non-null values
#  beta             475  non-null values
#  r2               475  non-null values
#  abs_ret          475  non-null values
#  news             102  non-null values
#  important_day    475  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06N60V-E CFBX8B-S-PL -- Asseco Poland SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             22  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06F4Y0-E Q56PJ8-S-CH -- Partners Group Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             90  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HXQ4-E FML079-S-CH -- Valora Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             53  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05LS6N-E T9PYNL-S-CH -- Panalpina Welttransport Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             138  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  08587L-E TKNGZ2-S-CH -- Julius Bär Gruppe AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             241  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J0BX-E WDBYR9-S-CH -- TEMENOS Group AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             53  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  0626FV-E QJKMWP-S-CH -- THERAMetrics holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 494 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          494  non-null values
#  alpha            494  non-null values
#  bench            494  non-null values
#  beta             494  non-null values
#  r2               494  non-null values
#  abs_ret          494  non-null values
#  news             38  non-null values
#  important_day    494  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05X140-E LZWN6R-S-PL -- Jastrzebska Spólka Weglowa SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 492 entries, 2012-06-18 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          492  non-null values
#  alpha            492  non-null values
#  bench            492  non-null values
#  beta             492  non-null values
#  r2               492  non-null values
#  abs_ret          492  non-null values
#  news             76  non-null values
#  important_day    492  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HZH0-E HJHS9P-S-CH -- Swiss Prime Site AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             46  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  0092QN-E RBJBCN-S-CH -- Cosmo Pharmaceuticals SpA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             29  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05YM3P-E M51RL0-S-CH -- Basilea Pharmaceutica AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             91  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JGML-E RPQ4V4-S-PL -- Polimex-Mostostal SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             89  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06Q6KP-E WSX1VG-S-CH -- VZ Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 495 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          495  non-null values
#  alpha            495  non-null values
#  bench            495  non-null values
#  beta             495  non-null values
#  r2               495  non-null values
#  abs_ret          495  non-null values
#  news             31  non-null values
#  important_day    495  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05FWJZ-E D0HSTL-S-CH -- Luzerner Kantonalbank AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             26  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  003J2S-E GNCGR4-S-PL -- KGHM Polska Miedz SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             153  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  001QBC-E JGZM69-S-CH -- Logitech International SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             90  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HWZT-E SGJ4BQ-S-CH -- Schindler Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             99  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05FRZ3-E M1HRSS-S-CH -- Banque Privée Edmond de Rothschild SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 413 entries, 2012-06-12 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          413  non-null values
#  alpha            413  non-null values
#  bench            413  non-null values
#  beta             413  non-null values
#  r2               413  non-null values
#  abs_ret          413  non-null values
#  news             23  non-null values
#  important_day    413  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06H61M-E N4MK7H-S-CH -- Burckhardt Compression Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             45  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HWGC-E THBV6Q-S-PL -- Orange Polska SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 496 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          496  non-null values
#  alpha            496  non-null values
#  bench            496  non-null values
#  beta             496  non-null values
#  r2               496  non-null values
#  abs_ret          496  non-null values
#  news             70  non-null values
#  important_day    496  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HWWL-E HD3D5P-S-CH -- Liechtensteinische Landesbank AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             42  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HF52-E JJ8MHV-S-CH -- Syngenta AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             230  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JDYL-E GB180M-S-CH -- CREALOGIX Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 436 entries, 2012-06-12 15:30:00+00:00 to 2014-06-03 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          436  non-null values
#  alpha            436  non-null values
#  bench            436  non-null values
#  beta             436  non-null values
#  r2               436  non-null values
#  abs_ret          436  non-null values
#  news             68  non-null values
#  important_day    436  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  07JKVP-E JFWY3V-S-CH -- Leonteq AG: <class 'pandas.core.frame.DataFrame'>
# ...
#  Data columns (total 8 columns):
#  rel_ret          484  non-null values
#  alpha            484  non-null values
#  bench            484  non-null values
#  beta             484  non-null values
#  r2               484  non-null values
#  abs_ret          484  non-null values
#  news             28  non-null values
#  important_day    484  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06B35H-E KZRX7C-S-CH -- Dufry AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             99  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HXP5-E CL0TNB-S-CH -- Lindt & Sprüngli AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             70  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  000VJ8-E M50G2S-S-CH -- Roche Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             403  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HZ7B-E PZBL6C-S-CH -- Barry Callebaut AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             135  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HZB6-E FWK8VC-S-CH -- Valiant Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             34  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J9F3-E T9S2QL-S-CH -- LEM Holding SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             26  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05FWLR-E K6W051-S-CH -- Bank Sarasin & Cie. AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 221 entries, 2012-06-11 15:30:00+00:00 to 2013-05-17 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          221  non-null values
#  alpha            221  non-null values
#  bench            221  non-null values
#  beta             221  non-null values
#  r2               221  non-null values
#  abs_ret          221  non-null values
#  news             37  non-null values
#  important_day    221  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  095XWF-E K81TX3-S-CH -- Cembra Money Bank AG: Empty DataFrame
#  Columns: [rel_ret, alpha, bench, beta, r2, abs_ret, news, important_day]
#  Index: [],
#  001YJY-E HTPG7V-S-CH -- Credit Suisse Group AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             477  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05JF24-E X8RZZ1-S-CH -- Elma Electronic AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 218 entries, 2012-06-11 15:30:00+00:00 to 2014-06-06 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          218  non-null values
#  alpha            218  non-null values
#  bench            218  non-null values
#  beta             218  non-null values
#  r2               218  non-null values
#  abs_ret          218  non-null values
#  news             11  non-null values
#  important_day    218  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05FWCG-E DKHSY5-S-CH -- Swiss Life Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             136  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05TSHP-E CQNCF1-S-PL -- Powszechny Zaklad Ubezpieczen SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             86  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HXJX-E BNLZPP-S-CH -- Helvetia Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             63  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HYWP-E NT081B-S-CH -- Tamedia AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 496 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          496  non-null values
#  alpha            496  non-null values
#  bench            496  non-null values
#  beta             496  non-null values
#  r2               496  non-null values
#  abs_ret          496  non-null values
#  news             113  non-null values
#  important_day    496  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05FWM4-E TBY5KG-S-CH -- Banque Cantonale de Genève: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             23  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J3QQ-E W7V1Y0-S-CH -- Cham Paper Group Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 448 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          448  non-null values
#  alpha            448  non-null values
#  bench            448  non-null values
#  beta             448  non-null values
#  r2               448  non-null values
#  abs_ret          448  non-null values
#  news             14  non-null values
#  important_day    448  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HZ2C-E N5PWTS-S-CH -- PubliGroupe SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             57  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05LVGR-E JCLN3X-S-PL -- Cyfrowy Polsat SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             45  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  060JP0-E C7TC2B-S-CH -- Ypsomed Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             18  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J59N-E CD6FM1-S-CH -- Walter Meier AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             22  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  06HKF6-E J64LL4-S-CH -- bfw liegenschaften AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 415 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          415  non-null values
#  alpha            415  non-null values
#  bench            415  non-null values
#  beta             415  non-null values
#  r2               415  non-null values
#  abs_ret          415  non-null values
#  news             15  non-null values
#  important_day    415  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J5MQ-E FS0924-S-CH -- Bossard Holding AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             18  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HXN2-E WYHX9J-S-CH -- Actelion Ltd.: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             142  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05SKCF-E SC4YMY-S-PL -- Ciech SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             33  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  067HV6-E MYVFRJ-S-PL -- ENEA SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             101  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05HL2N-E KV4JST-S-CH -- The Swatch Group AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             224  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05TNVM-E Q6M8S9-S-PL -- Bank Gospodarki Zywnosciowej SA: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             34  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  05J22K-E F1DV4S-S-CH -- Zehnder Group AG: <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 498 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          498  non-null values
#  alpha            498  non-null values
#  bench            498  non-null values
#  beta             498  non-null values
#  r2               498  non-null values
#  abs_ret          498  non-null values
#  news             24  non-null values
#  important_day    498  non-null values
#  dtypes: bool(1), float64(6), object(1),
#  002L8C-E D9LND3-S-PL -- Netia SA (Poland): <class 'pandas.core.frame.DataFrame'>
#  DatetimeIndex: 497 entries, 2012-06-11 15:30:00+00:00 to 2014-06-10 15:30:00+00:00
#  Data columns (total 8 columns):
#  rel_ret          497  non-null values
#  alpha            497  non-null values
#  bench            497  non-null values
#  beta             497  non-null values
#  r2               497  non-null values
#  abs_ret          497  non-null values
#  news             31  non-null values
#  important_day    497  non-null values
#  dtypes: bool(1), float64(6), object(1)}

# %%
abb = pl_ch_uni[0]

# %%
abb.
# Out:
# 0036X2-E B00N7M-S-CH -- ABB Ltd.

# %%
from fsprices.universe import get_research_universe

# %%
runi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22345 entries, B00BPC-S-JP to XR92HK-S-HK
# Data columns (total 16 columns):
# fs_perm_sec_id       22345  non-null values
# factset_entity_id    22345  non-null values
# currency             22345  non-null values
# sec_type             22345  non-null values
# exchange             22345  non-null values
# security_name        22345  non-null values
# country              22345  non-null values
# name                 22345  non-null values
# proper_name          22345  non-null values
# industry             22345  non-null values
# sector               22345  non-null values
# entity_country       22345  non-null values
# isin                 22345  non-null values
# ticker               22345  non-null values
# avg_vol              22345  non-null values
# market_cap           22345  non-null values
# dtypes: float64(2), object(14)
