# %%
# %load_ext autoreload
# %autoreload 2

# %%
from concat_overlord.tests.test_update_client import (
    MOCK_OUTPUT, TestUpdate
)

# %%
tu = TestUpdate()

# %%
tu.setUp()

# %%
tu.test_update_ubs()

# %%
tu.test_update_with_copy_from_fail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-00911912cb7c> in <module>()
# ----> 1 tu.test_update_with_copy_from_fail()
#
# /vagrant/concat_overlord/tests/test_update_client.py in test_update_with_copy_from_fail(self)
#      54             uni = Universe([UBS, CS, JB])
#      55             self.assertRaises(TypeError, update, (uni, self.db))
# ---> 56             assert self.db.execute(q.format('universe')).scalar() == 0
#      57             assert self.db.execute(q.format('news')).scalar() == 0
#      58             assert self.db.execute(q.format('return_data')).scalar() == 0
#
# NameError: name 'q' is not defined

# %%
tu.tearDown()

# %%
tcf = TestCopyFrom()

# %%
tcf.setUp()

# %%
tcf.test_fail_no_fail()
# Out:
# 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-8df46ce10fb4> in <module>()
# ----> 1 tcf.test_fail_no_fail()
#
# /vagrant/blvutils/tests/test_sql.py in test_fail_no_fail(self)
#      42             q = "SELECT count(*) from {0}"
#      43             print(self.db.execute(q.format('news')).scalar())
# ---> 44             assert self.db.execute(q.format('news')).scalar() == 5
#      45
#      46         MOCK_INCORRECT_INPUT = [{'id': 'reuters-234567',
#
# AssertionError:

# %%
tcf.tearDown()
