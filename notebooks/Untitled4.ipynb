# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from blvresearch.concat.analysts.reuters.main import (
    get_reuters_research_news
)
from blvprices.universe import Universe

# %%
uni = Universe('CONCAT_STANDARD')
start = '2014-01-01'
end = '2014-07-31'

# %%
entities = [sec.factset_entity_id for sec in uni]

# %%
news_items = get_reuters_research_news(entities, start, end)

# %%
len(news_items)
# Out:
# 65428

# %%
from feedimporter.analysts.reuters.main import (
    get_analysts_recommendations_from_news_items
)

# %%
res = get_analysts_recommendations_from_news_items(news_items)
# Out:
# Analyst not in database:  BNP Resources <BNXa.V:> Canaccord Genuity
# Analyst not in database:
#  Perrigo Company <PRGO.N> RBC
# Analyst not in database:
#  Perrigo Company <PRGO.N> RBC
# Analyst not in database:
#  Perrigo Company <PRGO.N> RBC
# Analyst not in database:
#  Perrigo Company <PRGO.N> RBC
# Analyst not in database:
#  Perrigo Company <PRGO.N> RBC
# Analyst not in database:
#  Perrigo Company <PRGO.N> RBC
# Analyst not in database:
#  Perrigo Company <PRGO.N> RBC
# Analyst not in database:
#  Perrigo Company <PRGO.N> RBC
# Analyst not in database:
#  Perrigo Company <PRGO.N> RBC
# Analyst not in database:
#  Perrigo Company <PRGO.N> RBC
# Analyst not in database:
#  Brokerage and Capital Markets Sector: Nomura
# Analyst not in database:
#  Brokerage and Capital Markets Sector: Nomura
# Analyst not in database:
#  Brokerage and Capital Markets Sector: Nomura
# Analyst not in database:
#  Brokerage and Capital Markets Sector: Nomura
# Analyst not in database:
#  Brokerage and Capital Markets Sector: Nomura
# Analyst not in database:
#  Brokerage and Capital Markets Sector: Nomura
# Analyst not in database:
#  Brokerage and Capital Markets Sector: Nomura
# Analyst not in database:
#  Shares rise 5.4% in early trade after Deutsche Bank
# to CZk 4700
# from CZk 4750
# to CZk 4700
# to CZk 4700
# from CZk 4750
# to CZk 4700
# from CZk 4750
# Analyst not in database:  Americas Waste sector: Credit Suisse
# to CZk 4700
# from CZk 4750
# to CZk 540
# from CZk 560
# to CZk 540
# from CZk 560
# to CZk 540
# from CZk 560
# to CZk 4700
# from CZk 4750
# to CZk 540
# from CZk 560
# to CZk 4700
# from CZk 4750
# Analyst not in database:
#  Americas waste sector: Credit Suisse
# to CZk 540
# from CZk 560
# to CZk 4700
# from CZk 4750
# Analyst not in database:
#  Teradata <TDC.N>, Atlantic Equities
# to CZk 540
# from CZk 560
# Analyst not in database:
#  Teradata <TDC.N>, Atlantic Equities
# Analyst not in database:  Americas waste sector: Credit Suisse
# Analyst not in database:
#  Teradata <TDC.N>, Atlantic Equities
# to CZk 540
# from CZk 560
# to CZk 4700
# from CZk 4750
# to CZk 540
# from CZk 560
# to CZk 4700
# from CZk 4750
# Analyst not in database:
#  Teradata <TDC.N>, Atlantic Equities
# Analyst not in database:  Americas waste sector: Credit Suisse
# Analyst not in database:
#  Teradata <TDC.N>, Atlantic Equities
# Analyst not in database:
#  Teradata <TDC.N>, Atlantic Equities
# Analyst not in database:  Americas waste sector: Credit Suisse
# Analyst not in database:
#  Teradata <TDC.N>, Atlantic Equities
# Analyst not in database:  Americas waste sector: Credit Suisse
# to CZk 540
# from CZk 560
# to CZk 4700
# from CZk 4750
# to CZk 540
# from CZk 560
# to CZk 540
# from CZk 560
# to CZk 4700
# from CZk 4750
# Analyst not in database:
#  Teradata <TDC.N>, Atlantic Equities
# Analyst not in database:  Americas waste sector: Credit Suisse
# Analyst not in database:
#  Teradata <TDC.N>, Atlantic Equities
# Analyst not in database:  Americas waste sector: Credit Suisse
# Analyst not in database:
#  Demandware Inc <DWRE.N>, ChannelAdvisor Corp <ECOM.N> ; Goldman Sachs
# 60000
# Analyst not in database:
#  TERI.PA
# Analyst not in database:
#  TERI.PA
# Analyst not in database:
#  TERI.PA
# Analyst not in database:
#  TERI.PA
# Analyst not in database:
#  Quanta services: Deutsche Bank
# Analyst not in database:
#  European Telecommunications Services: Morgan Stanley
# Analyst not in database:
#  European Telecommunications Services: Morgan Stanley
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:  European Telecommunications Services: Morgan Stanley
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:  European Telecommunications Services: Morgan Stanley
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:
#  European Telecommunications Services: Morgan Stanley
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:
#  European Telecommunications Services: Morgan Stanley
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:
#  European Telecommunications Services: Morgan Stanley
# Analyst not in database:
#  RBI <RBI.VI> Berenberg Bank
# Analyst not in database:
#  Scorpio Bulkers <SALT.NFF> Evercore
# Analyst not in database:
#  Scorpio Bulkers <SALT.NFF> Evercore
# Analyst not in database:
#  Scorpio Bulkers <SALT.NFF> Evercore
# Analyst not in database:
#  Scorpio Bulkers <SALT.NFF> Evercore
# Analyst not in database:
#  Scorpio Bulkers <SALT.NFF> Evercore
# Analyst not in database:
#  Scorpio Bulkers <SALT.NFF> Evercore
# Analyst not in database:
#  Deutsche
# Analyst not in database:
#  ; susquehanna
# Analyst not in database:
#  Philip Morris International <PM.N> Renaissance Capital
# Analyst not in database:
#  GasLog Ltd <GLOG.N>  Jefferies
# Analyst not in database:
#  Philip Morris International <PM.N> Renaissance Capital
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Philip Morris International <PM.N> Renaissance Capital
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# Analyst not in database:
#  Philip Morris International <PM.N> Renaissance Capital
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  GasLog Ltd <GLOG.N> Jefferies
# Analyst not in database:
#  Microchip Technology <MCHP.O> Citigroup
# 50000
# Analyst not in database:
#  Coloplast A/S <COLOb.CO> UBS
# Analyst not in database:
#  Coloplast A/S <COLOb.CO> UBS
# Analyst not in database:
#  Coloplast A/S <COLOb.CO> UBS
# Analyst not in database:
#  Coloplast A/S <COLOb.CO> UBS
# Analyst not in database:
#  Coloplast A/S <COLOb.CO> UBS
# Analyst not in database:
#  Coloplast A/S <COLOb.CO> UBS
# Analyst not in database:
#  Coloplast A/S <COLOb.CO> UBS
# Analyst not in database:
#  Coloplast A/S <COLOb.CO> UBS
# Analyst not in database:
#  Coloplast A/S <COLOb.CO> UBS
# Analyst not in database:
#  Italian banks: Citigroup
# Analyst not in database:
#  Italian banks: Citigroup
# Analyst not in database:
#  Deutsche
# Analyst not in database:  Italian banks: Citigroup
# Analyst not in database:
#  Italian banks: Citigroup
# Analyst not in database:
#  Italian banks: Citigroup
# Analyst not in database:
#  Deutsche
# Analyst not in database:  Italian banks: Citigroup
# Analyst not in database:  Italian banks: Citigroup
# Analyst not in database:
#  Italian banks: Citigroup
# Analyst not in database:
#  Deutsche
# Analyst not in database:  Italian banks: Citigroup
# Analyst not in database:
#  Italian banks: Citigroup
# Analyst not in database:
#  National bnak financial
# Analyst not in database:
#  Qualys Inc <QLYS.O> BMO
# Analyst not in database:
#  Qualys Inc <QLYS.O> BMO
# Analyst not in database:
#  Qualys Inc <QLYS.O> BMO
# to CZk 4,705
# from CZk 3,960
# to CZk 4,705
# from CZk 3,960
# to CZk 4,705
# from CZk 3,960
# to CZk 4,705
# from CZk 3,960
# to CZk 4,705
# from CZk 3,960
# Analyst not in database:
#  Self storage sector: Raymond James
# Analyst not in database:
#  Self storage sector: Raymond James
# Analyst not in database:
#  Self storage sector: Raymond James
# Analyst not in database:
#  Self storage sector: Raymond James
# Analyst not in database:
#  Self storage sector: Raymond James
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  De
# Analyst not in database:
#  De
# Analyst not in database:  De
# Analyst not in database:
#  De
# Analyst not in database:  De
# Analyst not in database:
#  De
# Analyst not in database:  De
# Analyst not in database:
#  De
# Analyst not in database:  De
# Analyst not in database:
#  De
# Analyst not in database:  De
# Analyst not in database:
#  De
# Analyst not in database:
#  De
# Analyst not in database:
#  De
# Analyst not in database:
#  De
# Analyst not in database:
#  De
# Analyst not in database:
#  Global Luxury Goods: Credit Suisse
# Analyst not in database:
#  Global Luxury Goods: Credit Suisse
# Analyst not in database:
#  Global Luxury Goods: Credit Suisse
# Analyst not in database:
#  Global Luxury Goods: Credit Suisse
# 40000
# Analyst not in database:
#  Global Luxury Goods: Credit Suisse
# Analyst not in database:
#  European Utilities: Citigroup
# to CZk 544
# from CZk 700
# to CZk 544
# from CZk 700
# Analyst not in database:
#  European Utilities: Citigroup
# to CZk 544
# from CZk 700
# to CZk 544
# from CZk 700
# to CZk 544
# from CZk 700
# to CZk 544
# from CZk 700
# Analyst not in database:
#  European Utilities: Citigroup
# to CZk 544
# from CZk 700
# to CZk 544
# from CZk 700
# Analyst not in database:
#  European Utilities: Citigroup
# to CZk 340
# to CZk 340
# from CZk 320
# Analyst not in database:  Assore Ltd <ASRJ.J> Citigroup
# to CZk 340
# from CZk 320
# to CZk 340
# from CZk 320
# to CZk 340
# from CZk 320
# Analyst not in database:
#  Pipe Jaffray
# Analyst not in database:
#  Barlays
# Analyst not in database:
#  Barlays
# Analyst not in database:
#  Barlays
# Analyst not in database:
#  Barlays
# Analyst not in database:
#  Barlays
# Analyst not in database:
#  Barlays
# Analyst not in database:
#  Barlays
# Analyst not in database:
#  pacific
# Analyst not in database:
#  pacific
# Analyst not in database:
#  pacific
# Analyst not in database:
#  pacific
# Analyst not in database:
#  pacific
# Analyst not in database:
#  pacific
# Analyst not in database:
#  pacific
# Analyst not in database:
#  pacific
# Analyst not in database:
#  pacific
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  ; Deutsche Bank
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Defense sector: RBC
# Analyst not in database:
#  KKR & Co <KKR.N> JMP Securities
# Analyst not in database:  Defense sector: RBC
# Analyst not in database:
#  KKR & Co <KKR.N> JMP Securities
# Analyst not in database:
#  KKR & Co <KKR.N> JMP Securities
# Analyst not in database:  Defense sector: RBC
# Analyst not in database:
#  KKR & Co <KKR.N> JMP Securities
# Analyst not in database:
#  KKR & Co <KKR.N> JMP Securities
# Analyst not in database:  Defense sector: RBC
# Analyst not in database:
#  KKR & Co <KKR.N> JMP Securities
# Analyst not in database:  Defense Sector: RBC
# Analyst not in database:
#  KKR & Co <KKR.N> JMP Securities
# Analyst not in database:  European Tech Hardware: UBS
# Analyst not in database:
#  European Tech Hardware: UBS
# Analyst not in database:  European Tech Hardware: UBS
# Analyst not in database:
#  KKR & Co <KKR.N> JMP Securities
# Analyst not in database:  Defense Sector: RBC
# Analyst not in database:
#  KKR & Co <KKR.N> JMP Securities
# Analyst not in database:
#  Naeem
# Analyst not in database:
#  Naeem
# Analyst not in database:
#  Naeem
# Analyst not in database:
#  Naeem
# Analyst not in database:
#  Americas regulated and diversified utilities: Goldman Sachs
# Analyst not in database:
#  Americas Regulated and Diversified Utilities: Goldman Sachs
# Analyst not in database:
#  Americas Regulated and Diversified Utilities: Goldman Sachs
# Analyst not in database:
#  Americas Regulated and Diversified Utilities: Goldman Sachs
# Analyst not in database:
#  Americas Regulated and Diversified Utilities: Goldman Sachs
# 30000
# Analyst not in database:
#  Chardan Capital
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Chardan Capital
# Analyst not in database:
#  Chardan Capital
# Analyst not in database:
#  Chardan Capital
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Noura
# Analyst not in database:  Pacific
# Analyst not in database:
#  Noura
# Analyst not in database:  Noura
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Noura
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Noura
# Analyst not in database:  Pacific
# Analyst not in database:
#  Noura
# Analyst not in database:  Pacific
# Analyst not in database:
#  Noura
# Analyst not in database:  Pacific
# Analyst not in database:
#  J P Morgan
# Analyst not in database:
#  J P Morgan
# Analyst not in database:
#  European Energy Sector: Morgan Stanley
# Analyst not in database:  European Materials Sector: Morgan Stanley
# Analyst not in database:  European Telecommunication Sector: Morgan Stanley
# Analyst not in database:
#  European Energy Sector: Morgan Stanley
# Analyst not in database:  European Materials Sector: Morgan Stanley
# Analyst not in database:  European Telecommunication Sector: Morgan Stanley
# Analyst not in database:
#  European Energy Sector: Morgan Stanley
# Analyst not in database:  European Materials Sector: Morgan Stanley
# Analyst not in database:  European Telecommunication Sector: Morgan Stanley
# Analyst not in database:
#  CIC
# Analyst not in database:
#  CIC
# Analyst not in database:
#  CIC
# Analyst not in database:
#  CIC
# Analyst not in database:
#  CIC
# Analyst not in database:
#  CIC
# Analyst not in database:
#  CIC
# Analyst not in database:
#  CIC
# Analyst not in database:
#  pacific
# Analyst not in database:
#  pacific
# Analyst not in database:
#  Watts Water Technologies <WTS.N> Baird
# Analyst not in database:
#  Watts Water Technologies <WTS.N> Baird
# Analyst not in database:
#  Watts Water Technologies <WTS.N> Baird
# Analyst not in database:
#  Watts Water Technologies <WTS.N> Baird
# Analyst not in database:
#  Naeem
# Analyst not in database:  BMP
# Analyst not in database:
#  Naeem
# Analyst not in database:  USG People <SGP.AS> ING
# Analyst not in database:
#  Naeem
# Analyst not in database:  BMP
# Analyst not in database:  USG People <SGP.AS> ING
# Analyst not in database:
#  Naeem
# Analyst not in database:  BMP
# Analyst not in database:  USG People <SGP.AS> ING
# Analyst not in database:
#  Naeem
# Analyst not in database:  BMP
# Analyst not in database:
#  Naeem
# Analyst not in database:  BMP
# Analyst not in database:
#  Naeem
# Analyst not in database:  BMP
# Analyst not in database:  USG People <SGP.AS> ING
# Analyst not in database:
#  Americas Environmental Services: Credit Suisse
# Analyst not in database:
#  Americas Environmental Services: Credit Suisse
# Analyst not in database:
#  Americas Environmental Services: Credit Suisse
# Analyst not in database:
#  Americas Environmental Services: Credit Suisse
# Analyst not in database:
#  Americas Environmental Services: Credit Suisse
# Analyst not in database:
#  Americas Environmental Services: Credit Suisse
# Analyst not in database:
#  Americas Environmental Services: Credit Suisse
# Analyst not in database:
#  Susuqhanna
# Analyst not in database:  Davidson
# Analyst not in database:
#  Susuqhanna
# Analyst not in database:  Davidson
# Analyst not in database:
#  Susuqhanna
# Analyst not in database:  Davidson
# Analyst not in database:
#  Susuqhanna
# Analyst not in database:  Davidson
# Analyst not in database:
#  Susuqhanna
# Analyst not in database:  Davidson
# Analyst not in database:
#  Susuqhanna
# Analyst not in database:  Davidson
# Analyst not in database:
#  Susuqhanna
# Analyst not in database:  Davidson
# Analyst not in database:
#  Davidson
# Analyst not in database:
#  Susuqhanna
# Analyst not in database:  Davidson
# Analyst not in database:
#  Davidson
# Analyst not in database:
#  Davidson
# Analyst not in database:
#  Susuqhanna
# Analyst not in database:  Davidson
# Analyst not in database:
#  Davidson
# Analyst not in database:
#  Davidson
# Analyst not in database:
#  Davidson
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  CreditSuisse
# Analyst not in database:
#  Teleste <LT1V.HE> ESN/Pohjola
# Analyst not in database:
#  Teleste <LT1V.HE> ESN/Pohjola
# Analyst not in database:
#  Teleste <LT1V.HE> ESN/Pohjola
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Teleste <LT1V.HE> ESN/Pohjola
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# 20000
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Benchamrk
# Analyst not in database:
#  Desjardin
# Analyst not in database:
#  Retail Softline Sector: Janney
# Analyst not in database:
#  Retail Softline Sector: Janney
# Analyst not in database:
#  Retail Softline Sector: Janney
# Analyst not in database:
#  Retail Softline Sector: Janney
# Analyst not in database:
#  Retail Softline Sector: Janney
# Analyst not in database:
#  Retail Softline Sector: Janney
# Analyst not in database:
#  Retail Softline Sector: Janney
# Analyst not in database:
#  France : Credit Suisse
# Analyst not in database:  Germany: Credit Suisse
# Analyst not in database:
#  France : Credit Suisse
# Analyst not in database:  Germany: Credit Suisse
# Analyst not in database:
#  France : Credit Suisse
# Analyst not in database:  Germany: Credit Suisse
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  European Oil: Deutsche Bank
# Analyst not in database:  European Industrials: Deutsche Bank
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  European Oil: Deutsche Bank
# Analyst not in database:  European Industrials: Deutsche Bank
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  European Oil: Deutsche Bank
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  European Oil: Deutsche Bank
# Analyst not in database:  European Industrials: Deutsche Bank
# Analyst not in database:  Ålandsbanken
# Analyst not in database:
#  Ålandsbanken
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Blackpearl Resources <PXX.TO> CIBC
# Analyst not in database:
#  Blackpearl Resources <PXX.TO> CIBC
# Analyst not in database:
#  Blackpearl Resources <PXX.TO> CIBC
# Analyst not in database:
#  Blackpearl Resources <PXX.TO> CIBC
# Analyst not in database:
#  Blackpearl Resources <PXX.TO> CIBC
# Analyst not in database:
#  GHS
# Analyst not in database:
#  GHS
# Analyst not in database:
#  GHS
# Analyst not in database:
#  GHS
# Analyst not in database:
#  GHS
# Analyst not in database:
#  GHS
# to Czk 4706
# from Czk 5126
# Analyst not in database:  Turkey: JP Morgan
# to Czk 510
# from Czk 480
# to Czk 4706
# from Czk 5126
# Analyst not in database:
#  Turkey: JP Morgan
# to Czk 510
# from Czk 480
# to Czk 4706
# from Czk 5126
# Analyst not in database:  Turkey: JP Morgan
# to Czk 510
# from Czk 480
# to Czk 4706
# from Czk 5126
# to Czk 510
# from Czk 480
# to Czk 4706
# from Czk 5126
# to Czk 510
# from Czk 480
# to Czk 4706
# from Czk 5126
# Analyst not in database:  Turkey: JP Morgan
# to Czk 510
# from Czk 480
# to Czk 4706
# from Czk 5126
# to Czk 510
# from Czk 480
# to Czk 4706
# from Czk 5126
# Analyst not in database:  Turkey: JP Morgan
# Analyst not in database:
#  Rayond James
# Analyst not in database:  Rayond James
# to Czk 510
# from Czk 480
# to Czk 4706
# from Czk 5126
# to Czk 510
# from Czk 480
# to Czk 4706
# from Czk 5126
# Analyst not in database:  Turkey: JP Morgan
# Analyst not in database:
#  Rayond James
# Analyst not in database:
#  Rayond James
# Analyst not in database:
#  Russian Steel: Barclays
# Analyst not in database:
#  DRAEGERWERK DRWG_p.DE: BERENBERG
# Analyst not in database:
#  Russian Steel: Barclays
# Analyst not in database:
#  Russian Steel: Barclays
# Analyst not in database:  DRAEGERWERK DRWG_p.DE: BERENBERG
# Analyst not in database:
#  Russian Steel: Barclays
# Analyst not in database:
#  Russian Steel: Barclays
# Analyst not in database:  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Shuaa Capital
# Analyst not in database:  Russian Steel: Barclays
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Shuaa Capital
# Analyst not in database:  Russian Steel: Barclays
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:  Pacific
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:  Pacific
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:  IBG Research
# Analyst not in database:
#  IBG Research
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:  IBG Research
# Analyst not in database:
#  IBG Research
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Gulfport Energy Corp <GPOR.O> SunTrust Robinson
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Morgan Stanly
# Analyst not in database:
#  Morgan Stanly
# Analyst not in database:
#  Telecom: Bernstein
# Analyst not in database:
#  Telecom: Bernstein
# Analyst not in database:
#  Telecom: Bernstein
# Analyst not in database:
#  PI Research
# Analyst not in database:  PI Research
# Analyst not in database:
#  PI Research
# Analyst not in database:  PI Research
# Analyst not in database:
#  CreditSuisse
# Analyst not in database:
#  CreditSuisse
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Standard Chartered
# Analyst not in database:  Standard Chartered
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Standard Chartered
# Analyst not in database:  Standard Chartered
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Standard Chartered
# Analyst not in database:  Standard Chartered
# Analyst not in database:
#  Pacific
# Analyst not in database:  Standard Chartered
# Analyst not in database:  Standard Chartered
# Analyst not in database:
#  Russian Steel: Citigroup
# Analyst not in database:  Russian Steel: Citigroup
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Russian Steel: Citigroup
# Analyst not in database:  Russian Steel: Citigroup
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Miuho
# Analyst not in database:
#  Broadcom Corp <BRCM.O> Cowen & Co
# Analyst not in database:
#  Broadcom Corp <BRCM.O> Cowen & Co
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  Cancccord Genuity
# Analyst not in database:
#  Westhouse
# Analyst not in database:
#  Westhouse
# Analyst not in database:
#  Westhouse
# Analyst not in database:
#  MorganStanley
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Macau Gaming Sector: Union Gaming Research
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Macau Gaming Sector: Union Gaming Research
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Mcadams Wright Ragen
# Analyst not in database:
#  Mcadams Wright Ragen
# Analyst not in database:
#  Mcadams Wright Ragen
# Analyst not in database:
#  Mcadams Wright Ragen
# Analyst not in database:
#  Mcadams Wright Ragen
# Analyst not in database:
#  Mcadams Wright Ragen
# Analyst not in database:
#  Triumph Group Inc <TGI.N> Credit Suisse
# Analyst not in database:  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:
#  Chardan Capital
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:  Chardan Capital
# Analyst not in database:
#  Triumph Group <TGI.N> Credit Suisse
# Analyst not in database:
#  SP Angel
# Analyst not in database:  SP Angel
# Analyst not in database:
#  SP Angel
# 10000
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  H.C.Wainwright
# Analyst not in database:
#  H.C.Wainwright
# Analyst not in database:
#  H.C.Wainwright
# Analyst not in database:
#  H.C.Wainwright
# Analyst not in database:
#  SP Angel
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  H.C.Wainwright
# Analyst not in database:
#  H.C.Wainwright
# Analyst not in database:
#  H.C.Wainwright
# Analyst not in database:
#  H.C.Wainwright
# Analyst not in database:
#  H.C.Wainwright
# Analyst not in database:
#  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:  Morgn Stanley
# Analyst not in database:
#  European Utilities: Citigroup
# Analyst not in database:
#  European Utilities: Citigroup
# Analyst not in database:
#  European Utilities: Citigroup
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:  Pacific
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:  Pacific
# Analyst not in database:
#  Lake Street Capital
# Analyst not in database:
#  Advertising And Market Research: Natixis
# Analyst not in database:  Airlines: Natixis
# Analyst not in database:  Automotive Components: Natixis
# Analyst not in database:  Beverages: Natixis
# Analyst not in database:  Catering: Natixis
# Analyst not in database:  Cosmetics & Personal Care: Natixis
# Analyst not in database:  Food Sector: Natixis
# Analyst not in database:  Food Retailing: Natixis
# Analyst not in database:  Investment Banks: Natixis
# Analyst not in database:  IT Services: Natixis
# Analyst not in database:  Luxury Goods: Natixis
# Analyst not in database:  Non Food Retailing: Natixis
# Analyst not in database:  Pharmaceuticals Sector: Natixis
# Analyst not in database:
#  Advertising And Market Research: Natixis
# Analyst not in database:  Airlines: Natixis
# Analyst not in database:  Automotive Components: Natixis
# Analyst not in database:  Beverages: Natixis
# Analyst not in database:  Catering: Natixis
# Analyst not in database:  Cosmetics & Personal Care: Natixis
# Analyst not in database:  Food Sector: Natixis
# Analyst not in database:  Food Retailing: Natixis
# Analyst not in database:  Investment Banks: Natixis
# Analyst not in database:  IT Services: Natixis
# Analyst not in database:  Luxury Goods: Natixis
# Analyst not in database:  Non Food Retailing: Natixis
# Analyst not in database:  Pharmaceuticals Sector: Natixis
# Analyst not in database:
#  Advertising And Market Research: Natixis
# Analyst not in database:  Airlines: Natixis
# Analyst not in database:  Automotive Components: Natixis
# Analyst not in database:  Beverages: Natixis
# Analyst not in database:  Catering: Natixis
# Analyst not in database:  Cosmetics & Personal Care: Natixis
# Analyst not in database:  Food Sector: Natixis
# Analyst not in database:  Food Retailing: Natixis
# Analyst not in database:  Investment Banks: Natixis
# Analyst not in database:  IT Services: Natixis
# Analyst not in database:  Luxury Goods: Natixis
# Analyst not in database:  Non Food Retailing: Natixis
# Analyst not in database:  Pharmaceuticals Sector: Natixis
# Analyst not in database:
#  Fondsfinans
# Analyst not in database:
#  Mirabaud Securities
# Analyst not in database:  Fondsfinans
# Analyst not in database:  Sanlam
# Analyst not in database:
#  Mirabaud Securities
# Analyst not in database:  Fondsfinans
# Analyst not in database:  Sanlam
# Analyst not in database:
#  Six brokerages
# Analyst not in database:  Mirabaud Securities
# Analyst not in database:  Fondsfinans
# Analyst not in database:  Sanlam
# Analyst not in database:
#  Mirabaud Securities
# Analyst not in database:  Fondsfinans
# Analyst not in database:  Sanlam
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Lake Street capital
# Analyst not in database:
#  Research alert: Yit <YTY1V.HE> - inderes
# Analyst not in database:
#  Capital Goods: JP Morgan
# Analyst not in database:  Chemicals: JP Morgan
# Analyst not in database:  Utilities: JP Morgan
# Analyst not in database:
#  Capital Goods: JP Morgan
# Analyst not in database:  Chemicals: JP Morgan
# Analyst not in database:  Utilities: JP Morgan
# Analyst not in database:
#  Capital Goods: JP Morgan
# Analyst not in database:  Chemicals: JP Morgan
# Analyst not in database:  Utilities: JP Morgan
# Analyst not in database:
#  Netflix <NFLX.O>Goldman Sachs
# Analyst not in database:
#  Benzinga
# Analyst not in database:
#  Benzinga
# Analyst not in database:
#  Benzinga
# Analyst not in database:
#  Benzinga
# Analyst not in database:
#  Benzinga
# Analyst not in database:
#  Benzinga
# Analyst not in database:
#  Benzinga
# Analyst not in database:
#  Benzinga
# Analyst not in database:
#  Benzinga
# Analyst not in database:
#  Benzinga
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  European Chemicals Sector: UBS
# Analyst not in database:
#  European Chemicals Sector: UBS
# Analyst not in database:
#  The mean price target on the stock has gone
# Analyst not in database:
#  Naional Bank Financial
# Analyst not in database:
#  European Chemicals Sector: UBS
# Analyst not in database:  Naional Bank Financial
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Average price target on stock is USD 70
# Analyst not in database:
#  Deutsche
# to Czk 272
# from Czk 295.15
# Analyst not in database:
#  Deutsche
# to Czk 272
# from Czk 295.15
# to Czk 272
# from Czk 295.15
# Analyst not in database:
#  Deutsche
# Analyst not in database:
#  Deutsche
# to Czk 272
# from Czk 295.15
# Analyst not in database:  Deutsche
# Analyst not in database:
#  Deutsche
# to Czk 272
# from Czk 295.15
# Analyst not in database:  Deutsche
# Analyst not in database:
#  Deutsche
# Analyst not in database:
#  Deutsche
# Analyst not in database:
#  Deutsche
# to Czk 272
# from Czk 295.15
# Analyst not in database:
#  North America Capital Goods: Citigroup
# Analyst not in database:  North America Food, Beverage & Tobacco: Citigroup
# Analyst not in database:
#  North America Capital Goods: Citigroup
# Analyst not in database:  North America Food, Beverage & Tobacco: Citigroup
# Analyst not in database:
#  North America Capital Goods: Citigroup
# Analyst not in database:  North America Food, Beverage & Tobacco: Citigroup
# Analyst not in database:
#  North America Capital Goods: Citigroup
# Analyst not in database:  North America Food, Beverage & Tobacco: Citigroup
# Analyst not in database:
#  Coca-Cola Enterprises Inc <CCE.N> UBS
# Analyst not in database:
#  North America Capital Goods: Citigroup
# Analyst not in database:  North America Food, Beverage & Tobacco: Citigroup
# Analyst not in database:
#  Coca-Cola Enterprises Inc <CCE.N> UBS
# Analyst not in database:
#  Coca-Cola Enterprises Inc <CCE.N> UBS
# Analyst not in database:
#  North America Capital Goods: Citigroup
# Analyst not in database:  North America Food, Beverage & Tobacco: Citigroup
# Analyst not in database:
#  Coca-Cola Enterprises Inc <CCE.N> UBS
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Brokerage also
# Analyst not in database:
#  Brokerage also
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:  H.C.Wainwright
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Median price target on stock is USD 87
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Sanlam
# Analyst not in database:
#  > Imperial Capital
# Analyst not in database:
#  > Imperial Capital
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Median price target on stock is USD 672.50
# Analyst not in database:  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Analysts' median price target on stock is USD 22, unchanged
# Analyst not in database:  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Healthy Lifestyle Sector: Wolfe Research
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Healthy Lifestyle Sector: Wolfe Research
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Rowan Companies Plc Rdc.N>: Raymond James
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  Analysts have median price target of USD 55
# Analyst not in database:  Median price target on stock is USD 31
# Analyst not in database:  Median price target on stock is USD 48
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  Ricardo Plc <RCDO.L> Berenberg
# Analyst not in database:
#  J P Morgan
# Analyst not in database:
#  J P Morgan
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Median price target on stock has risen to USD 40 from USD 38 in
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Analysts at Cowen & Co
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:
#  Pacific
# Analyst not in database:  Pacific
# Analyst not in database:
#  Says price mix reduced sales by USD 146 MLN in the quarter- conf call
