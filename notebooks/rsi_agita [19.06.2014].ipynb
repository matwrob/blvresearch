# %% [markdown]
# # RSI Agita

# %%
from concat_overlord.universes.standard import new_universe
from concat_overlord.standard import make_output
from fsprices.universe import Universe

# %% [markdown]
# ### Load CH-universe and data

# %%
funi = new_universe()

# %%
output = make_output(Universe([s for s in funi if s.country == 'CH']))

# %% [markdown]
# ### Import SignalReport

# %%
from blvresearch.concat.signals.signal_testing import SignalReport

# %% [markdown]
# ### Import get_signals function

# %%
from blvresearch.concat.signals.rsi_agita import get_signals

# %% [markdown]
# # Periods = 14, Buy Threshold = 30, Sell Threshold = 70

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, periods=14, buy_thrsh=30, sell_thrsh=70)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())
# Out:
# Strategy generated profit for 105 companies (0.5412371134020618)
# Strategy generated loss for 89 companies (0.4587628865979381)
# Strategy outperformed SP500 for 21 companies (0.10824742268041238)
# Average number of signals per entity: 10.8041
# Average return of winners was 0.2636
# Average return of losers was -0.3194
# Over the next 20 trading days after signals:
# * 0.6229 of signals were correct among winners
# * 0.5343 of signals were incorrect among losers

# %% [markdown]
# # Periods = 14, Buy Threshold = 30, Sell Threshold = 50

# %%
signals = dict()
for k, v in output.items():
    if len(v) > 0:
        signals[k] = get_signals(v, periods=14, buy_thrsh=30, sell_thrsh=50)

# %%
sr = SignalReport(signals, output)

# %%
print(sr.get())
# Out:
# Strategy generated profit for 110 companies (0.5670103092783505)
# Strategy generated loss for 84 companies (0.4329896907216495)
# Strategy outperformed SP500 for 34 companies (0.17525773195876287)
# Average number of signals per entity: 18.6959
# Average return of winners was 0.3633
# Average return of losers was -0.304
# Over the next 20 trading days after signals:
# * 0.6952 of signals were correct among winners
# * 0.4186 of signals were incorrect among losers
