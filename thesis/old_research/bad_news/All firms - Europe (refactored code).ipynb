# %%
import os
os.chdir('c:/users/mateusz/dropbox/mateusz/python_projects')

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

from concat.core.utils import load_object

# %%
DATA = load_object('data_europe_1433_2011_2013.pickle')
UNI = load_object('uni_europe_1433_2011_2013.pickle')[2013]

# %%
from blvresearch.core.news_events import NewsEvent, data_is_valid, mean_test
from blvresearch.core.event_study import EventDetector, EventList

# %%
class ManyNewsAlphaSmallerThanMiuMinus2Sigmas(NewsEvent):
    def triggers(self):
        if self.has_many_news and self.alpha_is_smaller_than_miu_minus_2_sigmas:
            return True
        return False

# %%
detect_many_news_alpha_is_smaller_than_miu_minus_2_sigmas = EventDetector(ManyNewsAlphaSmallerThanMiuMinus2Sigmas)

# %%
events_many_news_alpha_is_smaller_than_miu_minus_2_sigmas = dict()
for entity_id, entity_data in DATA.items():
    if data_is_valid(entity_data):
        entity_meta = UNI[entity_id]
        entity_events = detect_many_news_alpha_is_smaller_than_miu_minus_2_sigmas.run(entity_id, entity_data, entity_meta)
        if len(entity_events) > 0:
            events_many_news_alpha_is_smaller_than_miu_minus_2_sigmas[entity_id] = entity_events

# %%
events_many_news_alpha_is_smaller_than_miu_minus_2_sigmas['002ZDR-E']
# Out:
# EventList with 4 events

# %%
list_many_news_alpha_is_smaller_than_miu_minus_2_sigmas = EventList.from_dict(events_many_news_alpha_is_smaller_than_miu_minus_2_sigmas)

# %%
list_many_news_alpha_is_smaller_than_miu_minus_2_sigmas
# Out:
# EventList with 1554 events

# %%
mean_test(list_many_news_alpha_is_smaller_than_miu_minus_2_sigmas, 'alpha', 20)
# Out:
# Mean: -0.0022552453334
# p_value: 0.353478608627

# %%
class ManyNewsAlphaSmallerThanMinus2pct(NewsEvent):
    def triggers(self):
        if self.has_many_news and self.alpha_is_smaller_than_minus_2pct:
            return True
        return False

# %%
detect_many_news_alpha_is_smaller_than_minus_2pct = EventDetector(ManyNewsAlphaSmallerThanMinus2pct)

# %%
events_many_news_alpha_is_smaller_than_minus_2pct = dict()
for entity_id, entity_data in DATA.items():
    if data_is_valid(entity_data):
        entity_meta = UNI[entity_id]
        entity_events = detect_many_news_alpha_is_smaller_than_minus_2pct.run(entity_id, entity_data, entity_meta)
        if len(entity_events) > 0:
            events_many_news_alpha_is_smaller_than_minus_2pct[entity_id] = entity_events

# %%
len(events_many_news_alpha_is_smaller_than_minus_2pct)
# Out:
# 912

# %%
list_many_news_alpha_is_smaller_than_minus_2pct = EventList.from_dict(events_many_news_alpha_is_smaller_than_minus_2pct)

# %%
list_many_news_alpha_is_smaller_than_minus_2pct
# Out:
# EventList with 2397 events

# %%
mean_test(list_many_news_alpha_is_smaller_than_minus_2pct, 'alpha', 20)
# Out:
# Mean: -0.0051074394324
# p_value: 0.0165795948643
