# %% [markdown]
# ##### Corporate actions: repurchase tender offers, spinoffs, dividend initiations, open market repurchases, stock splits, initial public offerings, proxy contests, seasoned equity offerings, short interest announcements, NYSE/AMEX listing of the firm's common stock, dividend omissions, mergers

# %%
import os

# %%
os.getcwd()
# Out:
# '/vagrant/blvresearch/cases/bad_news'
