# %%
from concat.core.utils import load_object

# %%
data_us = load_object('/vagrant/blvresearch/old_pickles/data_usa_2453_2011_2013.pickle')

# %% [raw]
# old data generated using BenchmarkModelData from benchmark_model module of concat was generated using:
#     start_date = '2011-01-01'
#     end_date = '2013-12-31'
#     in_currency = 'USD'

# %%
type(data_us)
# Out:
# builtins.dict

# %%
data_us.keys()
# Out:
# dict_keys(['000P9Q-E', '0019X6-E', '00B1TN-E', '0786ZZ-E', '06JJMP-E', '002KWN-E', '001FBC-E', '00971Z-E', '0BCB14-E', '000SSF-E', '002RNG-E', '000VJS-E', '001149-E', '003F4V-E', '001WLC-E', '000C7F-E', '003T5H-E', '004G1T-E', '007F7K-E', '003K8X-E', '002QYC-E', '0077YX-E', '0028JG-E', '06PNJ3-E', '001MLD-E', '0B5HPY-E', '0749WJ-E', '005L7T-E', '000Z8F-E', '002FR0-E', '001M70-E', '0013TZ-E', '001CK4-E', '005Y6G-E', '000P26-E', '0656DF-E', '003JLG-E', '000BNF-E', '0025RW-E', '007LD2-E', '06MRKQ-E', '008BHP-E', '000C49-E', '002FQK-E', '000WW4-E', '000YQ6-E', '000Y8L-E', '000DGZ-E', '002LRZ-E', '003HLJ-E', '007MJV-E', '0076J5-E', '0024Z2-E', '06GFD5-E', '00188S-E', '000P1X-E', '000N20-E', '00421P-E', '002HBC-E', '0092YV-E', '008Z4S-E', '002GTF-E', '000HMR-E', '000VC1-E', '000PF5-E', '008L5S-E', '003123-E', '009T85-E', '07ZPTB-E', '001D39-E', '0077JG-E', '00D41Y-E', '0017CF-E', '000XXL-E', '002PF5-E', '06Q9S5-E', '06T26D-E', '088LTZ-E', '0038QK-E', '0011ZQ-E', '0014BW-E', '007H1Z-E', '00
# ...

# %%
data_us['000C7F-E']['abs_ret'][:'2011-01-31']
# Out:
# date
# 2011-01-03    0.021500
# 2011-01-04    0.005205
# 2011-01-05    0.008147
# 2011-01-06   -0.000809
# 2011-01-07    0.007136
# 2011-01-10    0.018672
# 2011-01-11   -0.002383
# 2011-01-12    0.008104
# 2011-01-13    0.003652
# 2011-01-14    0.008067
# 2011-01-18   -0.022725
# 2011-01-19   -0.005328
# 2011-01-20   -0.018347
# 2011-01-21   -0.018078
# 2011-01-24    0.032314
# 2011-01-25    0.011637
# 2011-01-26    0.007151
# 2011-01-27   -0.001863
# 2011-01-28   -0.020934
# 2011-01-31    0.009535
# Name: abs_ret, dtype: float64

# %%
data_us['000C7F-E']['abs_ret'][:'2011-01-31'].sum()
# Out:
# 0.050654449496584701

# %%
data_us['000C7F-E']['bench'][:'2011-01-31']
# Out:
# date
# 2011-01-03   -0.003004
# 2011-01-04   -0.002710
# 2011-01-05    0.007187
# 2011-01-06    0.011470
# 2011-01-07   -0.001230
# 2011-01-10    0.010200
# 2011-01-11    0.003424
# 2011-01-12    0.012595
# 2011-01-13    0.002513
# 2011-01-14    0.016968
# 2011-01-18    0.000962
# 2011-01-19   -0.023250
# 2011-01-20   -0.018067
# 2011-01-21   -0.010640
# 2011-01-24    0.016920
# 2011-01-25   -0.003939
# 2011-01-26    0.011108
# 2011-01-27    0.015574
# 2011-01-28   -0.027610
# 2011-01-31    0.008792
# Name: bench, dtype: float64

# %%
The difference between I
