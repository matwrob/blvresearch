# %%
import os
os.chdir('c:/users/mateusz/dropbox/mateusz/python_projects')

# %%
import sql

# %%
sql.factset.fp_basic_dividends
# Out:
# -------
# COLUMNS
# -------
#            COLUMN              TYPE        NOT NULL     PRIMARY KEY
#    fs_perm_sec_id       VARCHAR(20)           False             Yes
#              date              DATE           False             Yes
#          currency        VARCHAR(3)            True
#           adjdate              DATE            True
#         p_divs_pd  DOUBLE PRECISION            True
#   p_divs_paydatec              DATE            True
#   p_divs_recdatec              DATE            True
#  p_divs_s_spinoff        VARCHAR(1)            True
#       p_divs_s_pd  DOUBLE PRECISION            True
#             dtype      VARCHAR(255)           False
# -----------
# CONSTRAINTS
# -----------
#                  TYPE               CONSTRAINT               COLUMNS
#  PrimaryKeyConstraint  fp_basic_dividends_pkey  fs_perm_sec_id ,date

# %%
sql.factset.fp_basic_splits
# Out:
# -------
# COLUMNS
# -------
#          COLUMN              TYPE        NOT NULL     PRIMARY KEY
#  fs_perm_sec_id       VARCHAR(20)           False             Yes
#            date              DATE           False             Yes
#  p_split_factor  DOUBLE PRECISION            True
#           dtype      VARCHAR(255)           False
# -----------
# CONSTRAINTS
# -----------
#                  TYPE            CONSTRAINT               COLUMNS
#  PrimaryKeyConstraint  fp_basic_splits_pkey  fs_perm_sec_id ,date
