# %%
import pandas as pd

# %%
start = pd.datetime(2014, 4, 9)

# %%
start
# Out:
# datetime.datetime(2014, 4, 9, 0, 0)

# %%
tdays = 5

# %%
start + pd.tseries.offsets.BDay(tdays)
# Out:
# datetime.datetime(2014, 4, 16, 0, 0)

# %%
start - pd.tseries.offsets.BDay(tdays)
# Out:
# datetime.datetime(2014, 4, 2, 0, 0)
