# %%
import pandas as pd

from fsprices.topcountry_model import get_many
from fsprices.universe import Universe
from memnews.core import NewsList

# %%
year_start = 2011
year_end = 2013
runi = Universe.research(year_end)

# %%
start_date = str(year_start) + "-01-01"
end_date = str(year_end) + "-12-31"

# %%
countries_eu = ['CH', 'DE', 'GB']

# %%
securities_eu  = [s for s in runi if s.country in countries_eu]
securities_us = [s for s in runi if s.country == 'US']

# %%
entities_eu = [s.factset_entity_id for s in securities_eu]
entities_us = [s.factset_entity_id for s in securities_us]

# %%
prices_eu = get_many(securities_eu, start_date, end_date)
prices_us = get_many(securities_us, start_date, end_date)
news_eu = NewsList.get_by_entity(entities_eu, start_date, end_date)
news_us = NewsList.get_by_entity(entities_us, start_date, end_date)

# %%
news_eu = news_eu.split_by_entity()

# %%
for sec, price_data in prices_eu.items():
    break

# %%
n = news_eu[sec.factset_entity_id]

# %%
n
# Out:
# NewsList with 18 news

# %%
price_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 753 entries, 2011-01-03 00:00:00 to 2013-12-30 00:00:00
# Data columns (total 5 columns):
# rel_ret    753  non-null values
# alpha      753  non-null values
# bench      753  non-null values
# beta       753  non-null values
# r2         753  non-null values
# dtypes: float64(5)

# %%
for i in n:
    break

# %%
i['story_time']
# Out:
# '2011-05-27T05:25:04.000000Z'

# %%
{i.story_time: i for i in n}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-b77b725d49d9> in <module>()
# ----> 1 {i.story_time: i for i in n}
#
# <ipython-input-18-b77b725d49d9> in <dictcomp>(.0)
# ----> 1 {i.story_time: i for i in n}
#
# AttributeError: 'dict' object has no attribute 'story_time'

# %%
price_data.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-01-03 00:00:00, ..., 2013-12-30 00:00:00]
# Length: 753, Freq: None, Timezone: None

# %%
sec.exchangeobj.add_exact_time(price_data.index)
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-01-03 16:30:00, ..., 2013-12-30 16:30:00]
# Length: 753, Freq: None, Timezone: UTC

# %%
n.align_to_date_index(sec.exchangeobj.add_exact_time(price_data.index)).dropna()
# Out:
# 2011-03-11 16:30:00+00:00    ({'body': '11. Mrz (Reuters) - 12 Monate zum 3...
# 2011-05-27 15:30:00+00:00    ({'body': 'ZURICH, May 27 (Reuters) - The foll...
# 2011-08-19 15:30:00+00:00    ({'body': 'ZURICH, Aug 18 (Reuters) - The foll...
# 2012-03-09 16:30:00+00:00    ({'body': 'March 9 (Reuters) - mobilezone ag: ...
# 2012-08-24 15:30:00+00:00    ({'body': 'ZURICH, Aug 24 (Reuters) - Swiss st...
# 2012-09-25 15:30:00+00:00    ({'body': 'ZURICH, Sept 25(Reuters) - The foll...
# 2012-10-23 15:30:00+00:00    ({'body': 'ZURICH, Oct 23 (Reuters) - The foll...
# 2013-04-11 15:30:00+00:00    ({'body': 'ZURICH, April 11 (Reuters) - The fo...
# 2013-05-27 15:30:00+00:00    ({'body': 'ZURICH, May 27 (Reuters) - The foll...
# Name: news, dtype: object
