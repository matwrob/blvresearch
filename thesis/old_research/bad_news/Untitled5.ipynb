# %%
from blvworker.managedata.factset.ftp_connection import *

# %%
ftpc = FTPconnection()

# %%
ftpc._get_connection()

# %%
ftpc.get_file_list('datafeeds/prices/fp_basic_am/')

# %%
fl_prices_am
# Out:
# ['fp_basic_am_920.zip',
#  'fp_basic_am_921.zip',
#  'fp_basic_am_922.zip',
#  'fp_basic_am_923.zip',
#  'fp_basic_am_924.zip',
#  'fp_basic_am_925.zip',
#  'fp_basic_am_926.zip',
#  'fp_basic_am_927.zip',
#  'fp_basic_am_928.zip',
#  'fp_basic_am_929.zip',
#  'fp_basic_am_930.zip',
#  'fp_basic_am_931.zip',
#  'fp_basic_am_932.zip',
#  'fp_basic_am_933.zip',
#  'fp_basic_am_934.zip',
#  'fp_basic_am_935.zip',
#  'fp_basic_am_936.zip',
#  'fp_basic_am_937.zip',
#  'fp_basic_am_938.zip',
#  'fp_basic_am_939.zip',
#  'fp_basic_am_940.zip',
#  'fp_basic_am_941.zip',
#  'fp_basic_am_full_924.zip',
#  'fp_basic_am_full_929.zip',
#  'fp_basic_am_full_934.zip',
#  'fp_basic_am_full_939.zip',
#  'fp_basic_fast_am_full_922.zip',
#  'fp_basic_fast_am_full_923.zip',
#  'fp_basic_fast_am_full_924.zip',
#  'fp_basic_fast_am_full_925.zip',
#  'fp_basic_fast_am_full_926.zip',
#  'fp_basic_fast_am_full_927.zip',
#  'fp_basic_fast_am_full_928.zip',
#  'fp_basic_fast_am_full_929.zip',
# ...
