# %%
import numpy as np

# %%
from fsprices.universe import Universe

from blvresearch.core.research_data import get_research_data_by_country
from blvresearch.core.event_study import EventDetector, EventList
from blvresearch.core.news_events import NewsEvent
from blvresearch.core.utils import mean_test

# %%
start_date = '2011-01-01'
end_date = '2011-12-31'

# %%
def criteria(sec_meta):
    if sec_meta['avg_vol'] > 1000 and sec_meta['market_cap'] > 1000000:
        return True
    return False

# %% [markdown]
# ### USA

# %%
DATA_US = get_research_data_by_country(['US'],
                                       criteria,
                                       start_date,
                                       end_date)

# %%
len(DATA_US)  # vol > 1000, mcap > 1000000
# Out:
# 1482

# %%
len(DATA_US)  # vol > 1000, mcap > 750000
# Out:
# 1696

# %%
len(DATA_US)  # vol > 500, mcap > 750000
# Out:
# 1702

# %%
len(DATA_US)  # vol > 150, mcap > 750000
# Out:
# 1705

# %%
len(DATA_US)  # vol > 150, mcap > 500000
# Out:
# 2001

# %%
len(DATA_US)  # vol > 150, mcap > 300000
# Out:
# 2335

# %% [markdown]
# ### Europe

# %%
DATA_EU = get_research_data_by_country(['CH', 'DE', 'FR', 'GB'],
                                       criteria,
                                       start_date,
                                       end_date)

# %%
len(DATA_EU)  # vol > 1000, mcap > 1000000
# Out:
# 513

# %%
len(DATA_EU)  # vol > 1000, mcap > 750000
# Out:
# 554

# %%
len(DATA_EU)  # vol > 500, mcap > 750000
# Out:
# 588

# %%
len(DATA_EU)  # vol > 150, mcap > 750000
# Out:
# 619

# %%
len(DATA_EU)  # vol > 150, mcap > 20000
# Out:
# 979

# %%
len(DATA_EU)  # vol > 150, mcap > 300000
# Out:
# 815
