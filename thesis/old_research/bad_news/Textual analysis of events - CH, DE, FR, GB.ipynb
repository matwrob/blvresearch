# %%
import os
os.chdir('c:/users/mateusz/dropbox/mateusz/python_projects')

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

from concat.core.utils import load_object

# %%
from concat.core.universe import Universe

# %%
UNI = Universe.frontend()

# %%
EUROPE = UNI.filter('zone', 'eu')

# %%
len(EUROPE)
# Out:
# 1433

# %%
from concat.core.benchmark_model import BenchmarkModelData

# %%
bmd2013 = BenchmarkModelData(EUROPE, '2013-01-01', '2013-12-31', in_currency='USD', news=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-d6985c084dbf> in <module>()
# ----> 1 bmd2013 = BenchmarkModelData(EUROPE, '2013-01-01', '2013-12-31', in_currency='USD', news=True)
#
# c:\users\mateusz\dropbox\mateusz\python_projects\concat\core\collection.py in __init__(self, universe, start, end, in_currency, news)
#     116         data = self._price_data(universe, _start, end, in_currency)
#     117         if news:
# --> 118             data = NewsAdder(data, universe, _start, end).run()
#     119         data = {k: v.ix[start:] for k, v in data.items()}
#     120         super().__init__(data)
#
# c:\users\mateusz\dropbox\mateusz\python_projects\concat\core\collection.py in run(self)
#     141         for key in self.stock_data:
#     142             self.this_key = key
# --> 143             result[key] = self._add_news_to_this_frame()
# ...

# %%
print('2013 done')

# %%
bmd2012 = BenchmarkModelData(EUROPE, '2012-01-01', '2012-12-31', in_currency='USD', news=True)
