# %%
from concat.core.benchmark_model import Peers, data
us_non_empty = {k: v for k, v in us_mnastm2.items() if len(v) > 0}
eu_non_empty = {k: v for k, v in eu_mnastm2.items() if len(v) > 0}
len(eu_non_empty)  # 958
len(us_non_empty)  # 1615
peers = Peers(2013)
peers_us = dict()
for k, v in us_non_empty.items():
    sec_id = v[0].meta_data.fs_perm_sec_id
    p, country = peers.get_for_security(v[0].meta_data)
    peers_us[k] = data.add_fillups(sec_id, p, country)
peers_eu = dict()
for k, v in eu_non_empty.items():
    sec_id = v[0].meta_data.fs_perm_sec_id
    p, country = peers.get_for_security(v[0].meta_data)
    peers_eu[k] = data.add_fillups(sec_id, p, country)
us_peer_count = {k: len(v) for k, v in peers_us.items()}
eu_peer_count = {k: len(v) for k, v in peers_eu.items()}
us_peer_count = pd.Series(us_peer_count)
eu_peer_count = pd.Series(eu_peer_count)
us_peer_count.mean()  # 59.891640866873068
eu_peer_count.mean()  # 22.777661795407099
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-1fc7f513091d> in <module>()
# ----> 1 from concat.core.benchmark_model import Peers, data
#       2 us_non_empty = {k: v for k, v in us_mnastm2.items() if len(v) > 0}
#       3 eu_non_empty = {k: v for k, v in eu_mnastm2.items() if len(v) > 0}
#       4 len(eu_non_empty)  # 958
#       5 len(us_non_empty)  # 1615
#
# ImportError: No module named 'concat'
