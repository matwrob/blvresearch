# %%
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
from fsprices.universe import Universe

from blvresearch.core.research_data import get_research_data_by_country
from blvutils.finance import to_log_returns

# %%
start_date = '2011-01-01'
end_date = '2013-12-31'

# %%
DATA = get_research_data_by_country(['PL'],
                                    start_date,
                                    end_date)

# %%
UNI = Universe.research(int(start_date[:4]))

# %%
len(DATA)  # number of entities with data
# Out:
# 38

# %%
pl_bench = DATA['003J2S-E'].bench

# %%
wig30 = pd.DataFrame.from_csv('wig30tr_d.csv')

# %%
wig30_returns = to_log_returns(wig30['Close'])
wig30_returns.index = pl_bench.index

# %%
result = pd.DataFrame({'wig30': wig30_returns, 'our_bench': pl_bench['2011-01-04':]})

# %%
result.cumsum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 747 entries, 2011-01-03 16:30:00 to 2013-12-30 16:30:00
# Data columns (total 2 columns):
# our_bench    746  non-null values
# wig30        746  non-null values
# dtypes: float64(2)

# %%
result.corr()
# Out:
#            our_bench     wig30
# our_bench   1.000000  0.802606
# wig30       0.802606  1.000000

# %%
result['2011-01-01':'2011-03-31'].plot(figsize=(20, 15))

# %%
result.cumsum().plot(figsize=(20, 15))
