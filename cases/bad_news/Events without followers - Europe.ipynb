# %%
import os
os.chdir('c:/users/mateusz/dropbox/mateusz/python_projects')

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

from concat.core.utils import load_object

# %%
UNI = load_object('uni_europe_1433_2011_2013.pickle')
UNI = UNI[2013]
DATA = load_object('data_europe_1433_2011_2013.pickle')

# %%
from blvresearch.projects.event_study.news_events import NewsEvent
from blvresearch.core.es import EventDetector, EventList

# %% [markdown]
# ##### Rewriting NewsEvent class to collect all event occurrences without checking if they were preceded

# %%
from blvresearch.core.es import Event

# %%
class NewsEvent(Event):
    DISTANCE_THRESH = 30

    @property
    def _event_day_alpha(self):
        return self.concat_data.series_after('alpha', lag=0, length=1)[0]

    @property
    def _event_day_news_amount(self):
        news_list = self.concat_data.series_after('news', lag=0, length=1)[0]
        return self._get_news_list_len(news_list)

    def _is_negative(self):
        return self._event_day_alpha < 0

    def _is_positive(self):
        return self._event_day_alpha > 0

    def _alpha_greater_than_2pct(self):
        return self._event_day_alpha > 0.02

    def _alpha_smaller_than_minus_2pct(self):
        return self._event_day_alpha < -0.02

    def _alpha_smaller_than_minus_4pct(self):
        return self._event_day_alpha < -0.04

    def _absolute_alpha_greater_than_2pct(self):
        return abs(self._event_day_alpha) > 0.02

    def _has_many_news(self):
        mean, sigma = self._get_news_length_moments()
        return self._event_day_news_amount > mean + 2 * sigma

    def _has_no_news(self):
        mean, sigma = self._get_news_length_moments()
        return self._event_day_news_amount < mean

    def _get_news_length_moments(self):
        news = self.concat_data._data['news']
        news_len = news.map(self._get_news_list_len)
        return _get_mean_and_sigma(news_len)

    def _get_news_list_len(self, news_list):
        if not isinstance(news_list, NewsList):
            return 0
        return len(news_list)

# %%
class ManyNewsAbsoluteAlphaGreaterThan2pct(NewsEvent):
    def triggers(self):
        if self._has_many_news() and self._absolute_alpha_greater_than_2pct():
            return True
        return False

# %%
detect_mnaagt2 = EventDetector(ManyNewsAbsoluteAlphaGreaterThan2pct)

# %%
from concat.core.news import NewsList
from blvworker.news.important_days import _get_mean_and_sigma

# %%
events_mnaagt2 = dict()
for entity_id, entity_data in DATA.items():
    entity_meta = UNI[entity_id]
    events_mnaagt2[entity_id] = detect_mnaagt2.run(entity_id, entity_data, entity_meta)

# %%
list_mnaagt2 = EventList.from_dict(events_mnaagt2)

# %%
list_mnaagt2
# Out:
# EventList with 4862 events

# %%
list_mnastm2 = EventList()
[list_mnastm2.append_event(e) for e in list_mnaagt2 if e.concat_data.series_after('alpha', lag=0, length=1) < 0]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
list_mnastm2
# Out:
# EventList with 2390 events

# %%
negative_by_entity = list_mnastm2.split_by_entity()

# %%
all_by_entity = list_mnaagt2.split_by_entity()

# %%
wo_followers = dict()
for entity_id, event_list in all_by_entity.items():
    if entity_id in negative_by_entity.keys():
        negative = negative_by_entity[entity_id]
        dates = [e.date for e in event_list]
        deltas = [(dates[i], (d - dates[i]).days) for i, d in enumerate(dates[1:])]
        filtered_dates = [t[0] for t in deltas if t[1] > 30]
        if event_list[len(event_list) - 1].concat_data.series_after('alpha', lag=0, length=1)[0] < 0:
            filtered_dates.append(dates[-1])
        tmp = EventList()
        [tmp.append_event(e) for e in negative if e.date in filtered_dates]
        wo_followers[entity_id] = tmp

# %%
filtered_mnastm2_wo_followers = EventList.from_dict(wo_followers)

# %%
filtered_mnastm2_wo_followers
# Out:
# EventList with 1950 events

# %%
np.mean([e.concat_data.series_after("alpha", lag=0, length=1) for e in filtered_mnastm2_wo_followers])
# Out:
# -0.057168705474038371

# %%
for e in wo_followers['000JP9-E']:
    print(e)
    print(e.concat_data.series_after('alpha', lag=0, length=1))
# Out:
# Event for "000JP9-E" on 2011-07-28
# date
# 2011-07-28   -0.195544
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2011-12-08
# date
# 2011-12-08   -0.057056
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2012-09-13
# date
# 2012-09-13   -0.044473
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2013-02-15
# date
# 2013-02-15   -0.039236
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2013-07-26
# date
# 2013-07-26   -0.021639
# Name: alpha, dtype: float64

# %%
for e in all_by_entity['000JP9-E']:
    print(e)
    print(e.concat_data.series_after('alpha', lag=0, length=1))
# Out:
# Event for "000JP9-E" on 2011-07-28
# date
# 2011-07-28   -0.195544
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2011-11-15
# date
# 2011-11-15   -0.221425
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2011-12-02
# date
# 2011-12-02   -0.030299
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2011-12-08
# date
# 2011-12-08   -0.057056
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2012-02-16
# date
# 2012-02-16    0.030121
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2012-03-28
# date
# 2012-03-28    0.037103
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2012-09-13
# date
# 2012-09-13   -0.044473
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2013-02-12
# date
# 2013-02-12   -0.079521
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2013-02-13
# date
# 2013-02-13   -0.048795
# Name: alpha, dtype: float64
# Event for "000JP9-E" on 2013-02-15
# date
# 2013-02-15   -0.039236
# Name: alpha, dtype: float64
# ...

# %%
from concat.data.blvindustry import EXCHANGES

# %%
reputable_exchanges = EXCHANGES['CH'] + EXCHANGES['DE'] + EXCHANGES['FR'] + EXCHANGES['GB']

# %%
reputable_exchanges
# Out:
# ['SWX', 'VTX', 'BRN', 'FRA', 'ETR', 'PAR', 'LON']

# %%
events_reputable_mnaagt2 = dict()
for entity_id, entity_data in DATA.items():
    entity_meta = UNI[entity_id]
    if entity_meta.exchange in reputable_exchanges:
        events_reputable_mnaagt2[entity_id] = detect_mnaagt2.run(entity_id, entity_data, entity_meta)

# %%
list_reputable_mnaagt2 = EventList.from_dict(events_reputable_mnaagt2)

# %%
list_reputable_mnaagt2
# Out:
# EventList with 3031 events

# %%
list_reputable_mnastm2 = EventList()
[list_reputable_mnastm2.append_event(e) for e in list_reputable_mnaagt2 if e.concat_data.series_after('alpha', lag=0, length=1) < 0]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
list_reputable_mnastm2
# Out:
# EventList with 1469 events

# %%
negative_reputable_by_entity = list_reputable_mnastm2.split_by_entity()
all_reputable_by_entity = list_reputable_mnaagt2.split_by_entity()

# %%
reputable_wo_followers = dict()
reputable_predecessors = dict()
for entity_id, event_list in all_reputable_by_entity.items():
    if entity_id in negative_reputable_by_entity.keys():
        negative = negative_reputable_by_entity[entity_id]
        dates = [e.date for e in event_list]
        deltas = [(dates[i], (d - dates[i]).days) for i, d in enumerate(dates[1:])]
        filtered_dates = [t[0] for t in deltas if t[1] > 30]
        if event_list[len(event_list) - 1].concat_data.series_after('alpha', lag=0, length=1)[0] < 0:
            filtered_dates.append(dates[-1])
        tmp = EventList()
        [tmp.append_event(e) for e in negative if e.date in filtered_dates]
        reputable_wo_followers[entity_id] = tmp
        pred = EventList()
        [pred.append_event(e) for e in event_list if e.date in predec]
        reputable_predecessors[entity_id] = pred

# %%
filtered_reputable_mnastm2_wo_followers = EventList.from_dict(reputable_wo_followers)

# %%
filtered_reputable_mnastm2_wo_followers
# Out:
# EventList with 1217 events

# %%
mean_test(filtered_reputable_mnastm2_wo_followers, 'alpha', 20)
# Out:
# Mean: -0.00498086327595
# p_value: 0.0727381974039

# %%
np.mean([e.concat_data.series_after("alpha", lag=0, length=1) for e in filtered_reputable_mnastm2_wo_followers])
# Out:
# -0.058871464950547507

# %% [markdown]
# ### Sample of negative events followed within the next month by another event (CH/DE/GB/FR)

# %%
list_reputable_mnaagt2
# Out:
# EventList with 3031 events

# %%
list_reputable_mnastm2
# Out:
# EventList with 1469 events

# %%
len(all_reputable_by_entity)
# Out:
# 756

# %%
len(negative_reputable_by_entity)
# Out:
# 586

# %%
negative_reputable_followed_by_another = dict()
for entity_id, event_list in all_reputable_by_entity.items():
    if entity_id in negative_reputable_by_entity.keys():
        negative = negative_reputable_by_entity[entity_id]
        dates = [e.date for e in event_list]
        deltas = [(dates[i], (d - dates[i]).days) for i, d in enumerate(dates[1:])]
        filtered_dates = [t[0] for t in deltas if t[1] < 28]
        tmp = EventList()
        [tmp.append_event(e) for e in negative if e.date in filtered_dates]
        negative_reputable_followed_by_another[entity_id] = tmp

# %%
negative_reputable_followed_by_another = {k: v for k, v in negative_reputable_followed_by_another.items() if len(v) > 0}

# %%
list_negative_reputable_followed_by_another = EventList.from_dict(negative_reputable_followed_by_another)

# %%
list_negative_reputable_followed_by_another
# Out:
# EventList with 237 events

# %%
np.mean([e.concat_data.series_after("alpha", lag=0, length=1) for e in list_negative_reputable_followed_by_another])
# Out:
# -0.11062212157644502

# %%
mean_test(list_negative_followed_by_another, 'alpha', 20)
# Out:
# Mean: -0.0288144187142
# p_value: 0.00701134500813

# %%
for e in negative_followed_by_another['001FW9-E']:
    print(e)
    print(e.concat_data.series_after('alpha', lag=0, length=1))
# Out:
# Event for "001FW9-E" on 2011-02-24
# date
# 2011-02-24   -0.050876
# Name: alpha, dtype: float64
# Event for "001FW9-E" on 2011-03-14
# date
# 2011-03-14   -0.042113
# Name: alpha, dtype: float64

# %%
for e in all_reputable_by_entity['001FW9-E']:
    print(e)
    print(e.concat_data.series_after('alpha', lag=0, length=1))
# Out:
# Event for "001FW9-E" on 2011-02-24
# date
# 2011-02-24   -0.050876
# Name: alpha, dtype: float64
# Event for "001FW9-E" on 2011-03-14
# date
# 2011-03-14   -0.042113
# Name: alpha, dtype: float64
# Event for "001FW9-E" on 2011-03-15
# date
# 2011-03-15   -0.025759
# Name: alpha, dtype: float64
# Event for "001FW9-E" on 2011-05-30
# date
# 2011-05-30   -0.022585
# Name: alpha, dtype: float64
# Event for "001FW9-E" on 2011-08-09
# date
# 2011-08-09   -0.065559
# Name: alpha, dtype: float64
# Event for "001FW9-E" on 2011-12-06
# date
# 2011-12-06   -0.059778
# Name: alpha, dtype: float64
# Event for "001FW9-E" on 2012-03-06
# date
# 2012-03-06    0.036118
# Name: alpha, dtype: float64
# Event for "001FW9-E" on 2013-03-01
# date
# 2013-03-01    0.026145
# Name: alpha, dtype: float64
# Event for "001FW9-E" on 2013-07-01
# date
# 2013-07-01   -0.054675
# Name: alpha, dtype: float64
# Event for "001FW9-E" on 2013-08-13
# date
# 2013-08-13    0.039253
# Name: alpha, dtype: float64
# ...

# %%
for e in all_reputable_by_entity['05HLDR-E']:
    print(e)
    print(e.concat_data.series_after('alpha', lag=0, length=1))
# Out:
# Event for "05HLDR-E" on 2012-08-17
# date
# 2012-08-17   -0.020517
# Name: alpha, dtype: float64
# Event for "05HLDR-E" on 2012-08-20
# date
# 2012-08-20   -0.033902
# Name: alpha, dtype: float64
# Event for "05HLDR-E" on 2012-08-21
# date
# 2012-08-21   -0.02362
# Name: alpha, dtype: float64
# Event for "05HLDR-E" on 2012-08-23
# date
# 2012-08-23    0.043745
# Name: alpha, dtype: float64
# Event for "05HLDR-E" on 2012-09-06
# date
# 2012-09-06    0.034745
# Name: alpha, dtype: float64
# Event for "05HLDR-E" on 2012-09-14
# date
# 2012-09-14   -0.036253
# Name: alpha, dtype: float64
# Event for "05HLDR-E" on 2012-09-17
# date
# 2012-09-17    0.058624
# Name: alpha, dtype: float64
# Event for "05HLDR-E" on 2013-05-14
# date
# 2013-05-14   -0.064842
# Name: alpha, dtype: float64

# %%
for e in negative_followed_by_another['05HLDR-E']:
    print(e)
    print(e.concat_data.series_after('alpha', lag=0, length=1))
# Out:
# Event for "05HLDR-E" on 2012-08-17
# date
# 2012-08-17   -0.020517
# Name: alpha, dtype: float64
# Event for "05HLDR-E" on 2012-08-20
# date
# 2012-08-20   -0.033902
# Name: alpha, dtype: float64
# Event for "05HLDR-E" on 2012-08-21
# date
# 2012-08-21   -0.02362
# Name: alpha, dtype: float64
# Event for "05HLDR-E" on 2012-09-14
# date
# 2012-09-14   -0.036253
# Name: alpha, dtype: float64
