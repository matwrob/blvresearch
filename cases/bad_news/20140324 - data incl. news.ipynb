# %%
from fsprices.universe import Universe

# %%
runi2011 = Universe.research(2011)

# %%
all_entities = [s.factset_entity_id for s in runi2011]

# %%
len(all_entities)
# Out:
# 10289

# %%
eu_countries = ['AT', 'BE', 'CH', 'DE', 'DK', 'ES', 'FI', 'FR', 'GB', 'GR', 'IE', 'IT', 'NL', 'NO', 'PL', 'RU', 'SE', 'TR', 'ZA']

# %%
eu_entities = [s.factset_entity_id for s in runi2011 if s.country in eu_countries]

# %%
us_entities = [s.factset_entity_id for s in runi2011 if s.country == 'US']

# %%
us_eu_entities = us_entities + eu_entities

# %%
from blvresearch.core.research_data import get_research_data

# %%
DATA = get_research_data(us_eu_entities, '2011-01-01', '2013-12-31')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-75ecd7c0cbba> in <module>()
# ----> 1 DATA = get_research_data(us_eu_entities, '2011-01-01', '2013-12-31')
#
# /vagrant/blvresearch/core/research_data.py in get_research_data(entity_ids, start_date, end_date)
#      10     securities = _get_securities(entity_ids, year)
#      11     prices = get_many(securities, start_date, end_date)
# ---> 12     news = NewsList.get_by_entity(entity_ids, start_date, end_date)
#      13     news = news.split_by_entity()
#      14     return _join_prices_and_news(prices, news)
#
# /vagrant/memnews/core.py in get_by_entity(cls, entities, start_date, end_date, providers)
#      38                 awp_ids = get_awp_ids(entities, start_date, end_date)
#      39                 ids.extend(globids(awp_ids, p))
# ---> 40         return cls(ids)
#      41
# ...
