# %%
import pandas as pd

from fsprices.topcountry_model import get_many
from fsprices.universe import Universe
from memnews.core import NewsList

# %%
runi = Universe.research(2013)

# %%
runi['002ZDR-E']
# Out:
# 002ZDR-E NYJLQ1-S-CH -- UBS AG

# %%
prices = get_many([runi['002ZDR-E']], '2013-01-01', '2013-12-31')

# %%
prices[runi['002ZDR-E']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 249 entries, 2013-01-03 00:00:00 to 2013-12-30 00:00:00
# Data columns (total 5 columns):
# rel_ret    249  non-null values
# alpha      249  non-null values
# bench      249  non-null values
# beta       249  non-null values
# r2         249  non-null values
# dtypes: float64(5)
