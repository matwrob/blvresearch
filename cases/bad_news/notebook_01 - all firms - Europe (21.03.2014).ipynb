# %% [markdown]
# # notebook_01: all firms - Europe (21.03.2014)

# %%
from fsprices.universe import Universe

# %%
runi_2013 = Universe.research(2013)

# %%
entities_eu = [s.factset_entity_id for s in runi_2013 if s.zone == 'eu']

# %%
entities_us = [s.factset_entity_id for s in runi_2013 if s.country == 'US']
