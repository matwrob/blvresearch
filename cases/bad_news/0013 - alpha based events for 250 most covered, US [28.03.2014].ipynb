# %%
import pandas as pd
import numpy as np

# %%
from fsprices.universe import Universe

from blvresearch.core.research_data import get_research_data_by_country
from blvresearch.core.event_study import EventDetector, EventList
from blvresearch.core.news_events import NewsEvent
from blvresearch.core.utils import mean_test

# %%
start_date = '2011-01-01'
end_date = '2013-12-31'

# %%
DATA = get_research_data_by_country(['US'],
                                    start_date,
                                    end_date)

# %%
UNI = Universe.research(int(start_date[:4]))

# %%
len(DATA)  # number of entities with data
# Out:
# 3134

# %% [markdown]
# ##### Finding most news-covered entities

# %%
from memnews.core import NewsList

# %%
def news_count_func(x):
    return len(x) if isinstance(x, NewsList) else 0

# %%
news_by_entity = dict()
for entity_id, entity_data in DATA.items():
    news = entity_data['news'].map(news_count_func)
    news_by_entity[entity_id] = news.sum()

# %%
news_by_entity = pd.Series(news_by_entity)
news_by_entity.sort()

# %%
most_covered_250 = list(news_by_entity[-250:].index)

# %% [markdown]
# ##### Event 1: alpha < miu - 2 * sigma

# %%
class AlphaSmallerThanMiuMinus2Sigmas(NewsEvent):
    def triggers(self):
        if self.alpha_is_smaller_than_miu_minus_2_sigmas:
            return True
        return False

# %%
detector1 = EventDetector(AlphaSmallerThanMiuMinus2Sigmas)

# %%
events1 = dict()
for entity_id, entity_data in DATA.items():
    if entity_id in most_covered_250:
        entity_events = detector1.run(entity_id, entity_data, UNI[entity_id])
        if len(entity_events) > 0:
            events1[entity_id] = entity_events

# %%
len(events1)  # number of entities with at least 1 event
# Out:
# 250

# %%
list1 = EventList.from_dict(events1)

# %%
list1
# Out:
# EventList with 3939 events

# %%
mean_test(list1, 'alpha', 20)
# Out:
# Mean: -0.00321122916529
# p_value: 0.0218730865683

# %%
np.mean([e.concat_data.series_after('alpha', lag=0, length=1) for e in list1])
# Out:
# -0.04978638669702138

# %% [markdown]
# ##### Event 2: alpha > miu + 2 * sigma

# %%
class AlphaGreaterThanMiuPlus2Sigmas(NewsEvent):
    def triggers(self):
        if self.alpha_is_greater_than_miu_plus_2_sigmas:
            return True
        return False

# %%
detector2 = EventDetector(AlphaGreaterThanMiuPlus2Sigmas)

# %%
events2 = dict()
for entity_id, entity_data in DATA.items():
    if entity_id in most_covered_250:
        entity_events = detector2.run(entity_id, entity_data, UNI[entity_id])
        if len(entity_events) > 0:
            events2[entity_id] = entity_events

# %%
len(events2)  # number of entities with at least 1 event
# Out:
# 250

# %%
list2 = EventList.from_dict(events2)

# %%
list2
# Out:
# EventList with 4321 events

# %%
mean_test(list2, 'alpha', 20)
# Out:
# Mean: -0.0049251511749
# p_value: 0.000207194069768

# %%
np.mean([e.concat_data.series_after('alpha', lag=0, length=1) for e in list2])
# Out:
# 0.049816271718008384
