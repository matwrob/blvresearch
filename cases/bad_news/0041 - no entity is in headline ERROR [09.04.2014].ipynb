# %%
from fsprices.universe import (
    Universe, Security, get_research_universe
)

from blvresearch.core.research_data import (
    get_research_data_by_country
)

# %%
start_date = '2011-01-01'
end_date = '2013-12-31'

# %%
def criteria(sec_meta):
    if (sec_meta['avg_vol'] > 1000 and
        sec_meta['market_cap'] > 1000000):
        return True
    return False

# %%
DATA = get_research_data_by_country(
    ['US'], criteria, start_date, end_date
)

# %%
UNI = get_research_universe(start_date[:4])
META = {v['factset_entity_id']: Security(v)
        for k, v in UNI.iterrows()}

# %%
len(DATA)  # number of entities with data
# Out:
# 1491

# %%
for entity_id, entity_data in DATA.items():
    news = entity_data['news'].dropna()
    for day, nl in news.items():
        for n in nl:
            if len(n['headline_entities']) > 0:
                print('there are headline entities')
                print(entity_id, day)
                break
    break
# Out:
# there are headline entities
# 000JND-E 2011-01-20 21:00:00+00:00
# there are headline entities
# 000JND-E 2011-01-25 21:00:00+00:00
# there are headline entities
# 000JND-E 2011-01-28 21:00:00+00:00
# there are headline entities
# 000JND-E 2011-02-02 21:00:00+00:00
# there are headline entities
# 000JND-E 2011-02-22 21:00:00+00:00
# there are headline entities
# 000JND-E 2011-03-02 21:00:00+00:00
# there are headline entities
# 000JND-E 2011-03-17 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-03-18 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-03-22 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-04-21 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-05-13 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-05-16 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-05-17 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-05-18 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-06-03 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-06-30 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-07-21 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-08-03 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-09-13 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-10-06 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-10-20 20:00:00+00:00
# there are headline entities
# 000JND-E 2011-11-15 21:00:00+00:00
# there are headline entities
# 000JND-E 2011-11-16 21:00:00+00:00
# there are headline entities
# 000JND-E 2011-11-23 21:00:00+00:00
# there are headline entities
# 000JND-E 2011-12-07 21:00:00+00:00
# there are headline entities
# 000JND-E 2011-12-14 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-01-05 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-01-17 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-01-20 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-03-05 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-03-07 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-03-08 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-03-12 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-03-14 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-03-22 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-03-29 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-04-03 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-04-10 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-04-19 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-04-20 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-04-23 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-04-24 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-04-26 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-06-04 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-06-18 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-07-03 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-07-20 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-07-24 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-08-15 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-08-22 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-08-23 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-08-24 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-09-13 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-09-18 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-10-01 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-10-02 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-10-04 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-10-18 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-10-19 20:00:00+00:00
# there are headline entities
# 000JND-E 2012-11-07 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-11-26 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-11-28 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-11-29 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-12-03 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-12-06 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-12-07 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-12-13 21:00:00+00:00
# there are headline entities
# 000JND-E 2012-12-19 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-01-04 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-01-07 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-01-09 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-01-17 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-01-18 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-01-29 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-02-11 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-02-20 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-03-19 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-04-04 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-04-10 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-04-19 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-05-03 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-05-06 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-05-08 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-05-22 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-05-28 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-06-18 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-07-10 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-07-19 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-07-24 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-07-25 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-07-29 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-09-04 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-09-09 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-09-17 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-09-24 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-09-27 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-10-18 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-10-21 20:00:00+00:00
# there are headline entities
# 000JND-E 2013-11-11 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-11-25 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-12-09 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-12-13 21:00:00+00:00
# there are headline entities
# 000JND-E 2013-12-16 21:00:00+00:00

# %%
entity_id
# Out:
# '000JND-E'

# %%
len(n['headline_entities']) > 0
# Out:
# False

# %%
for n in news['2011-01-20'][0]:
    print(n['clean_headline'])
    print(n['headline_entities'])
# Out:
# Fifth Third raises $1.7 bln to repay TARP
# []
# New Issue-Fifth Third sells $1 bln in notes
# []
# Fifth Third raises $1.7 bln to repay TARP
# []
# Fifth third announces plans to repay TARP preferred shares
# []
# Fifth Third beats estimates as delinquencies fall
# []
# Fifth Third prices $1.7 biLn stock offering
# []
# Fifth Third Bancorp Q4 results
# ['000JND-E']
# Wells, U.S. Bancorp profits up, margins squeezed
# ['001R78-E']
