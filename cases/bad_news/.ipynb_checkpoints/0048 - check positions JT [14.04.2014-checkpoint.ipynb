# %%
from blvresearch.core.std_rolling_portfolio import (
    get_sorted_returns, get_dataframe_of_returns
)

# %% [markdown]
# ### Check Holdings

# %%
jt = JegadeeshTitman(DATA,
                     type_of_return='alpha',
                     no_of_quantiles=10)

# %%
df_of_returns = get_dataframe_of_returns(RESEARCH_DATA, type_of_return='abs_ret')
df_of_returns = df_of_returns.resample('M', how=sum)

# %%
df_of_returns

# %%
df_of_returns = jt._get_initial_returns(freq='M')

# %%
sort_ret = get_sorted_returns(df_of_returns, test_per=1)

# %%
for day, series, in sort_ret.items():
    size = int(len(series) / 10)
    w = list(series[-size:].index)
    l = list(series[:size].index)
    break

# %%
series['00CGVP-E']

# %%
print(l)

# %%
print(w)

# %%
df_of_returns['2011-01-31':'2011-02-28'].stack()

# %%
result = dict()

# %%
test_per = 1

# %%
for i in range(len(df_of_returns) - test_per + 1):
    break

# %%
i

# %%
frame = df_of_returns[i:i + test_per]

# %%
series = frame.sum()

# %%
frame = pd.DataFrame([series, series * 2])

# %%
frame.sum(skipna=False)

# %%
sort_ret = get_sorted_returns(df_of_returns, test_per=1)

# %%
sort_ret
