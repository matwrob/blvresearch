# %% [markdown]
# # Basic events with news for CH/DE/FR/GB

# %% [markdown]
# ## ncount > ncount_miu + ncount_sigma

# %%
from fsprices.universe import (
    Universe, Security, get_research_universe
)

from blvresearch.core.research_data import (
    get_research_data_by_country
)
from blvresearch.core.event_study import (
    EventDetector, EventList
)
from blvresearch.core.news_events import NewsEvent
from blvresearch.core.stat_utils import (
    mean_test, print_summary_wo_outliers,
    plot_histogram, plot_histogram_wo_outliers,
    tabular_results
)

# %%
pylab.rcParams['figure.figsize'] = (16.0, 8.0)

# %%
start_date = '2011-01-01'
end_date = '2013-12-31'

# %%
def criteria(sec_meta):
    if (sec_meta['avg_vol'] > 1000 and
        sec_meta['market_cap'] > 1000000):
        return True
    return False

# %%
DATA = get_research_data_by_country(['CH', 'DE', 'FR', 'GB'],
                                    criteria,
                                    start_date,
                                    end_date)

# %%
UNI = get_research_universe(start_date[:4])
META = {v['factset_entity_id']: Security(v) for k, v in UNI.iterrows()}

# %%
len(DATA)  # number of entities with data  [29.04.2014]
# Out:
# 515

# %%
result_days = [(-20, 20),  # 20 days before the event (excluding the event day)
               (-10, 10),  # 10 days before the event (excluding the event day)
               (-5, 5),    # 5 days before the event (excluding the event day)
               (-3, 3),    # 3 days before the event (excluding the event day)
               (-1, 1),    # 1 day before the event (excluding the event day)
               (0, 1),     # EVENT DAY
               (1, 1),     # 1 day after the event (excluding the event day)
               (1, 3),     # 3 days after the event (excluding the event day)
               (1, 5),     # 5 days after the event (excluding the event day)
               (1, 10),    # 10 days after the event (excluding the event day)
               (1, 20),    # 20 days after the event (excluding the event day)
               (2, 3),     # 3 days after the event (excluding also the 1st day after the event)
               (2, 5),     # 5 days after the event (excluding also the 1st day after the event)
               (2, 10),    # 10 days after the event (excluding also the 1st day after the event)
               (2, 20)]    # 20 days after the event (excluding also the 1st day after the event)

# %% [markdown]
# ### Event 1b: ncount > ncount_miu + ncount_sigma AND alpha < alpha_miu - 2 * alpha_sigma

# %%
class Event1b(NewsEvent):
    @property
    def description(self):
        return 'nc > nc_m + nc_s AND a < a_m - 2 * a_s'
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha < a_m - 2 * a_s):
            return True
        return False

# %%
detector1b = EventDetector(Event1b)

# %%
events1b = dict()
for entity_id, entity_data in DATA.items():
    entity_events = detector1b.run(entity_id, entity_data, META[entity_id])
    if len(entity_events) > 0:
        events1b[entity_id] = entity_events

# %%
len(events1b)  # number of entities with at least 1 event [29.04.2014]
# Out:
# 423

# %%
list1b = EventList.from_dict(events1b)

# %%
list1b  # [29.04.2014]
# Out:
# EventList with 1266 events

# %% [markdown]
# ##### Results

# %%
res1b = tabular_results([list1b], 'alpha', result_days)

# %%
res1b.T  # [29.04.2014]
# Out:
#           nc > nc_m + nc_s AND a < a_m - 2 * a_s
# (-20, 20)             (-0.767, 0.00237629857407)
# (-10, 10)               (-0.391, 0.032748286318)
# (-5, 5)                (-0.261, 0.0595067032776)
# (-3, 3)                (-0.278, 0.0158285728838)
# (-1, 1)                (-0.203, 0.0221548401074)
# (0, 1)               (-6.826, 7.7325027245e-176)
# (1, 1)                (-0.228, 0.00266125881753)
# (1, 3)                 (-0.35, 0.00604596141878)
# (1, 5)                 (-0.39, 0.00908139149511)
# (1, 10)                (-0.412, 0.0255420022132)
# (1, 20)                (-0.591, 0.0202149659855)
# (2, 3)                   (-0.181, 0.11934865603)
# (2, 5)                  (-0.197, 0.135125862879)
# (2, 10)                 (-0.057, 0.747499393695)
# (2, 20)                 (-0.329, 0.188951429603)

# %% [markdown]
# ##### Histograms

# %%
plot_histogram(list1b, 'alpha', lag=-20, length=20)  # [29.04.2014]

# %% [markdown]
# ##### Summary without outliers

# %%
print_summary_wo_outliers(list1b, 'alpha',
                          lag=-20, length=20,
                          outlier_abs_threshold=0.2)  # [29.04.2014]
# Out:
# Full sample
# Size: 1266
# Mean: -0.0076708221258
# 0.00237629857407
#
# Without outliers
# Size:  1224
# Mean: -0.00398212961506
# 0.0325303745551

# %% [markdown]
# ### Event 2b: ncount > ncount_miu + ncount_sigma AND alpha > alpha_miu + 2 * alpha_sigma

# %%
class Event2b(NewsEvent):
    @property
    def description(self):
        return 'nc > nc_m + nc_s AND a > a_m + 2 * a_s'
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha > a_m + 2 * a_s):
            return True
        return False

# %%
detector2b = EventDetector(Event2b)

# %%
events2b = dict()
for entity_id, entity_data in DATA.items():
    entity_events = detector2b.run(entity_id, entity_data, META[entity_id])
    if len(entity_events) > 0:
        events2b[entity_id] = entity_events

# %%
len(events2b)  # number of entities with at least 1 event [29.04.2014]
# Out:
# 444

# %%
list2b = EventList.from_dict(events2b)

# %%
list2b  # [29.04.2014]
# Out:
# EventList with 1468 events

# %% [markdown]
# ##### Results

# %%
res2b = tabular_results([list2b], 'alpha', result_days)

# %%
res2b.T  # [29.04.2014]
# Out:
#           nc > nc_m + nc_s AND a > a_m + 2 * a_s
# (-20, 20)            (-0.959, 8.67987474759e-05)
# (-10, 10)            (-0.798, 6.38751198418e-06)
# (-5, 5)              (-0.548, 7.78500423738e-05)
# (-3, 3)              (-0.443, 0.000216050820528)
# (-1, 1)                (-0.198, 0.0178125205961)
# (0, 1)               (5.914, 2.94101810999e-313)
# (1, 1)                   (0.041, 0.500414195827)
# (1, 3)                  (-0.065, 0.466646276722)
# (1, 5)                   (-0.16, 0.130691603491)
# (1, 10)                (-0.293, 0.0469477038204)
# (1, 20)                (-0.382, 0.0707031016933)
# (2, 3)                  (-0.126, 0.107989751864)
# (2, 5)                 (-0.196, 0.0418997951243)
# (2, 10)                 (-0.336, 0.013096890088)
# (2, 20)                 (-0.37, 0.0742036557869)

# %% [markdown]
# ### Event 3b: ncount > ncount_miu + ncount_sigma AND alpha < alpha_miu - alpha_sigma

# %%
class Event3b(NewsEvent):
    @property
    def description(self):
        return 'nc > nc_m + nc_s AND a < a_m - a_s'
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha < a_m - a_s):
            return True
        return False

# %%
detector3b = EventDetector(Event3b)

# %%
events3b = dict()
for entity_id, entity_data in DATA.items():
    entity_events = detector3b.run(entity_id, entity_data, META[entity_id])
    if len(entity_events) > 0:
        events3b[entity_id] = entity_events

# %%
len(events3b)  # number of entities with at least 1 event
# Out:
# 473

# %%
list3b = EventList.from_dict(events3b)

# %%
list3b  # [29.04.2014]
# Out:
# EventList with 2640 events

# %% [markdown]
# ##### Event 3b: UBS AG

# %%
for d in events3b['002ZDR-E']:
    print(d)
# Out:
# Event for "002ZDR-E" on 2011-07-26
# Event for "002ZDR-E" on 2011-08-02
# Event for "002ZDR-E" on 2011-08-18
# Event for "002ZDR-E" on 2011-09-15
# Event for "002ZDR-E" on 2011-11-15
# Event for "002ZDR-E" on 2012-02-07
# Event for "002ZDR-E" on 2012-02-22
# Event for "002ZDR-E" on 2012-03-09
# Event for "002ZDR-E" on 2012-05-03
# Event for "002ZDR-E" on 2012-07-31
# Event for "002ZDR-E" on 2013-02-05
# Event for "002ZDR-E" on 2013-02-13
# Event for "002ZDR-E" on 2013-10-29
# Event for "002ZDR-E" on 2013-10-30
# Event for "002ZDR-E" on 2013-11-04

# %% [markdown]
# Using Event 3b framework I find 15 events for UBS AG over 3 years. This is 7 observations more compared to Event 3 study.

# %% [markdown]
# * 2011-07-26 - Q2 results
# * 2011-08-02 - Switzerland & Germany will sign tax deal
# * 2011-08-18 - Madoff trustee files lawsuit vs UBS
# * 2011-09-15 - Adoboli
# * 2011-11-15 - Ermotti named CEO
# * 2012-02-07 - predicts/warns of poor Q1 results
# * 2012-02-22 - wants to issue more loss-absorbing capital
# * 2012-03-09 - LIBOR?
# * 2012-05-03 - Axel Weber becomes chairman
# * 2012-07-31 - Q2 results
# * 2013-02-05 - Q4/full-year results
# * 2013-02-13 - ?
# * 2013-10-29 - Q3 results
# * 2013-10-30 -
# * 2013-11-04 - Swiss want stricter capital rules

# %% [markdown]
# Some days are close by.

# %%
for d in events3b['002ZDR-E']:
    print(d)
    for n in d.concat_data.series_after('news', lag=0, length=1)[0]:
        print('\t', n['clean_headline'])
# Out:
# Event for "002ZDR-E" on 2011-07-26
# 	 Jefferies, Lazard, Moelis, Threadneedle
# 	 UBS mit Q2-Gewinn von 1,0 Mrd sfr
# 	 UBS to cut costs as says to miss targets
# 	 Deutsche Bank seals succession as trading wilts
# 	 Deutsche Bank seals succession as trading wilts
# 	 UBS to cut costs, targets missed
# 	 UBS - Wealth Management Americas steht nicht zum Verkauf
# 	 Singapore's GIC says US bonds remain safe asset for now
# 	 Deutsche Bank seals succession as trading wilts
# 	 UBS says profitable US brokerage unit not for sale
# 	 UBS CEO reviewing fixed income business
# 	 Deutsche Bank seals succession as trading wilts
# 	 Deutsche Bank seals succession as trading wilts
# 	 UBS names Americas head of leveraged finance
# 	 UBS to cut costs after profits halve
# 	 Deutsche Bank's Jain sees execution as his forte
# 	 UBS reports Q2 net profit of 1.0 billion SFR
# 	 UBS Q2 investment bank pretax profit 376 mln SFR
# 	 Shares in UBS slide after Q2 figures
# 	 Deutsche Bank seals succession as trading wilts
# 	 UBS CFO sees cuts across all divisions, jobs to go
# 	 Deutsche Bank seals succession as trading wilts
# 	 UBS-Kosteneinsparungen werden auch Arbeitsplätze einschliessen
# 	 Shares in UBS indicated down 3 pct after Q2 figures
# 	 UBS says wealth management americas not for sale
# 	 Deutsche Bank's Jain sees execution as his forte
# 	 Singapore GIC's portfolio at a glance
# 	 Deutsche Bank's Jain sees execution as his forte
# 	 Jefferies, Lazard, Moelis, Deutsche Bank, Ernst & Young
# 	 UBS to cut costs, targets missed
# 	 Jefferies, Lazard, Moelis, Threadneedle
# 	 UBS to cut costs and rethink fixed income unit
# 	 UBS-Aktie drei Prozent tiefer indiziert
# 	 Deutsche Bank klärt Führungsfrage - Duo folgt Ackermann
# 	 Lazard hires ex-UBS financial services banker Howe
# 	 Singapore wealth fund GIC turns to China, Brazil, Korea
# 	 Deutsche Bank seals succession as trading wilts
# 	 Trading malaise at investment banks set to linger
# 	 Singapore wealth fund GIC turns to China, Brazil, Korea
# 	 UBS says granted some immunity in LIBOR probe
# 	 Singapore's GIC says its long-term view on Citi, UBS unchanged-paper
# 	 UBS schwenkt nach Gewinneinbruch auf Sparkurs ein
# 	 UBS to cut costs and rethink fixed income unit
# 	 Deutsche Bank seals succession as trading wilts
# 	 Singapore's GIC cuts exposure to West over debt worries
# 	 Morning News Call - EMEA, July 26
# 	 Deutsche Bank verdient im Quartal etwas weniger als erwartet
# 	 Singapore's GIC says its long-term view on Citi, UBS unchanged-paper
# 	 UBS schwenkt nach Gewinneinbruch auf Sparkurs ein
# Event for "002ZDR-E" on 2011-08-02
# 	 Global banks squeezed in Australia as bond volumes drop
# 	 UBS hires BofA banker as global equities co-head
# 	 Polls find investors rattled by U.S. debt issue
# 	 UBS hires BofA banker as global equities co-head
# 	 RBC Wealth Management, Gamma Finance, Schroders
# 	 Macquarie Group, RBC Wealth Management, Schroders
# 	 HSBC will fast die Hälfte des US-Geschäfts verkaufen
# 	 Barclays to cut 3,000 jobs as profit sags
# 	 Merrill hires 7 advisers with $813 mln in assets
# 	 IL&FS unit picks banks for first India yuan bond-sources
# 	 HSBC will fast die Hälfte des US-Geschäfts verkaufen
# 	 REPEAT-FirstPoint aims to guide advisers to independence
# 	 Barclays to cut 3,000 jobs as profit drops
# 	 ASIA PRIVATE EQUITY WEEKLY NEWS, AUGUST 1, 2011
# 	 Magazin - Bald Abkommen im Schwarzgeld-Streit mit der Schweiz
# 	 Swiss, Germans to sign tax deal on Aug. 10 - media
# 	 JPMorgan, UBS urge Madoff trustee claims be tossed
# 	 Polls find investors rattled by U.S. debt issue
# 	 Einigung auf Steuerabkommen mit Schweiz wohl noch im August
# 	 Citi, Threadneedle, HSBC, UBS AG
# 	 RBC Wealth Management, Gamma Finance, Raiffeisen Investment
# 	 Barclays to cut 3,000 jobs as profit drops
# 	 Barclays to cut 3,000 jobs as profit drops
# 	 India's IL&FS unit picks 3 banks for renminbi bonds-sources
# 	 Swiss, Germans to sign tax deal on Aug. 10 - media
# 	 NEW ISSUE-India's IL&FS unit mandates 3 banks for renminbi bonds-sources
# 	 UBS reviews New York moving plans as cost cuts bite
# 	 Studie- Risikolust am Zertifikatemarkt im Juli gesunken
# 	 Swiss, Germans to sign tax deal on Aug. 10-media
# 	 Swiss, Germans to sign tax deal on Aug. 10-paper
# 	 Credit Suisse, Merrill Lynch, RBC Wealth Management
# Event for "002ZDR-E" on 2011-08-18
# 	 Madoff trustee adds claims in $2 bln UBS lawsuit
# 	 Madoff trustee files amended lawsuit vs UBS
# 	 Swiss govt to ease franc pain with 2 bln Sfr package
# 	 Manchester United applies for Singapore IPO -source
# 	 Madoff trustee adds claims in $2 bln UBS lawsuit
# 	 Madoff trustee adds claims in $2 bln UBS lawsuit
# 	 Madoff trustee adds claims in $2 bln UBS lawsuit
# 	 Life after Wall Street: Ex-bankers answer the call
# 	 US units of European banks under NY Fed scrutiny-report
# 	 Swiss govt to ease franc pain with 2 bln Sfr package
# 	 Absolute return funds: no sure refuge
# 	 IPO VIEW-Market turmoil puts damper on IPOs
# 	 Absolute return funds: no sure refuge
# 	 Credit Suisse reorganises private banking-memo
# 	 Absolute return funds: no sure refuge
# 	 Absolute return funds: no sure refuge
# 	 Sage in exclusive talks for Australia's MYOB -sources
# 	 Asahi buys NZ firm for $1.3 bln in pre-mixed drinks push
# 	 Asahi buys NZ firm for $1.3 bln in pre-mixed drinks push
# Event for "002ZDR-E" on 2011-09-15
# 	 UBS rogue trader held in London after $2 bln loss
# 	 London police arrest Adoboli in UBS case - sources
# 	 Oil up near $113, mkt awaits U.S. data
# 	 Former Deutsche Bank Islamic finance head joins UBS
# 	 Oil up over $114, equity rally supports
# 	 UBS says $2 bln rogue trade suspect held in London
# 	 UBS - Handelsverlust beeinträchtigt nicht unsere fundamentale Stärke
# 	 UBS loss rallies support for tougher Swiss rules
# 	 Oil up over $115 boosted by central bank action
# 	 Festnahme in London im Zusammenhang mit UBS-Handelsaffäre
# 	 UBS $2 bln rogue trade suspect held in London
# 	 TSX may open higher on support for Greece
# 	 Oil up over $115, equity rally supports
# 	 UBS rogue loss hammers risk efforts, new risk boss
# 	 EIL-Händler beschert UBS Handelsverlust von 2 Milliarden Dollar
# 	 UBS trader was a good tenant but not tidy
# 	 London police arrest man on suspicion of fraud
# 	 UBS says $2 bln rogue trader arrested in London
# 	 UBS strong despite rogue trader case-internal memo
# 	 UBS $2 bln rogue trade suspect held in London
# 	 UBS says $2 bln rogue trader arrested in London
# 	 UBS rogue trader loses $2 bln
# 	 UBS press release on unauthorised trading
# 	 UBS says $2 bln rogue trade suspect held in London
# 	 Schweizer Aufsichtsbehörde steht in Kontakt mit UBS
# 	 UBS shares tumble after says could post Q3 loss
# 	 FINMA in contact with UBS in rogue trader case
# 	 Goldman team forms San Francisco wealth boutique
# 	 UBS hit by $2 bln rogue trader loss
# 	 UBS - Ein Mitarbeiter in London nach Handelsverlust festgenommen
# 	 UBS investment bank mishaps and upheavals
# Event for "002ZDR-E" on 2011-11-15
# 	 Weber begrüßt Ernennung von Ermotti zum CEO der UBS
# 	 Financial Times - Nov 15
# 	 UniCredit ditches Europe equities for alliance
# 	 UBS names Ermotti CEO to steady bank after scandal
# 	 UBS names Ermotti CEO to steady bank after scandal
# 	 Citigroup, UBS, Morgan Stanley
# 	 UBS board names Ermotti permanent CEO
# 	 Sergio Ermotti wird definitiv UBS-Konzernchef
# 	 UBS does not plan to disclose more job cuts-source
# 	 Weber welcomes Ermotti's appointment as UBS CEO
# 	 Weber backs appointment of Ermotti as CEO-Villiger
# 	 Funds Industry News-Nov 15
# 	 UBS-Aktien nach Ernennung von permanentem CEO schwächer
# 	 UBS shares down 1 pct after names Ermotti CEO
# 	 UBS-CEO stellt sich hinter Chef der Investmentbank-Sparte
# 	 MOVE: Raymond James hires former UBS advisers
# 	 UBS, Citigroup, Morgan Stanley
# 	 Insider - Am UBS-Investorentag kommt kein weiterer Stellenabbau
# 	 UBS does not plan to disclose more job cuts-source
# 	 UBS names Ermotti CEO to reassure investors
# 	 UBS names Ermotti CEO to steady bank after scandal
# 	 Ermotti to present targets at UBS investor event
# Event for "002ZDR-E" on 2012-02-07
# 	 UBS says conomic outlook concerns may weigh on Q1
# 	 Swiss stocks - Factors to watch on Feb 7
# 	 UBS - Bonus-Pool um 40 Prozent reduziert
# 	 UBS warns of poor Q1 after investment bank loss
# 	 UBS - IB-Chef Kengeter verzichtet auf Bonus 2011
# 	 UBS warns of poor Q1 as investment bank struggles
# 	 Anleger reduzieren Risikopuffer bei Dax-Discountern
# 	 UBS says rogue trader not material for inflows
# 	 Private bank inflows key focus in UBS Q4
# 	 UBS loses case to recoup bonus from ex-broker
# 	 Wall St to open lower with Greece in focus
# 	 UBS loses case to recoup bonus from ex-broker
# 	 UBS says unit head Kengeter will forgo 2011 bonus
# 	 UBS-Aktie setzt zwei Prozent tiefer ein
# 	 UBS hires advisers from Merrill, Morgan Stanley
# 	 Swiss stocks - Factors to watch on Feb 7
# 	 Euro-Schuldenkrise nagt am Gewinn der Großbank UBS
# 	 UBS - Handels-Verlust hat kaum Einfluss auf Nettoneugeld
# 	 UBS warns of poor Q1 as investment bank struggles
# 	 Wall St edges higher as Greece draws up bailout terms
# 	 UBS says bonus pool reduced by 40 pct in 2011
# 	 UBS warns of poor Q1 as investment bank struggles
# 	 UBS loses case to recoup bonus from ex-broker
# 	 Futures fall with eyes on Greece talks
# 	 UBS hires advisers from Merrill, Morgan Stanley
# 	 Wall St edges lower as Greece deal advances
# 	 Jefferies must consolidate rapid expansion: Mullin
# 	 UBS shares fall after warns of tough first quarter
# 	 UBS predicts poor Q1 over eurozone woes
# Event for "002ZDR-E" on 2012-02-22
# 	 Swiss demand banks help clean up tax-haven image
# 	 Merrill raises bid for rivals' top brokers-sources
# 	 Citi, UBS provide keys to widening interest rate-rigging probe - sources
# 	 UBS to issue more loss-absorbing capital
# 	 Citi, UBS provide keys to widening interest rate-rigging probe - sources
# 	 Schweizer Regierung legt Pläne für Weißgeldstrategie vor
# 	 MOVE: UBS broker goes independent, joins Dynasty
# 	 UBS platziert Eigenkapital-Anleihe
# 	 Swiss take steps to clean up tax-haven image
# 	 NewRiver Retail, Lazard, Huron
# 	 Swiss stocks - Factors to watch on Feb 22
# 	 Swiss demand banks help clean up tax-haven image
# 	 Swiss stocks - Factors to watch on Feb 22
# 	 Swiss stocks - Factors to watch on Feb 22
# 	 Russia's MICEX-RTS stockmarket picks IPO banks-IFR
# 	 UBS to issue more loss-absorbing capital
# 	 UBS plans to issue more loss-absorbing capital
# 	 UBS platziert Eigenkapital-Anleihe
# 	 Swiss stocks - Factors to watch on Feb 22
# 	 UBS says plans more loss-absorbing capital issues
# 	 UBS flags issuance of more loss-absorbing capital
# 	 Merrill raises bid for rivals' top brokers-sources
# 	 IFR-VTB Capital's hiring spree signals global intent
# 	 UBS plant Emission von weiteren Eigenkapital-Anleihen
# Event for "002ZDR-E" on 2012-03-09
# 	 CVC hires UBS to sell Australia hotel group - source
# 	 Barclays says may face action in Libor probe
# 	 China Comm Construction jumps in Shanghai debut
# 	 China Comm Construction jumps on Shanghai debut
# 	 CVC hires UBS to sell Australia hotel group - source
# 	 BofA, HSBC, Zurich Financial
# 	 Ziggo IPO to raise up to 745 mln euros
# 	 BofA names Koder Asia-Pacific president, memo says
# 	 Libor's survival hinges on its ubiquity
# 	 Financial Times - March 9
# 	 MOVE: UBS hires from Merrill Lynch, RBC Wealth
# 	 Barclays may settle action over Libor probe
# 	 BofA names Koder Asia-Pacific president - source
# 	 Ziggo owners to raise up to $989 mln from IPO
# 	 BofA bumps up Koder to Asia-Pacific president
# 	 Blackstone tops hedge fund investor list
# 	 BofA-Merrill Lynch, Zurich Financial, IIFL
# Event for "002ZDR-E" on 2012-05-03
#  UBS says positioned to adapt to bank secrecy shift
# 	 RBC unit to cover $3 mln of investor ETF losses
# 	 BofA exodus continues as top MENA banker resigns
# 	 Australia's Packer to sell Foxtel pay TV stake, eyes Echo
# 	 UBS-Aktionäre kritisieren hohe Manager-Löhne
# 	 Schweizer Immobilienmarkt heizt sich weiter auf
# 	 Fitch says no rating impact on UBS AG from Q1 results
# 	 UBS to sell Packer's stake in Foxtel holding company
# 	 UBS gets stinging rebuke from shareholders on pay
# 	 UBS-Aktionäre heissen Vergütungsbericht gut
# 	 UBS-Aktionäre wählen Axel Weber zum neuen Präsidenten
# 	 Deutsche Bank raises UBS to hold
# 	 ETF controversy puts online brokers in odd spot
# 	 Osborne slams EU bank talks, fears "idiot" deal
# 	 US-Regulierer straft weiteren ETF-Händler ab
# 	 BofA's top MENA banker El-Amir resigns - source
# 	 Morgan Stanley hires brokers from UBS, Wells Fargo
# 	 UBS faces pay backlash as Weber becomes chairman
# 	 UBS-Präsident plädiert für Steuerabkommen mit Deutschland
# 	 RBC unit to cover nearly $3 mln of investor ETF losses
# 	 Aviva investors rebel over executive pay
# 	 UBS 98.8 percent shareholders vote weber to board
# 	 UBS SHAREHOLDERS VOTE AXEL WEBER TO BOARD
# 	 Spain sounding out investment banks on crisis options
# 	 UBS faces pay backlash as Weber becomes chairman
# 	 UBS shareholders back compensation report
# Event for "002ZDR-E" on 2012-07-31
# 	 Swiss regulator quizzes Credit Suisse, UBS on Libor
# 	 UBS profit shrivels on investment bank woes
# 	 Swiss stocks - Factors to watch on July 31
# 	 Warburg Pincus, Cinven to sell more Ziggo shares
# 	 UBS confident in net new money despite challenges
# 	 UBS shares indicated down 5 pct after Q2 results
# 	 UBS - Haben angemessene Rückstellungen für alle Problembereiche
# 	 UBS Q2 profit shrivels as trading revenue drops; outlook cautious
# 	 Swiss stocks - Factors to watch on July 31
# 	 Facebook fiasco drags UBS profit lower
# 	 Recession, Libor, Facebook pummel Europe's banks
# 	 Ex-UBS bankers cheated cities by rigging bond bids -U.S.
# 	 UBS shares open down 4 percent after Q2 results
# 	 Credit Suisse senkt Rating-Ausblick für UBS auf "negativ"
# 	 Swiss regulator quizzes Credit Suisse, UBS on Libor
# 	 UBS says fees, gains boost U.S. brokerage profit 28 percent
# 	 Facebook und Schuldenkrise lassen UBS-Gewinn einbrechen
# 	 UBS CEO says appropriately provisioned for Libor
# 	 Swiss stocks - Factors to watch
# 	 UBS Q2 profit shrivels amid trading slump and Facebook loss
# 	 UBS-Aktie verliert zu Beginn 3,3 Prozent
# 	 Swiss stocks - Factors to watch on July 31
# 	 Facebook fiasco drags UBS profit lower
# 	 UBS Q2 profit shrivels as trading revenue drops; outlook cautious
# 	 Deutsche Bank investment bank profit plunges 63 pct
# 	 Ex-UBS clients get year in prison in offshore tax dodge case
# 	 Ex-UBS bankers cheated cities by rigging bond bids -U.S.
# 	 Ex-UBS bankers cheated cities by rigging bond bids -U.S.
# 	 Schweizer Aufsicht holt bei Großbanken Libor-Informationen ein
# 	 Schuldenkrise und Facebook-Börsengang verhageln UBS den Gewinn
# Event for "002ZDR-E" on 2013-02-05
# 	 UBS seen cutting risky assets as charges push it to loss
# 	 Swiss stocks - Factors to watch on Feb 5
# 	 UBS overhaul bearing fruit despite hefty quarterly loss
# 	 UBS to buy back 5 bln Sfr in senior debt after revamp
# 	 UBS shares down 3.7 percent after results
# 	 SNB's Zurbruegg says cycle to turn, no negative rates
# 	 AIG, UBS, Citi, Mediobanca, Ameriprise, Alvarez & Marsal
# 	 Konzernumbau und Libor-Skandal brocken UBS Milliardenverlust ein
# 	 UBS schreibt nach Skandalen Milliardenverlust
# 	 Swiss stocks - Factors to watch on Feb 5
# 	 SNB's Zurbruegg sees rates rising eventually, no negative rates
# 	 UBS-Aktie dreht ins Plus - steigt 1,3 Prozent auf 15,82 Franken
# 	 UBS bond buyback could prompt Q1 own credit charge
# 	 Multipolar, Matahari continue rally on acquisition deal
# 	 UBS swings to Q4, full-year net loss after Libor fine, revamp
# 	 Wells brokerage unit expanding to attract new breed of adviser
# 	 UBS will mit Anleihenrückkauf Zinsaufwand senken
# 	 UBS shares turn positive after initial fall
# 	 UBS-Aktie sinkt nach Jahresabschluss um 3,7 Prozent auf 15,05 Franken
# 	 Swiss stocks - Factors to watch on Feb 5
# 	 UBS private bank inflows weak as reports big loss
# Event for "002ZDR-E" on 2013-02-13
# 	 Swiss government bids to cool housing bubble
# 	 Swiss stocks - Factors to watch on Feb 13
# 	 UBS, SocGen, BlackRock, Legg Mason, MetLife
# 	 SocGen reshuffles exec team after Q4 loss
# 	 SocGen seen swinging to Q4 loss, naming new CFO
# 	 Swiss banks need extra 3 bln Sfr capital to meet mortgage rules
# 	 UBS, SocGen, BlackRock, Legg Mason, MetLife
# 	 Auction rate arbitration against UBS may proceed -judge
# 	 UBS, SocGen, BlackRock, Legg Mason, WellPoint
# 	 UBS executive Kengeter to exit bank -internal memo
# 	 Früherer Chef von UBS-Investmentbank verlässt Konzern
# 	 New York Times business news - Feb 13
# 	 UBS financial services co-head De Vitry to leave -sources
# 	 Swiss stocks - Factors to watch on Feb 13
# 	 Barclays vows fresh course, axes 3,700 jobs
# 	 UBS financial services co-head De Vitry to leave-sources
# 	 Financial Times - Feb 13
# 	 Kreise - Santander im Visier der britischen Finanzaufsicht
# 	 Swiss government seeks to cool housing bubble
# 	 SocGen reshuffles exec team after quarterly loss
# 	 Schweizer Regierung verordnet Banken höhere Kapitalpuffer
# 	 UBS former investment bank CEO Kengeter to leave
# 	 Wall Street Journal - Feb 13
# Event for "002ZDR-E" on 2013-10-29
# 	 European banks pay heavy price for scandals
# 	 UBS nimmt Devisengeschäft unter die Lupe
# 	 Energy stocks fuel European shares after results beats
# 	 UBS defers key return target on extra capital demands
# 	 Energy stocks shore up European shares after results beats
# 	 UBS-Aktie  startet nach Quartalsbericht deutlich schwächer
# 	 UBS: reviewing FX for potential irregularities
# 	 Huishang Bank seeks $1.3 bln in HK's biggest bank IPO since 2010
# 	 Swiss stocks - Factors to watch on Oct 29
# 	 Huishang Bank launches $1.3 bln HK IPO, adds cornerstone investor
# 	 UBS says took swift action over ongoing forex probe
# 	 Switzerland - Corporate events From Oct 28, 2013
# 	 ING: Goldman Sachs raises target price
# 	 UBS defers key return target on extra capital demands
# 	 Swiss stocks - Factors to watch on Oct 29
# 	 UBS indicated down 2.5 pct after Q3, FINMA top-up
# 	 UBS falls 5.6 pct after Q3 results, Finma top-up
# 	 Handelsflaute bremst Schweizer Großbank UBS
# 	 UBS-Aktie nach Quartalsbericht vorbörslich drei Prozent schwächer
# 	 JPMorgan, Bank of America, State Street, Cantor Fitzgerald
# 	 Swiss stocks - Factors to watch on Oct 29
# 	 Lower client activity weighs on UBS Americas wealth business
# 	 Investment banking slowdown to hit European lenders
# 	 Swiss stocks - Factors to watch on Oct 29
# Event for "002ZDR-E" on 2013-10-30
# 	 StanChart puts senior FX trader in London on leave -source
# 	 UBS: S&P Capital IQ cuts to hold
# 	 UBS, Deutsche Bank confirm cooperation in forex probes
# 	 UBS: Citigroup cuts target price
# 	 U.S. SEC judge throws out complaint against UBS Puerto Rico execs
# 	 UBS: BofA Merrill cuts to neutral - Theflyonthewall.com
# 	 UBS: Helvea Baader Bank cuts target price
# 	 Ally settles U.S. regulators' mortgage securities claims
# 	 UBS: Exane BNP Paribas cuts target price
# 	 Switzerland - Corporate events to Nov 29, 2013
# 	 British Business - Oct 30
# 	 German prosecutors say too early to settle UBS tax probe
# 	 Steuer-Ermittlungen im Fall UBS nicht vor dem Ende
# 	 U.S. confirms criminal probe of forex manipulation
# 	 Energy stocks power European shares after results beats
# 	 UBS: Deutsche Bank cuts price target
# 	 Schwaches Investmentbanking drückt Barclays-Gewinn
# 	 RBS reviews FX practices, Barclays flags probe
# Event for "002ZDR-E" on 2013-11-04
# 	 UBS, Credit Suisse hit by threat of stricter capital rules
# 	 Swiss Finance Minister wants banks to boost leverage ratios - paper
# 	 Swiss stocks - Factors to watch on Nov 4
# 	 UBS, Credit Suisse hit by stricter capital rules threat
# 	 UBS hires seven advisers from BofA Merrill Lynch
# 	 Blessing lehnt Übernahme der Commerzbank nicht grundsätzlich ab
# 	 UBS and Credit Suisse shares fall as stricter capital rules loom
# 	 Swiss stocks - Factors to watch on Nov 4
# 	 UBS, Credit Swiss hit by threat of stricter capital rules
# 	 Schweiz erwägt deutlich höhere Kapitalpuffer für Banken
# 	 Swiss stocks - Factors to watch on Nov 4
# 	 Schweiz - Härtere Eigenkapitalregeln nicht konkret geplant
# 	 UBS, Credit Suisse hit by threat of stricter capital rules
# 	 Schweiz erwägt deutlich höhere Kapitalpuffer für Banken
# 	 Carlyle Group, UBS, Macquarie, RBS, Foros
# 	 UBS, Goldman Sachs, RBS, Bluebay Asset Management
# 	 Schweiz - Ruf nach mehr Eigenkapital belastet Bank-Aktien
# 	 Switzerland - Corporate events from Nov 04, 2013

# %% [markdown]
# ##### Results

# %%
res3b = tabular_results([list3b], 'alpha', result_days)

# %%
res3b.T  # [29.04.2014]
# Out:
#           nc > nc_m + nc_s AND a < a_m - a_s
# (-20, 20)         (-0.582, 0.00038068311649)
# (-10, 10)          (-0.253, 0.0327875402667)
# (-5, 5)            (-0.155, 0.0996138270483)
# (-3, 3)            (-0.177, 0.0250972187722)
# (-1, 1)            (-0.129, 0.0303197764752)
# (0, 1)          (-4.397, 3.29113456132e-277)
# (1, 1)            (-0.145, 0.00151630681079)
# (1, 3)            (-0.215, 0.00440404194395)
# (1, 5)            (-0.269, 0.00282529455791)
# (1, 10)            (-0.281, 0.0133932247823)
# (1, 20)           (-0.512, 0.00128848175309)
# (2, 3)             (-0.115, 0.0991287365171)
# (2, 5)              (-0.16, 0.0505310113727)
# (2, 10)             (-0.098, 0.371119769216)
# (2, 20)            (-0.319, 0.0406894053256)

# %% [markdown]
# ### Event 4b: ncount > ncount_miu + ncount_sigma AND alpha > alpha_miu + alpha_sigma

# %%
class Event4b(NewsEvent):
    @property
    def description(self):
        return 'nc > nc_m + nc_s AND a > a_m + a_s'
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha > a_m + a_s):
            return True
        return False

# %%
detector4b = EventDetector(Event4b)

# %%
events4b = dict()
for entity_id, entity_data in DATA.items():
    entity_events = detector4b.run(entity_id, entity_data, META[entity_id])
    if len(entity_events) > 0:
        events4b[entity_id] = entity_events

# %%
len(events4b)  # number of entities with at least 1 event [29.04.2014]
# Out:
# 491

# %%
list4b = EventList.from_dict(events4b)

# %%
list4b  # [29.04.2014]
# Out:
# EventList with 2903 events

# %% [markdown]
# ##### Results

# %%
res4b = tabular_results([list4b], 'alpha', result_days)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-84303d75ea17> in <module>()
# ----> 1 res4b = tabular_results([list10], 'alpha', result_days)
#
# NameError: name 'list10' is not defined
