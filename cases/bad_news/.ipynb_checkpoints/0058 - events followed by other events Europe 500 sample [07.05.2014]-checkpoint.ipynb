# %%
from fsprices.universe import (
    Universe, Security, get_research_universe
)

from blvresearch.core.research_data import (
    get_research_data_by_country
)
from blvresearch.core.event_study import (
    EventDetector, EventList, CloseEvents
)
from blvresearch.core.news_events import NewsEvent
from blvresearch.core.stat_utils import (
    mean_test, print_summary_wo_outliers,
    plot_histogram, plot_histogram_wo_outliers,
    tabular_results
)

# %%
pylab.rcParams['figure.figsize'] = (16.0, 8.0)

# %%
start_date = '2011-01-01'
end_date = '2013-12-31'

# %%
def criteria(sec_meta):
    if (sec_meta['avg_vol'] > 1000 and
        sec_meta['market_cap'] > 1000000):
        return True
    return False

# %%
DATA = get_research_data_by_country(
    ['CH', 'DE', 'FR', 'GB'], criteria, start_date, end_date
)

# %%
UNI = get_research_universe(start_date[:4])
META = {v['factset_entity_id']: Security(v)
        for k, v in UNI.iterrows()}

# %%
len(DATA)  # number of entities with data [07.05.2014]
# Out:
# 515

# %%
result_days = [(-20, 20),  # 20 days before the event (excluding the event day)
               (-10, 10),  # 10 days before the event (excluding the event day)
               (-5, 5),    # 5 days before the event (excluding the event day)
               (-3, 3),    # 3 days before the event (excluding the event day)
               (-1, 1),    # 1 day before the event (excluding the event day)
               (0, 1),     # EVENT DAY
               (1, 1),     # 1 day after the event (excluding the event day)
               (1, 3),     # 3 days after the event (excluding the event day)
               (1, 5),     # 5 days after the event (excluding the event day)
               (1, 10),    # 10 days after the event (excluding the event day)
               (1, 20),    # 20 days after the event (excluding the event day)
               (2, 3),     # 3 days after the event (excluding also the 1st day after the event)
               (2, 5),     # 5 days after the event (excluding also the 1st day after the event)
               (2, 10),    # 10 days after the event (excluding also the 1st day after the event)
               (2, 20)]    # 20 days after the event (excluding also the 1st day after the event)

# %% [markdown]
# ### Event 1c: ncount > ncount_miu + ncount_sigma AND alpha < alpha_miu - alpha_sigma

# %% [markdown]
# ### Followed by: ncount > ncount_miu + ncount_sigma AND abs(alpha) > alpha_miu + alpha_sigma

# %%
class AbsFollower(NewsEvent):
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            abs(self.event_day_alpha) > a_m + a_s):
            return True
        return False

# %%
class Event1c(NewsEvent):
    @property
    def description(self):
        return 'nc > nc_m + nc_s AND a < a_m - a_s FOLLOWED by AbsFollower'
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']        
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha < a_m - a_s):
            ce = CloseEvents(self)
            close_events = ce.find_after(AbsFollower, 20)
            if len(close_events) > 0:
                return True
            return False

# %%
detector1c = EventDetector(Event1c)

# %%
events1c = dict()
for entity_id, entity_data in DATA.items():
    entity_events = detector1c.run(entity_id, entity_data, META[entity_id])
    if len(entity_events) > 0:
        events1c[entity_id] = entity_events

# %%
len(events1c)  # number of entities with at least 1 event [07.05.2014]
# Out:
# 272

# %%
list1c = EventList.from_dict(events1c)

# %%
list1c  # [07.05.2014]
# Out:
# EventList with 856 events

# %% [markdown]
# ##### Results

# %%
res1c = tabular_results([list1c], 'alpha', result_days)

# %%
res1c.T  # [07.05.2014]
# Out:
#           nc > nc_m + nc_s AND a < a_m - a_s FOLLOWED by AbsFollower
# (-20, 20)                         (-1.607, 4.8168005274e-07)
# (-10, 10)                        (-0.791, 0.000364786357303)
# (-5, 5)                            (-0.318, 0.0835704701701)
# (-3, 3)                            (-0.362, 0.0134602535998)
# (-1, 1)                            (-0.191, 0.0930896067836)
# (0, 1)                           (-4.569, 2.16380009478e-62)
# (1, 1)                             (-0.208, 0.0450347009412)
# (1, 3)                               (-0.27, 0.126215410751)
# (1, 5)                              (-0.218, 0.279436783801)
# (1, 10)                            (-0.491, 0.0415196114472)
# (1, 20)                          (-1.382, 8.34586704948e-05)
# (2, 3)                              (-0.083, 0.590609595195)
# (2, 5)                              (-0.101, 0.563144022402)
# (2, 10)                             (-0.295, 0.177434222989)
# (2, 20)                          (-1.202, 0.000320075989823)

# %% [markdown]
# ### Event2c: ncount > ncount_miu + ncount_sigma AND alpha < alpha_miu - alpha_sigma

# %% [markdown]
# ### Followed by: ncount > ncount_miu + ncount_sigma AND alpha < alpha_miu - alpha_sigma

# %%
class NegFollower(NewsEvent):
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha < a_m - a_s):
            return True
        return False

# %%
class Event2c(NewsEvent):
    @property
    def description(self):
        return 'nc > nc_m + nc_s AND a < a_m - a_s FOLLOWED by NegFollower'
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']        
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha < a_m - a_s):
            ce = CloseEvents(self)
            close_events = ce.find_after(NegFollower, 20)
            if len(close_events) > 0:
                return True
            return False

# %%
detector2c = EventDetector(Event2c)

# %%
events2c = dict()
for entity_id, entity_data in DATA.items():
    entity_events = detector2c.run(entity_id, entity_data, META[entity_id])
    if len(entity_events) > 0:
        events2c[entity_id] = entity_events

# %%
len(events2c)  # number of entities with at least 1 event [07.05.2014]
# Out:
# 207

# %%
list2c = EventList.from_dict(events2c)

# %%
list2c  # [07.05.2014]
# Out:
# EventList with 545 events

# %% [markdown]
# ##### Results

# %%
res2c = tabular_results([list2c], 'alpha', result_days)

# %%
res2c.T  # [07.05.2014]
# Out:
#           nc > nc_m + nc_s AND a < a_m - a_s FOLLOWED by NegFollower
# (-20, 20)                        (-1.614, 4.18109477504e-05)
# (-10, 10)                        (-0.992, 0.000223762546505)
# (-5, 5)                            (-0.417, 0.0404162466791)
# (-3, 3)                           (-0.538, 0.00121981946222)
# (-1, 1)                           (-0.394, 0.00120691219186)
# (0, 1)                           (-4.274, 8.36148287948e-61)
# (1, 1)                           (-0.804, 6.49477512478e-12)
# (1, 3)                           (-1.239, 1.90266457025e-11)
# (1, 5)                           (-1.317, 2.03429971427e-09)
# (1, 10)                          (-2.123, 7.00768934342e-14)
# (1, 20)                          (-3.833, 2.95699912129e-18)
# (2, 3)                             (-0.454, 0.0130361216427)
# (2, 5)                           (-0.769, 0.000454715092739)
# (2, 10)                           (-1.408, 3.5602765026e-07)
# (2, 20)                           (-3.056, 1.6273058285e-12)

# %% [markdown]
# ### Event3c: ncount > ncount_miu + ncount_sigma AND alpha < alpha_miu - alpha_sigma

# %% [markdown]
# ### Followed by: ncount > ncount_miu + ncount_sigma AND alpha > alpha_miu + alpha_sigma

# %%
class PosFollower(NewsEvent):
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha > a_m + a_s):
            return True
        return False

# %%
class Event3c(NewsEvent):
    @property
    def description(self):
        return 'nc > nc_m + nc_s AND a < a_m - a_s FOLLOWED by PosFollower'
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']        
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha < a_m - a_s):
            ce = CloseEvents(self)
            close_events = ce.find_after(PosFollower, 20)
            if len(close_events) > 0:
                return True
            return False

# %%
detector3c = EventDetector(Event3c)

# %%
events3c = dict()
for entity_id, entity_data in DATA.items():
    entity_events = detector3c.run(entity_id, entity_data, META[entity_id])
    if len(entity_events) > 0:
        events3c[entity_id] = entity_events

# %%
len(events3c)  # number of entities with at least 1 event [07.05.2014]
# Out:
# 204

# %%
list3c = EventList.from_dict(events3c)

# %%
list3c  # [07.05.2014]
# Out:
# EventList with 502 events

# %% [markdown]
# ##### Results

# %%
res3c = tabular_results([list3c], 'alpha', result_days)

# %%
res3c.T  # [07.05.2014]
# Out:
#           nc > nc_m + nc_s AND a < a_m - a_s FOLLOWED by PosFollower
# (-20, 20)                        (-2.055, 7.29695487131e-07)
# (-10, 10)                         (-0.862, 0.00351220136402)
# (-5, 5)                             (-0.355, 0.164156965371)
# (-3, 3)                             (-0.278, 0.173204897507)
# (-1, 1)                             (-0.054, 0.744030940861)
# (0, 1)                           (-4.746, 1.01744819786e-30)
# (1, 1)                             (0.362, 0.00894776220037)
# (1, 3)                              (0.703, 0.0050298164606)
# (1, 5)                            (0.976, 0.000537716263362)
# (1, 10)                           (1.176, 0.000426853880006)
# (1, 20)                            (1.316, 0.00203482308069)
# (2, 3)                               (0.353, 0.102589756076)
# (2, 5)                             (0.704, 0.00233518012143)
# (2, 10)                            (0.847, 0.00413571610348)
# (2, 20)                             (0.904, 0.0242497228511)

# %% [markdown]
# ### Event 4c: ncount > ncount_miu + ncount_sigma AND alpha < alpha_miu - 2 * alpha_sigma

# %% [markdown]
# ### Followed by: ncount > ncount_miu + ncount_sigma AND abs(alpha) > alpha_miu + alpha_sigma

# %%
class Event4c(NewsEvent):
    @property
    def description(self):
        return 'nc > nc_m + nc_s AND a < a_m - 2 * a_s FOLLOWED by AbsFollower'
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']        
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha < a_m - 2 * a_s):
            ce = CloseEvents(self)
            close_events = ce.find_after(AbsFollower, 20)
            if len(close_events) > 0:
                return True
            return False

# %%
detector4c = EventDetector(Event4c)

# %%
events4c = dict()
for entity_id, entity_data in DATA.items():
    entity_events = detector4c.run(entity_id, entity_data, META[entity_id])
    if len(entity_events) > 0:
        events4c[entity_id] = entity_events

# %%
len(events4c)  # number of entities with at least 1 event [07.05.2014]
# Out:
# 203

# %%
list4c = EventList.from_dict(events4c)

# %%
list4c  # [07.05.2014]
# Out:
# EventList with 374 events

# %% [markdown]
# ##### Results

# %%
res4c = tabular_results([list4c], 'alpha', result_days)

# %%
res4c.T  # [07.05.2014]
# Out:
#           nc > nc_m + nc_s AND a < a_m - 2 * a_s FOLLOWED by AbsFollower
# (-20, 20)                        (-1.887, 0.000177102482718)
# (-10, 10)                           (-0.879, 0.013923694824)
# (-5, 5)                            (-0.511, 0.0794629958752)
# (-3, 3)                             (-0.361, 0.109622748454)
# (-1, 1)                             (-0.224, 0.170148830941)
# (0, 1)                           (-7.767, 8.47815202417e-39)
# (1, 1)                              (-0.302, 0.109160869997)
# (1, 3)                               (-0.346, 0.29803295135)
# (1, 5)                              (-0.307, 0.415850822944)
# (1, 10)                              (-0.66, 0.137961264604)
# (1, 20)                            (-1.622, 0.0116911818753)
# (2, 3)                              (-0.056, 0.849387454922)
# (2, 5)                              (-0.093, 0.767460202589)
# (2, 10)                             (-0.242, 0.543863995076)
# (2, 20)                            (-1.476, 0.0146778413498)

# %% [markdown]
# ### Event 5c: ncount > ncount_miu + ncount_sigma AND alpha < alpha_miu - 2 * alpha_sigma

# %% [markdown]
# ### Followed by: ncount > ncount_miu + ncount_sigma AND alpha < alpha_miu - alpha_sigma

# %%
class Event5c(NewsEvent):
    @property
    def description(self):
        return 'nc > nc_m + nc_s AND a < a_m - 2 * a_s FOLLOWED by NegFollower'
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']        
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha < a_m - 2 * a_s):
            ce = CloseEvents(self)
            close_events = ce.find_after(NegFollower, 20)
            if len(close_events) > 0:
                return True
            return False

# %%
detector5c = EventDetector(Event5c)

# %%
events5c = dict()
for entity_id, entity_data in DATA.items():
    entity_events = detector5c.run(entity_id, entity_data, META[entity_id])
    if len(entity_events) > 0:
        events5c[entity_id] = entity_events

# %%
len(events5c)  # number of entities with at least 1 event [07.05.2014]
# Out:
# 147

# %%
list5c = EventList.from_dict(events5c)

# %%
list5c  # [07.05.2014]
# Out:
# EventList with 233 events

# %% [markdown]
# ##### Results

# %%
res5c = tabular_results([list5c], 'alpha', result_days)

# %%
res5c.T  # [07.05.2014]
# Out:
#           nc > nc_m + nc_s AND a < a_m - 2 * a_s FOLLOWED by NegFollower
# (-20, 20)                          (-1.629, 0.0137383128394)
# (-10, 10)                          (-0.946, 0.0412786593278)
# (-5, 5)                            (-0.734, 0.0249197936274)
# (-3, 3)                            (-0.706, 0.0106652588808)
# (-1, 1)                           (-0.622, 0.00296169556797)
# (0, 1)                           (-7.272, 1.36029241082e-38)
# (1, 1)                           (-1.112, 1.56594758394e-07)
# (1, 3)                           (-1.666, 2.28351764655e-07)
# (1, 5)                           (-1.732, 1.23885019654e-05)
# (1, 10)                          (-2.731, 3.18886350586e-07)
# (1, 20)                          (-4.695, 3.21023002654e-09)
# (2, 3)                             (-0.641, 0.0525087852794)
# (2, 5)                              (-0.839, 0.037136479562)
# (2, 10)                           (-1.626, 0.00200009031037)
# (2, 20)                           (-3.761, 2.1461416515e-06)

# %% [markdown]
# ### Event 6c: ncount > ncount_miu + ncount_sigma AND alpha < alpha_miu - 2 * alpha_sigma

# %% [markdown]
# ### Followed by: ncount > ncount_miu + ncount_sigma AND alpha > alpha_miu + alpha_sigma

# %%
class Event6c(NewsEvent):
    @property
    def description(self):
        return 'nc > nc_m + nc_s AND a < a_m - 2 * a_s FOLLOWED by PosFollower'
    def triggers(self):
        n_m = self.additional_data['news_count_miu']
        n_s = self.additional_data['news_count_sigma']        
        a_m = self.additional_data['alpha_miu']
        a_s = self.additional_data['alpha_sigma']
        if (self.event_day_news_count > n_m + n_s and
            self.event_day_alpha < a_m - 2 * a_s):
            ce = CloseEvents(self)
            close_events = ce.find_after(PosFollower, 20)
            if len(close_events) > 0:
                return True
            return False

# %%
detector6c = EventDetector(Event6c)

# %%
events6c = dict()
for entity_id, entity_data in DATA.items():
    entity_events = detector6c.run(entity_id, entity_data, META[entity_id])
    if len(entity_events) > 0:
        events6c[entity_id] = entity_events

# %%
len(events6c)  # number of entities with at least 1 event [07.05.2014]
# Out:
# 139

# %%
list6c = EventList.from_dict(events6c)

# %%
list6c  # [07.05.2014]
# Out:
# EventList with 222 events

# %% [markdown]
# ##### Results

# %%
res6c = tabular_results([list6c], 'alpha', result_days)

# %%
res6c.T  # [07.05.2014]
# Out:
#           nc > nc_m + nc_s AND a < a_m - 2 * a_s FOLLOWED by PosFollower
# (-20, 20)                        (-2.265, 0.000186948129389)
# (-10, 10)                          (-0.978, 0.0317909200392)
# (-5, 5)                             (-0.467, 0.263149486971)
# (-3, 3)                             (-0.181, 0.572299058613)
# (-1, 1)                             (-0.097, 0.683623793654)
# (0, 1)                           (-8.074, 1.85220745475e-19)
# (1, 1)                              (0.503, 0.0450326131702)
# (1, 3)                              (0.892, 0.0650347473086)
# (1, 5)                              (1.092, 0.0434341328841)
# (1, 10)                             (1.225, 0.0527676393144)
# (1, 20)                              (1.296, 0.114247464801)
# (2, 3)                               (0.425, 0.316125371316)
# (2, 5)                              (0.723, 0.0896799276905)
# (2, 10)                             (0.948, 0.0797389528606)
# (2, 20)                              (0.634, 0.392753212092)
