# %%
import pandas as pd

# %%
from fsprices.universe import (
    Universe, Security, get_research_universe
)

from blvresearch.core.research_data import (
    get_research_data_by_country
)
from blvresearch.core.chan import (
    ChanNews, ChanNoNews,
)
from blvresearch.core.std_rolling_portfolio import (
    JegadeeshTitman
)

# %%
pylab.rcParams['figure.figsize'] = (16.0, 8.0)

# %%
start_date = '2011-01-01'
end_date = '2013-12-31'

# %%
def criteria(sec_meta):
    if (sec_meta['avg_vol'] > 1000 and
        sec_meta['market_cap'] > 1000000):
        return True
    return False

# %%
DATA = get_research_data_by_country(
    ['US'], criteria, start_date, end_date
)

# %%
len(DATA)  # total number of entities [15.04.2014]
# Out:
# 1491

# %% [markdown]
# ### Jegadeesh & Titman 1M-1M (terciles)

# %%
jt = JegadeeshTitman(DATA,
                     type_of_return='alpha',
                     no_of_quantiles=3)

# %%
w = jt.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = jt.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = jt.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ### Jegadeesh & Titman 1M-3M (terciles)

# %%
w = jt.get_winners_returns('M', test_per=1, hold_per=3)
w.name = 'W'

l = jt.get_losers_returns('M', test_per=1, hold_per=3)
l.name = 'L'

wml = jt.get_wml_returns('M', test_per=1, hold_per=3)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ### Jegadeesh & Titman 1M-1M (deciles)

# %%
jt = JegadeeshTitman(DATA,
                     type_of_return='alpha',
                     no_of_quantiles=10)

# %%
w = jt.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = jt.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = jt.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %% [markdown]
# ### Chan News 1M-1M (terciles)

# %%
cn = ChanNews(DATA,
              type_of_return='alpha',
              no_of_quantiles=3)

# %%
w = cn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ### Chan News 1M-3M (terciles)

# %%
w = cn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ### Chan News 1M-1M (deciles)

# %%
cn = ChanNews(DATA,
              type_of_return='alpha',
              no_of_quantiles=10)

# %%
w = cn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %% [markdown]
# ### Chan No News 1M-1M (terciles)

# %%
cnn = ChanNoNews(DATA,
                 type_of_return='alpha',
                 no_of_quantiles=3)

# %%
w = cnn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cnn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cnn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ### Chan No News 1M-3M (terciles)

# %%
w = cnn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cnn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cnn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ### Chan No News 1M-1M (deciles)

# %%
cnn = ChanNoNews(DATA,
                 type_of_return='alpha',
                 no_of_quantiles=10)

# %%
w = cnn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cnn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cnn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml
# Out:
#                                   W         L       WmL
# 2011-02-28 00:00:00+00:00  0.051605 -0.016265  0.067870
# 2011-03-31 00:00:00+00:00  0.072877  0.056718  0.016159
# 2011-04-30 00:00:00+00:00 -0.021917  0.039313 -0.061230
# 2011-05-31 00:00:00+00:00 -0.033699 -0.017783 -0.015916
# 2011-06-30 00:00:00+00:00  0.079828  0.027033  0.052795
# 2011-07-31 00:00:00+00:00 -0.057774 -0.033598 -0.024176
# 2011-08-31 00:00:00+00:00 -0.084103 -0.075789 -0.008314
# 2011-09-30 00:00:00+00:00 -0.017499 -0.139371  0.121872
# 2011-10-31 00:00:00+00:00 -0.047634  0.159299 -0.206933
# 2011-11-30 00:00:00+00:00  0.035212  0.089598 -0.054386
# 2011-12-31 00:00:00+00:00 -0.013844 -0.062930  0.049086
# 2012-01-31 00:00:00+00:00  0.039248  0.146044 -0.106797
# 2012-02-29 00:00:00+00:00  0.033690 -0.013954  0.047644
# 2012-03-31 00:00:00+00:00 -0.190347 -0.025693 -0.164654
# 2012-04-30 00:00:00+00:00  0.035677 -0.013246  0.048922
# 2012-05-31 00:00:00+00:00 -0.052996 -0.053629  0.000633
# 2012-06-30 00:00:00+00:00 -0.013209  0.011254 -0.024464
# 2012-07-31 00:00:00+00:00 -0.088284 -0.007770 -0.080515
# 2012-08-31 00:00:00+00:00  0.035860       NaN       NaN
# 2012-09-30 00:00:00+00:00  0.062434 -0.029722  0.092156
# 2012-10-31 00:00:00+00:00 -0.028201  0.010508 -0.038709
# 2012-11-30 00:00:00+00:00       NaN  0.030483       NaN
# 2012-12-31 00:00:00+00:00  0.039203  0.006615  0.032589
# 2013-01-31 00:00:00+00:00  0.087576  0.030083  0.057492
# 2013-02-28 00:00:00+00:00 -0.081658 -0.046842 -0.034815
# 2013-03-31 00:00:00+00:00  0.008196 -0.030481  0.038678
# 2013-04-30 00:00:00+00:00 -0.044825 -0.058676  0.013851
# 2013-05-31 00:00:00+00:00 -0.005401  0.000206 -0.005607
# 2013-06-30 00:00:00+00:00 -0.025009 -0.030643  0.005634
# 2013-07-31 00:00:00+00:00  0.007603  0.031702 -0.024098
# 2013-08-31 00:00:00+00:00 -0.052193  0.171885 -0.224078
# 2013-09-30 00:00:00+00:00 -0.011987  0.083209 -0.095196
# 2013-10-31 00:00:00+00:00 -0.045263  0.005679 -0.050942
# 2013-11-30 00:00:00+00:00  0.150352  0.001078  0.149274
# 2013-12-31 00:00:00+00:00 -0.022494 -0.019582 -0.002912

# %%
df_of_returns = cnn._get_initial_returns(freq='M')

# %%
df_of_returns.loc[ts(2012, 8, 31)][losers[ts(2012, 7, 31)]]
# Out:
# 000PYN-E   -0.709797
# 000SVH-E    0.156781
# 0015K9-E   -0.045030
# 00194M-E   -0.013183
# 0025XP-E    0.084032
# 0063GJ-E    0.189476
# 007C1Y-E    0.196658
# 007QP2-E    0.060560
# 008P69-E    0.221921
# 009FPC-E    0.009589
# 05MHNR-E   -0.077003
# 0B0G82-E    0.112216
# Name: 2012-08-31 00:00:00+00:00, dtype: float64

# %%
w_l_wml.fillna(0, inplace=True)  # some average returns are NaN, is it because no return passed the breakpoint?

# %%
w_l_wml.cumsum().plot()  # portfolios are small, from 4 [February 2013] to 37 [December 2011] stocks

# %% [markdown]
# ##### Portfolios

# %%
df_of_returns = cnn._get_initial_returns('M')
winners = cnn._get_winners(df_of_returns, 1)
losers = cnn._get_losers(df_of_returns, 1)

# %%
for day, lst in winners.items():
    print(day, len(lst))
# Out:
# 2011-01-31 00:00:00+00:00 16
# 2011-02-28 00:00:00+00:00 9
# 2011-03-31 00:00:00+00:00 14
# 2011-04-30 00:00:00+00:00 20
# 2011-05-31 00:00:00+00:00 16
# 2011-06-30 00:00:00+00:00 29
# 2011-07-31 00:00:00+00:00 10
# 2011-08-31 00:00:00+00:00 21
# 2011-09-30 00:00:00+00:00 27
# 2011-10-31 00:00:00+00:00 10
# 2011-11-30 00:00:00+00:00 16
# 2011-12-31 00:00:00+00:00 37
# 2012-01-31 00:00:00+00:00 19
# 2012-02-29 00:00:00+00:00 5
# 2012-03-31 00:00:00+00:00 18
# 2012-04-30 00:00:00+00:00 15
# 2012-05-31 00:00:00+00:00 8
# 2012-06-30 00:00:00+00:00 28
# 2012-07-31 00:00:00+00:00 10
# 2012-08-31 00:00:00+00:00 11
# 2012-09-30 00:00:00+00:00 29
# 2012-10-31 00:00:00+00:00 6
# 2012-11-30 00:00:00+00:00 19
# 2012-12-31 00:00:00+00:00 23
# 2013-01-31 00:00:00+00:00 15
# 2013-02-28 00:00:00+00:00 4
# 2013-03-31 00:00:00+00:00 13
# 2013-04-30 00:00:00+00:00 9
# 2013-05-31 00:00:00+00:00 10
# 2013-06-30 00:00:00+00:00 29
# 2013-07-31 00:00:00+00:00 9
# 2013-08-31 00:00:00+00:00 8
# 2013-09-30 00:00:00+00:00 26
# 2013-10-31 00:00:00+00:00 10
# 2013-11-30 00:00:00+00:00 18
# 2013-12-31 00:00:00+00:00 18

# %%
for day, lst in losers.items():
    print(day, len(lst))
# Out:
# 2011-01-31 00:00:00+00:00 30
# 2011-02-28 00:00:00+00:00 19
# 2011-03-31 00:00:00+00:00 22
# 2011-04-30 00:00:00+00:00 15
# 2011-05-31 00:00:00+00:00 8
# 2011-06-30 00:00:00+00:00 19
# 2011-07-31 00:00:00+00:00 23
# 2011-08-31 00:00:00+00:00 9
# 2011-09-30 00:00:00+00:00 22
# 2011-10-31 00:00:00+00:00 16
# 2011-11-30 00:00:00+00:00 15
# 2011-12-31 00:00:00+00:00 29
# 2012-01-31 00:00:00+00:00 8
# 2012-02-29 00:00:00+00:00 12
# 2012-03-31 00:00:00+00:00 16
# 2012-04-30 00:00:00+00:00 18
# 2012-05-31 00:00:00+00:00 12
# 2012-06-30 00:00:00+00:00 16
# 2012-07-31 00:00:00+00:00 12
# 2012-08-31 00:00:00+00:00 10
# 2012-09-30 00:00:00+00:00 36
# 2012-10-31 00:00:00+00:00 15
# 2012-11-30 00:00:00+00:00 10
# 2012-12-31 00:00:00+00:00 37
# 2013-01-31 00:00:00+00:00 19
# 2013-02-28 00:00:00+00:00 4
# 2013-03-31 00:00:00+00:00 32
# 2013-04-30 00:00:00+00:00 19
# 2013-05-31 00:00:00+00:00 9
# 2013-06-30 00:00:00+00:00 42
# 2013-07-31 00:00:00+00:00 13
# 2013-08-31 00:00:00+00:00 17
# 2013-09-30 00:00:00+00:00 25
# 2013-10-31 00:00:00+00:00 12
# 2013-11-30 00:00:00+00:00 8
# 2013-12-31 00:00:00+00:00 32

# %% [markdown]
# ### Chan News 1M-1M (deciles)

# %%
cn = ChanNews(DATA,
              type_of_return='alpha',
              no_of_quantiles=10)

# %%
w = cn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ##### Portfolios

# %%
df_of_returns = cn._get_initial_returns('M')
winners = cn._get_winners(df_of_returns, 1)
losers = cn._get_losers(df_of_returns, 1)

# %%
for day, lst in winners.items():
    print(day, len(lst))
# Out:
# 2011-01-31 00:00:00+00:00 123
# 2011-02-28 00:00:00+00:00 128
# 2011-03-31 00:00:00+00:00 114
# 2011-04-30 00:00:00+00:00 126
# 2011-05-31 00:00:00+00:00 123
# 2011-06-30 00:00:00+00:00 108
# 2011-07-31 00:00:00+00:00 123
# 2011-08-31 00:00:00+00:00 126
# 2011-09-30 00:00:00+00:00 113
# 2011-10-31 00:00:00+00:00 126
# 2011-11-30 00:00:00+00:00 120
# 2011-12-31 00:00:00+00:00 104
# 2012-01-31 00:00:00+00:00 121
# 2012-02-29 00:00:00+00:00 130
# 2012-03-31 00:00:00+00:00 111
# 2012-04-30 00:00:00+00:00 121
# 2012-05-31 00:00:00+00:00 124
# 2012-06-30 00:00:00+00:00 106
# 2012-07-31 00:00:00+00:00 125
# 2012-08-31 00:00:00+00:00 120
# 2012-09-30 00:00:00+00:00 103
# 2012-10-31 00:00:00+00:00 125
# 2012-11-30 00:00:00+00:00 117
# 2012-12-31 00:00:00+00:00 103
# 2013-01-31 00:00:00+00:00 117
# 2013-02-28 00:00:00+00:00 124
# 2013-03-31 00:00:00+00:00 101
# 2013-04-30 00:00:00+00:00 118
# 2013-05-31 00:00:00+00:00 120
# 2013-06-30 00:00:00+00:00 95
# 2013-07-31 00:00:00+00:00 120
# 2013-08-31 00:00:00+00:00 110
# 2013-09-30 00:00:00+00:00 103
# 2013-10-31 00:00:00+00:00 122
# 2013-11-30 00:00:00+00:00 112
# 2013-12-31 00:00:00+00:00 103

# %% [markdown]
# ##### Getting News Winners by Chan

# %%
test_per = 1

# %%
df_of_returns = cn._nan_returns_without_news(returns)

# %%
df_of_returns['000BFS-E']
# Out:
# 2011-01-31 00:00:00+00:00         NaN
# 2011-02-28 00:00:00+00:00         NaN
# 2011-03-31 00:00:00+00:00    0.033730
# 2011-04-30 00:00:00+00:00   -0.079583
# 2011-05-31 00:00:00+00:00         NaN
# 2011-06-30 00:00:00+00:00         NaN
# 2011-07-31 00:00:00+00:00    0.088111
# 2011-08-31 00:00:00+00:00         NaN
# 2011-09-30 00:00:00+00:00   -0.318138
# 2011-10-31 00:00:00+00:00    0.082511
# 2011-11-30 00:00:00+00:00   -0.100664
# 2011-12-31 00:00:00+00:00   -0.006594
# 2012-01-31 00:00:00+00:00    0.067831
# 2012-02-29 00:00:00+00:00   -0.005582
# 2012-03-31 00:00:00+00:00   -0.257481
# 2012-04-30 00:00:00+00:00   -0.150317
# 2012-05-31 00:00:00+00:00         NaN
# 2012-06-30 00:00:00+00:00    0.052448
# 2012-07-31 00:00:00+00:00    0.013364
# 2012-08-31 00:00:00+00:00         NaN
# 2012-09-30 00:00:00+00:00    0.065706
# 2012-10-31 00:00:00+00:00   -0.035465
# 2012-11-30 00:00:00+00:00    0.025916
# 2012-12-31 00:00:00+00:00    0.188609
# 2013-01-31 00:00:00+00:00         NaN
# 2013-02-28 00:00:00+00:00   -0.107141
# 2013-03-31 00:00:00+00:00    0.001622
# 2013-04-30 00:00:00+00:00   -0.050066
# 2013-05-31 00:00:00+00:00    0.089205
# 2013-06-30 00:00:00+00:00    0.111011
# 2013-07-31 00:00:00+00:00    0.055807
# 2013-08-31 00:00:00+00:00    0.090592
# 2013-09-30 00:00:00+00:00    0.083369
# 2013-10-31 00:00:00+00:00         NaN
# 2013-11-30 00:00:00+00:00    0.023383
# 2013-12-31 00:00:00+00:00   -0.124077
# Freq: M, Name: 000BFS-E, dtype: float64

# %%
result = dict()

# %%
from blvresearch.core.std_rolling_portfolio import (
    get_sorted_returns
)

# %%
sorted_returns = get_sorted_returns(df_of_returns, test_per=1)

# %%
def ts(year, month, day):
    dt = pd.datetime(year, month, day, 0, 0, 0)
    return pd.Timestamp(dt, tz='UTC')

# %%
sorted_returns[ts(2011, 1, 31)].dropna()
# Out:
# 005SV0-E   -0.535550
# 001CHF-E   -0.361765
# 00694W-E   -0.354266
# 001NXZ-E   -0.317358
# 000X42-E   -0.294893
# 007QP2-E   -0.284427
# 0010YB-E   -0.272562
# 004Y8D-E   -0.266470
# 001D39-E   -0.261160
# 000XM1-E   -0.259514
# 000LLZ-E   -0.257032
# 000C6F-E   -0.246765
# 00163M-E   -0.244352
# 0011NQ-E   -0.225987
# 0050DS-E   -0.223970
# ...
# 002S9V-E    0.188321
# 00B1TT-E    0.188800
# 000YVQ-E    0.189379
# 000Y86-E    0.193318
# 0018TH-E    0.193392
# 002XRT-E    0.196024
# 0023S0-E    0.204032
# 000WTW-E    0.209743
# 0021ZC-E    0.214296
# 05SGY2-E    0.217921
# 05LN81-E    0.221154
# 09XZP2-E    0.251157
# 000PZY-E    0.256080
# 000DS3-E    0.262393
# 00208X-E    0.440166
# Length: 1236, dtype: float64

# %%
for day, series in sorted_returns.items():
    break

# %%
day
# Out:
# Timestamp('2011-10-31 00:00:00+0000', tz='UTC')

# %%
series
# Out:
# 0016K0-E   -0.468014
# 0070ZH-E   -0.408896
# 002X9M-E   -0.402952
# 002WRP-E   -0.396529
# 008FJT-E   -0.346371
# 005VKB-E   -0.319395
# 000V6D-E   -0.318383
# 0011NH-E   -0.301310
# 007295-E   -0.273372
# 0078VV-E   -0.271444
# 0069MX-E   -0.255103
# 066ZNL-E   -0.248037
# 063Y5D-E   -0.246607
# 004SP8-E   -0.245139
# 0023Q5-E   -0.241494
# ...
# 06P3KD-E   NaN
# 06Q9HM-E   NaN
# 06RBV0-E   NaN
# 07516L-E   NaN
# 0789KJ-E   NaN
# 07HRY8-E   NaN
# 07NWQP-E   NaN
# 08GVST-E   NaN
# 08GVVX-E   NaN
# 09XX7D-E   NaN
# 09XZP2-E   NaN
# 0B0G82-E   NaN
# 0BRKZH-E   NaN
# 0C5TLV-E   NaN
# 0D4BBG-E   NaN
# Length: 1491, dtype: float64

# %%
series = series.dropna()

# %%
series
# Out:
# 0016K0-E   -0.468014
# 0070ZH-E   -0.408896
# 002X9M-E   -0.402952
# 002WRP-E   -0.396529
# 008FJT-E   -0.346371
# 005VKB-E   -0.319395
# 000V6D-E   -0.318383
# 0011NH-E   -0.301310
# 007295-E   -0.273372
# 0078VV-E   -0.271444
# 0069MX-E   -0.255103
# 066ZNL-E   -0.248037
# 063Y5D-E   -0.246607
# 004SP8-E   -0.245139
# 0023Q5-E   -0.241494
# ...
# 000FFL-E    0.269003
# 0035RF-E    0.277549
# 05NGF9-E    0.289738
# 000QTL-E    0.291077
# 0013RD-E    0.295967
# 000LGX-E    0.297936
# 0032VQ-E    0.311239
# 0011GW-E    0.318807
# 0037KG-E    0.342724
# 000PF5-E    0.355138
# 000XNL-E    0.368259
# 000Y2H-E    0.368893
# 007C1Y-E    0.388028
# 009SYB-E    0.432285
# 007NHS-E    0.450755
# Length: 1268, dtype: float64

# %%
winners = series[-size:]

# %%
winners[0]
# Out:
# 0.1435140781689021

# %%
losers = series[:size]

# %%
losers[-1]
# Out:
# -0.049702000134292684

# %%
size = int(len(series) / 10)

# %%
size
# Out:
# 149

# %%
ser = series.dropna()

# %%
ser[:size].index
# Out:
# Index(['0016K0-E', '0070ZH-E', '002X9M-E', '002WRP-E', '008FJT-E', '005VKB-E', '000V6D-E', '0011NH-E', '007295-E', '0078VV-E', '0069MX-E', '066ZNL-E', '063Y5D-E', '004SP8-E', '0023Q5-E', '0059GK-E', '005TLP-E', '005NJ1-E', '000F6C-E', '001NVG-E', '000CXX-E', '005YGS-E', '0016M8-E', '0011X7-E', '000N0T-E', '0020GS-E', '002WXZ-E', '00694W-E', '000YJB-E', '000CGK-E', '000DLW-E', '05L5CH-E', '005MYP-E', '000XNX-E', '05LN81-E', '00156C-E', '006Q7L-E', '000WTW-E', '0094JK-E', '001MF1-E', '001DY1-E', '0014HR-E', '000VC1-E', '002WDD-E', '005Q6P-E', '000CSD-E', '000PLK-E', '000CR1-E', '06GD1S-E', '0049BR-E', '067TWF-E', '00B2RQ-E', '002F40-E', '000LLP-E', '06LJVN-E', '000LNJ-E', '0036P0-E', '009LD2-E', '0B34WJ-E', '000M2Q-E', '000CNJ-E', '003T5H-E', '0013JH-E', '002L95-E', '0011QQ-E', '000R9T-E', '003HZ1-E', '000CLT-E', '000SV2-E', '000F34-E', '0011GG-E', '000XM1-E', '0043JL-E', '0010YB-E', '000NVS-E', '001WDQ-E', '001QX0-E', '000HJ4-E', '06M8S0-E', '000Y4T-E', '000X16-E', '001RND-E', '000YVZ-E', '06NQM5-E', '000YTL-E', '000XM9-E', '002K2T-E', '003123-E', '002S9J-E', '001H0J-E', '0024XW-E', '05M40C-E', '000DQG-E', '000YMW-E', '00650L-E', '000X6Q-E', '000XKX-E', '00BDWZ-E', '000HYL-E', '000JJW-E', '000P56-E', '002843-E', '009KX0-E', '000V1Y-E', '004LNZ-E', '001RKD-E', '001Y7N-E', '0013YQ-E', '000F9X-E', '0020LT-E', '009Z0H-E', '000KNF-E', '000BQR-E', '0022QP-E', '000L50-E', '000DSS-E', '000X58-E', '002MY0-E', '001ZRY-E', '061F6G-E', '000DWY-E', '000YPQ-E', '002X70-E', '000NB6-E', '06CZGM-E', '001WPM-E', '0680QK-E', '000CQ8-E', '002VL5-E', '0014BW-E', '001585-E', '0022BX-E', '000PLZ-E', '0089PB-E', '00150Y-E', '000TMB-E', '000Y8L-E', '000XXL-E', '00389G-E', '000KYW-E', '0023JS-E', '000Q94-E', '000DV5-E', '060KMN-E', '000TRY-E', '000TCG-E', '002M94-E', '001RMM-E', '000HND-E'], dtype=object)

# %%
w = cn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ### Chan No News 1M-1M (deciles)

# %%
cnn = ChanNoNews(DATA,
                 type_of_return='alpha',
                 no_of_quantiles=10)

# %%
w = cnn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cnn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cnn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml
# Out:
#                                   W         L       WmL
# 2011-02-28 00:00:00+00:00  0.051605 -0.016265  0.067870
# 2011-03-31 00:00:00+00:00  0.072877  0.056718  0.016159
# 2011-04-30 00:00:00+00:00 -0.021917  0.039313 -0.061230
# 2011-05-31 00:00:00+00:00 -0.033699 -0.017783 -0.015916
# 2011-06-30 00:00:00+00:00  0.079828  0.027033  0.052795
# 2011-07-31 00:00:00+00:00 -0.057774 -0.033598 -0.024176
# 2011-08-31 00:00:00+00:00 -0.084103 -0.075789 -0.008314
# 2011-09-30 00:00:00+00:00 -0.017499 -0.139371  0.121872
# 2011-10-31 00:00:00+00:00 -0.047634  0.159299 -0.206933
# 2011-11-30 00:00:00+00:00  0.035212  0.089598 -0.054386
# 2011-12-31 00:00:00+00:00 -0.013844 -0.062930  0.049086
# 2012-01-31 00:00:00+00:00  0.039248  0.146044 -0.106797
# 2012-02-29 00:00:00+00:00  0.033690 -0.013954  0.047644
# 2012-03-31 00:00:00+00:00 -0.190347 -0.025693 -0.164654
# 2012-04-30 00:00:00+00:00  0.035677 -0.013246  0.048922
# 2012-05-31 00:00:00+00:00 -0.052996 -0.053629  0.000633
# 2012-06-30 00:00:00+00:00 -0.013209  0.011254 -0.024464
# 2012-07-31 00:00:00+00:00 -0.088284 -0.007770 -0.080515
# 2012-08-31 00:00:00+00:00  0.035860       NaN       NaN
# 2012-09-30 00:00:00+00:00  0.062434 -0.029722  0.092156
# 2012-10-31 00:00:00+00:00 -0.028201  0.010508 -0.038709
# 2012-11-30 00:00:00+00:00       NaN  0.030483       NaN
# 2012-12-31 00:00:00+00:00  0.039203  0.006615  0.032589
# 2013-01-31 00:00:00+00:00  0.087576  0.030083  0.057492
# 2013-02-28 00:00:00+00:00 -0.081658 -0.046842 -0.034815
# 2013-03-31 00:00:00+00:00  0.008196 -0.030481  0.038678
# 2013-04-30 00:00:00+00:00 -0.044825 -0.058676  0.013851
# 2013-05-31 00:00:00+00:00 -0.005401  0.000206 -0.005607
# 2013-06-30 00:00:00+00:00 -0.025009 -0.030643  0.005634
# 2013-07-31 00:00:00+00:00  0.007603  0.031702 -0.024098
# 2013-08-31 00:00:00+00:00 -0.052193  0.171885 -0.224078
# 2013-09-30 00:00:00+00:00 -0.011987  0.083209 -0.095196
# 2013-10-31 00:00:00+00:00 -0.045263  0.005679 -0.050942
# 2013-11-30 00:00:00+00:00  0.150352  0.001078  0.149274
# 2013-12-31 00:00:00+00:00 -0.022494 -0.019582 -0.002912

# %%
df_of_returns = cnn._get_initial_returns('M')
winners = cnn._get_winners(df_of_returns, 1)
losers = cnn._get_losers(df_of_returns, 1)

# %%
brkpts = cnn._get_breakpoints()

# %%
brkpts[ts(2011, 1, 31)]
# Out:
# {'l': -0.090858256498725629, 'w': 0.085132488724436267}

# %%
for day, lst in winners.items():
    print(day, len(lst))
# Out:
# 2011-01-31 00:00:00+00:00 16
# 2011-02-28 00:00:00+00:00 9
# 2011-03-31 00:00:00+00:00 14
# 2011-04-30 00:00:00+00:00 20
# 2011-05-31 00:00:00+00:00 16
# 2011-06-30 00:00:00+00:00 29
# 2011-07-31 00:00:00+00:00 10
# 2011-08-31 00:00:00+00:00 21
# 2011-09-30 00:00:00+00:00 27
# 2011-10-31 00:00:00+00:00 10
# 2011-11-30 00:00:00+00:00 16
# 2011-12-31 00:00:00+00:00 37
# 2012-01-31 00:00:00+00:00 19
# 2012-02-29 00:00:00+00:00 5
# 2012-03-31 00:00:00+00:00 18
# 2012-04-30 00:00:00+00:00 15
# 2012-05-31 00:00:00+00:00 8
# 2012-06-30 00:00:00+00:00 28
# 2012-07-31 00:00:00+00:00 10
# 2012-08-31 00:00:00+00:00 11
# 2012-09-30 00:00:00+00:00 29
# 2012-10-31 00:00:00+00:00 6
# 2012-11-30 00:00:00+00:00 19
# 2012-12-31 00:00:00+00:00 23
# 2013-01-31 00:00:00+00:00 15
# 2013-02-28 00:00:00+00:00 4
# 2013-03-31 00:00:00+00:00 13
# 2013-04-30 00:00:00+00:00 9
# 2013-05-31 00:00:00+00:00 10
# 2013-06-30 00:00:00+00:00 29
# 2013-07-31 00:00:00+00:00 9
# 2013-08-31 00:00:00+00:00 8
# 2013-09-30 00:00:00+00:00 26
# 2013-10-31 00:00:00+00:00 10
# 2013-11-30 00:00:00+00:00 18
# 2013-12-31 00:00:00+00:00 18

# %%
df_of_returns = cnn._get_initial_returns(freq='M')

# %%
naned_returns = cnn._nan_returns_with_news(df_of_returns)

# %%
nr_jan2011 = naned_returns.loc[ts(2011, 1, 31)].dropna()

# %%
brkpts = cn.get_breakpoints(df_of_returns)

# %%
brkpts[ts(2011, 1, 31)]
# Out:
# {'l': -0.023117199783867039, 'w': 0.027708258375963864}

# %%
for day, series in naned_returns.iterrows():
    break

# %%
day
# Out:
# Timestamp('2011-01-31 00:00:00+0000', tz='UTC')

# %%
series = series.dropna()

# %%
los_brkpt = brkpts[ts(2011, 1, 31)]['l']

# %%
list(series[series < los_brkpt].index)
# Out:
# ['000BFS-E',
#  '000BPS-E',
#  '000BVM-E',
#  '000C9Q-E',
#  '000CLW-E',
#  '000DCQ-E',
#  '000DNJ-E',
#  '000F6H-E',
#  '000F9L-E',
#  '000JBM-E',
#  '000KHW-E',
#  '000L4D-E',
#  '000LL9-E',
#  '000LM7-E',
#  '000LRT-E',
#  '000LS4-E',
#  '000M2Q-E',
#  '000NGS-E',
#  '000P1X-E',
#  '000P2H-E',
#  '000PQH-E',
#  '000Q0V-E',
#  '000Q1J-E',
#  '000R7G-E',
#  '000RG6-E',
#  '000SVH-E',
#  '000THJ-E',
#  '000VLJ-E',
#  '000VM6-E',
#  '000W7N-E',
#  '000WPH-E',
#  '0011KF-E',
#  '0011LP-E',
#  '0011SR-E',
#  '0013FT-E',
#  '0013P2-E',
#  '0013W7-E',
#  '0014KB-E',
#  '0014N5-E',
#  '0014T1-E',
#  '0015K9-E',
#  '00163B-E',
#  '0016D6-E',
#  '0019K8-E',
#  '001MPG-E',
#  '001MY1-E',
#  '001NVG-E',
#  '001QX0-E',
#  '001RK1-E',
#  '001S8D-E',
#  '001VB2-E',
#  '002260-E',
#  '002F4Q-E',
#  '002G4B-E',
#  '002LP2-E',
#  '002P6D-E',
#  '002RNG-E',
#  '002YR5-E',
#  '002ZTV-E',
#  '00316P-E',
#  '003196-E',
#  '0032NB-E',
#  '00345K-E',
#  '003BKC-E',
#  '003CZW-E',
#  '003HLJ-E',
#  '003T5H-E',
#  '00421P-E',
#  '0043JL-E',
#  '005NP1-E',
#  '005Y6C-E',
#  '006JX6-E',
#  '007295-E',
#  '0072XZ-E',
#  '007M1P-E',
#  '007WJS-E',
#  '008P69-E',
#  '0091TV-E',
#  '009FPC-E',
#  '009PJ4-E',
#  '00B36T-E',
#  '00B72R-E',
#  '00BR8H-E',
#  '00C87B-E',
#  '00F03V-E',
#  '05JLY2-E',
#  '05LJBY-E',
#  '05MHNR-E',
#  '05XCS7-E',
#  '060KMN-E',
#  '063Y5D-E',
#  '067TWF-E',
#  '06D8MS-E',
#  '06GD1S-E',
#  '06NX47-E',
#  '06S131-E',
#  '06WDS9-E',
#  '07HRY8-E',
#  '085R9C-E',
#  '09XX7D-E']

# %%
nr_jan2011[nr_jan2011 < -0.0231171997]
# Out:
# 000BFS-E   -0.043943
# 000BPS-E   -0.033259
# 000BVM-E   -0.079475
# 000C9Q-E   -0.087153
# 000CLW-E   -0.059424
# 000DCQ-E   -0.068906
# 000DNJ-E   -0.038637
# 000F6H-E   -0.045445
# 000F9L-E   -0.036927
# 000JBM-E   -0.056903
# 000KHW-E   -0.095141
# 000L4D-E   -0.252896
# 000LL9-E   -0.025139
# 000LM7-E   -0.059747
# 000LRT-E   -0.046680
# ...
# 05JLY2-E   -0.101471
# 05LJBY-E   -0.116957
# 05MHNR-E   -0.125780
# 05XCS7-E   -0.193319
# 060KMN-E   -0.118133
# 063Y5D-E   -0.148369
# 067TWF-E   -0.033786
# 06D8MS-E   -0.063770
# 06GD1S-E   -0.040720
# 06NX47-E   -0.181113
# 06S131-E   -0.079411
# 06WDS9-E   -0.055513
# 07HRY8-E   -0.072428
# 085R9C-E   -0.271434
# 09XX7D-E   -0.137479
# Name: 2011-01-31 00:00:00+00:00, Length: 100, dtype: float64

# %%
nr_jan2011[nr_jan2011 > 0.027708]
# Out:
# 000C6B-E    0.041341
# 000D69-E    0.031956
# 000D6V-E    0.055048
# 000DW6-E    0.030687
# 000DX7-E    0.039722
# 000LSC-E    0.077020
# 000P2Z-E    0.091526
# 000PPY-E    0.040897
# 000W9G-E    0.034636
# 000WR0-E    0.090732
# 000XKX-E    0.031974
# 000XQB-E    0.072453
# 000XX9-E    0.031306
# 000Y5N-E    0.078737
# 00100S-E    0.053628
# 0010NQ-E    0.092751
# 00114X-E    0.040551
# 0011GW-E    0.033978
# 0011PD-E    0.074575
# 00133S-E    0.036756
# 0013JH-E    0.028949
# 0013NM-E    0.062097
# 0013WC-E    0.063245
# 0015DL-E    0.058772
# 0016KT-E    0.089774
# 0017N7-E    0.054079
# 00182C-E    0.121740
# 0019JD-E    0.082158
# 001BPJ-E    0.057824
# 001T0G-E    0.075965
# 001V6Q-E    0.131583
# 002171-E    0.223016
# 0024F0-E    0.051535
# 002BMT-E    0.034554
# 002G54-E    0.061716
# 002HD5-E    0.086463
# 002XST-E    0.047641
# 0033G3-E    0.063414
# 003VPY-E    0.103238
# 004RNJ-E    0.044840
# 0063GJ-E    0.074098
# 007B8X-E    0.035666
# 007C1Y-E    0.107739
# 008D1G-E    0.089157
# 0096VN-E    0.188200
# 00986H-E    0.137320
# 00B374-E    0.054161
# 00C249-E    0.029363
# 00CHRF-E    0.030073
# 05J06N-E    0.135764
# 05LC5Y-E    0.065319
# 06679M-E    0.072951
# 06773B-E    0.054122
# 06BZ3S-E    0.032915
# 06CZGM-E    0.115867
# 06Q9HM-E    0.055919
# 0BJQSB-E    0.168560
# Name: 2011-01-31 00:00:00+00:00, Length: 57, dtype: float64

# %%
brkpts = cn.get_breakpoints(df_of_returns)

# %%
w = cnn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cnn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cnn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.fillna(0, inplace=True)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ##### Portfolios

# %%
df_of_returns = cnn._get_initial_returns('M')
winners = cnn._get_winners(df_of_returns, 1)
losers = cnn._get_losers(df_of_returns, 1)

# %%
for day, lst in winners.items():
    print(day, len(lst))
# Out:
# 2011-01-31 00:00:00+00:00 16
# 2011-02-28 00:00:00+00:00 9
# 2011-03-31 00:00:00+00:00 14
# 2011-04-30 00:00:00+00:00 20
# 2011-05-31 00:00:00+00:00 16
# 2011-06-30 00:00:00+00:00 29
# 2011-07-31 00:00:00+00:00 10
# 2011-08-31 00:00:00+00:00 21
# 2011-09-30 00:00:00+00:00 27
# 2011-10-31 00:00:00+00:00 10
# 2011-11-30 00:00:00+00:00 16
# 2011-12-31 00:00:00+00:00 37
# 2012-01-31 00:00:00+00:00 19
# 2012-02-29 00:00:00+00:00 5
# 2012-03-31 00:00:00+00:00 18
# 2012-04-30 00:00:00+00:00 15
# 2012-05-31 00:00:00+00:00 8
# 2012-06-30 00:00:00+00:00 28
# 2012-07-31 00:00:00+00:00 10
# 2012-08-31 00:00:00+00:00 11
# 2012-09-30 00:00:00+00:00 29
# 2012-10-31 00:00:00+00:00 6
# 2012-11-30 00:00:00+00:00 19
# 2012-12-31 00:00:00+00:00 23
# 2013-01-31 00:00:00+00:00 15
# 2013-02-28 00:00:00+00:00 4
# 2013-03-31 00:00:00+00:00 13
# 2013-04-30 00:00:00+00:00 9
# 2013-05-31 00:00:00+00:00 10
# 2013-06-30 00:00:00+00:00 29
# 2013-07-31 00:00:00+00:00 9
# 2013-08-31 00:00:00+00:00 8
# 2013-09-30 00:00:00+00:00 26
# 2013-10-31 00:00:00+00:00 10
# 2013-11-30 00:00:00+00:00 18
# 2013-12-31 00:00:00+00:00 18

# %% [markdown]
# ### Change from 10ciles to 3ciles

# %% [markdown]
# ##### Jegadeesh & Titman 1M-1M, terciles

# %%
jt = JegadeeshTitman(DATA,
                     type_of_return='alpha',
                     no_of_quantiles=3)

# %%
w = jt.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = jt.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = jt.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ##### Chan News 1M-1M, terciles

# %%
cn = ChanNews(DATA,
              type_of_return='alpha',
               no_of_quantiles=3)

# %%
w = cn.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cn.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cn.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ##### Chan News 1M-1M 1 sigma (deciles)

# %%
cn1s = ChanNews1Sigma(DATA,
                      type_of_return='alpha',
                      no_of_quantiles=10)

# %%
w = cn1s.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cn1s.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cn1s.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ##### Chan News 1M-1M 2 sigma (deciles)

# %%
cn2s = ChanNews2Sigma(DATA,
                      type_of_return='alpha',
                      no_of_quantiles=10)

# %%
w = cn2s.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cn2s.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cn2s.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ##### Chan No News 1M-1M 1 sigma (deciles)

# %%
cnn1s = ChanNoNews1Sigma(DATA,
                         type_of_return='alpha',
                         no_of_quantiles=10)

# %%
w = cnn1s.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cnn1s.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cnn1s.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()

# %% [markdown]
# ##### Chan No News 1M-1M 2 sigma (deciles)

# %%
cnn2s = ChanNoNews2Sigma(DATA,
                         type_of_return='alpha',
                         no_of_quantiles=10)

# %%
w = cnn2s.get_winners_returns('M', test_per=1, hold_per=1)
w.name = 'W'

l = cnn2s.get_losers_returns('M', test_per=1, hold_per=1)
l.name = 'L'

wml = cnn2s.get_wml_returns('M', test_per=1, hold_per=1)
wml.name = 'WmL'

# %%
w_l_wml = pd.concat([w, l, wml], axis=1)

# %%
w_l_wml.cumsum().plot()
