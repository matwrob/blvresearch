# %%
from concat.core.utils import load_object

# %%
OLD_DATA = load_object('/vagrant/blvresearch/old_pickles/data_europe_1433_2011_2013.pickle')

# %%
old_entities = list(OLD_DATA.keys())

# %%
len(old_entities)
# Out:
# 1433

# %%
old_entities[0]
# Out:
# '002TMK-E'

# %%
from blvresearch.core.research_data import get_research_data_by_entity

# %%
NEW_DATA = get_research_data_by_entity(old_entities, '2011-01-01', '2013-12-31')
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-15-beaceaee959b> in <module>()
# ----> 1 NEW_DATA = get_research_data_by_entity(old_entities, '2011-01-01', '2013-12-31')
#
# /vagrant/blvresearch/core/research_data.py in get_research_data_by_entity(entity_ids, start_date, end_date)
#      22             and _matches_criteria(v)
#      23             and daycount[k] > 12]
# ---> 24     return _get_prices_and_news(secs, start_date, end_date)
#      25
#      26
#
# /vagrant/blvresearch/core/research_data.py in _get_prices_and_news(securities, start_date, end_date)
#      37
#      38 def _get_prices_and_news(securities, start_date, end_date):
# ---> 39     prices = get_many(securities, start_date, end_date)
#      40     news = NewsList.get_by_entity([s.factset_entity_id for s in securities],
#      41                                   start_date, end_date)
#
# ...

# %%
from blvresearch.core.news_events import NewsEvent
from blvresearch.core.event_study import EventDetector, EventList
from blvresearch.core.utils import mean_test

# %% [markdown]
# ##### Event 1: many news & alpha > 2%

# %%
class ManyNewsAlphaGreaterThan2pct(NewsEvent):
    def triggers(self):
        if self.has_many_news and self.alpha_is_greater_than_2pct:
            return True
        return False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5fbc3b478fe4> in <module>()
# ----> 1 class ManyNewsAlphaGreaterThan2pct(NewsEvent):
#       2     def triggers(self):
#       3         if self.has_many_news and self.alpha_is_greater_than_2pct:
#       4             return True
#       5         return False
#
# NameError: name 'NewsEvent' is not defined
