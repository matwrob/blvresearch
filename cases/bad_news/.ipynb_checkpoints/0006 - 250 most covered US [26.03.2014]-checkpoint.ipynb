# %%
import pandas as pd
import numpy as np

from fsprices.universe import Universe

# %%
from blvresearch.core.research_data import get_research_data_by_country
from blvresearch.core.event_study import EventDetector, EventList
from blvresearch.core.news_events import NewsEvent
from blvresearch.core.utils import mean_test

# %%
start_date = '2011-01-01'
end_date = '2013-12-31'

# %%
DATA = get_research_data_by_country(['US'],
                                    start_date,
                                    end_date)

# %%
UNI = Universe.research(int(start_date[:4]))
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-10-550ae518ed3e> in <module>()
# ----> 1 UNI = Universe.research(int(start_date[:4]))
#
# /vagrant/fsprices/universe.py in research(cls, year)
#     152     @classmethod
#     153     def research(cls, year):
# --> 154         obj = cls.from_security_ids(list(get_research_universe(year).index))
#     155         obj.info = 'research universe ' + str(year)
#     156         return obj
#
# /vagrant/fsprices/universe.py in from_security_ids(cls, security_ids)
#     167         if len(res) != len(security_ids):
#     168             res = get_security_meta(security_ids)
# --> 169             return cls.from_sql_result(res)
#     170         else:
#     171             return cls(list(res.values()))
#
# /vagrant/fsprices/universe.py in from_sql_result(cls, sql_result)
#     159     def from_sql_result(cls, sql_result):
#     160         data = [Security(i) for i in sql_result]
# --> 161         store_in_redis(data)
#     162         return cls(data)
#     163
#
# /vagrant/fsprices/universe.py in store_in_redis(securities)
#     258 def store_in_redis(securities):
#     259     store = {s.id: pickle.dumps(s) for s in securities}
# --> 260     redis().store_many(store, expire=ONE_DAY)
#     261
#     262
#
# /vagrant/blvutils/redishelpers.py in store_many(self, key_obj_dict, expire)
#     110             if expire:
#     111                 pipe.expire(key, expire)
# --> 112         pipe.execute()
#     113
#     114     def get_many(self, keys, strict=False):
#
# /usr/envs/py33/lib/python3.3/site-packages/redis/client.py in execute(self, raise_on_error)
#    2153
#    2154         try:
# -> 2155             return execute(conn, stack, raise_on_error)
#    2156         except ConnectionError:
#    2157             conn.disconnect()
#
# /usr/envs/py33/lib/python3.3/site-packages/redis/client.py in _execute_transaction(self, connection, commands, raise_on_error)
#    2051                 self.immediate_execute_command('DISCARD')
#    2052             if errors:
# -> 2053                 raise errors[0][1]
#    2054             raise sys.exc_info()[1]
#    2055
#
# /usr/envs/py33/lib/python3.3/site-packages/redis/client.py in _execute_transaction(self, connection, commands, raise_on_error)
#    2038         for i, command in enumerate(commands):
#    2039             try:
# -> 2040                 self.parse_response(connection, '_')
#    2041             except ResponseError:
#    2042                 ex = sys.exc_info()[1]
#
# /usr/envs/py33/lib/python3.3/site-packages/redis/client.py in parse_response(self, connection, command_name, **options)
#    2114     def parse_response(self, connection, command_name, **options):
#    2115         result = StrictRedis.parse_response(
# -> 2116             self, connection, command_name, **options)
#    2117         if command_name in self.UNWATCH_COMMANDS:
#    2118             self.watching = False
#
# /usr/envs/py33/lib/python3.3/site-packages/redis/client.py in parse_response(self, connection, command_name, **options)
#     469     def parse_response(self, connection, command_name, **options):
#     470         "Parses a response from the Redis server"
# --> 471         response = connection.read_response()
#     472         if command_name in self.response_callbacks:
#     473             return self.response_callbacks[command_name](response, **options)
#
# /usr/envs/py33/lib/python3.3/site-packages/redis/connection.py in read_response(self)
#     342             raise
#     343         if isinstance(response, ResponseError):
# --> 344             raise response
#     345         return response
#     346
#
# ResponseError: Command # 1 (SET b'fsprices:universe:security:M2TV4B-S-AU' b'\x80\x03cfsprices.universe\nSecurity\nq\x00)\x81q\x01N}q\x02(X\x05\x00\x00\x00namesq\x03cfsprices.universe\nNames\nq\x04)\x81q\x05N}q\x06(X\r\x00\x00\x00security_nameq\x07X\x13\x00\x00\x00GOODMAN FIELDER NPVq\x08X\x04\x00\x00\x00nameq\tX\x13\x00\x00\x00GOODMAN FIELDER LTDq\nX\x0b\x00\x00\x00proper_nameq\x0bX\x14\x00\x00\x00Goodman Fielder Ltd.q\x0cX\x06\x00\x00\x00tickerq\rX\x07\x00\x00\x00GFF-ASXq\x0eu\x86q\x0fbX\x0b\x00\x00\x00exchangeobjq\x10cfsprices.universe\nExchange\nq\x11)\x81q\x12}q\x13(X\x04\x00\x00\x00openq\x14X\x08\x00\x00\x0010:00:00q\x15X\x05\x00\x00\x00closeq\x16X\x08\x00\x00\x0016:00:00q\x17h\tX\x03\x00\x00\x00ASXq\x18X\x04\x00\x00\x00zoneq\x19X\x10\x00\x00\x00Australia/Sydneyq\x1aX\x07\x00\x00\x00countryq\x1bX\x02\x00\x00\x00AUq\x1cubX\x08\x00\x00\x00sec_typeq\x1dX\x05\x00\x00\x00SHAREq\x1eX\x0e\x00\x00\x00entity_countryq\x1fX\x02\x00\x00\x00AUq X\x08\x00\x00\x00exchangeq!X\x03\x00\x00\x00ASXq"h\x1bX\x02\x00\x00\x00AUq#X\x11\x00\x00\x00factset_entity_idq$X\x08\x00\x00\x0006BJ4R-Eq%X\x08\x00\x00\x00currencyq&X\x03\x00\x00\x00AUDq\'X\x06\x00\x00\x00sectorq(X\x04\x00\x00\x002400q)X\x0e\x00\x00\x00fs_perm_sec_idq*X\x0b\x00\x00\x00M2TV4B-S-AUq+X\x04\x00\x00\x00isinq,X\x0c\x00\x00\x00AU000000GFF8q-X\x08\x00\x00\x00industryq.X\x04\x00\x00\x002405q/u\x86q0b.') of pipeline caused error: MISCONF Redis is configured to save RDB snapshots, but is currently not able to persist on disk. Commands that may modify the data set are disabled. Please check Redis logs for details about the error.

# %% [markdown]
# ##### Finding most news-covered entities

# %%
from memnews.core import NewsList

# %%
def news_count_func(x):
    return len(x) if isinstance(x, NewsList) else 0

# %%
news_by_entity = dict()
for entity_id, entity_data in DATA.items():
    news = entity_data['news'].map(news_count_func)
    news_by_entity[entity_id] = news.sum()

# %%
news_by_entity = pd.Series(news_by_entity)
news_by_entity.sort()

# %%
most_covered_250 = list(news_by_entity[-250:].index)

# %% [markdown]
# ##### Event 1: many news & alpha < miu - 2 * sigma

# %%
class ManyNewsAlphaSmallerThanMiuMinus2Sigmas(NewsEvent):
    def triggers(self):
        if self.has_many_news and self.alpha_is_smaller_than_miu_minus_2_sigmas:
            return True
        return False

# %%
detector1 = EventDetector(ManyNewsAlphaSmallerThanMiuMinus2Sigmas)

# %%
events1 = dict()
for entity_id, entity_data in DATA.items():
    if entity_id in most_covered_250:
        entity_events = detector1.run(entity_id, entity_data, UNI[entity_id])
        if len(entity_events) > 0:
            events1[entity_id] = entity_events

# %%
len(events1)
# Out:
# 227

# %%
list1 = EventList.from_dict(events1)

# %%
mean_test(list1, 'alpha', 20)
# Out:
# Mean: -0.00243648554328
# p_value: 0.472396528039

# %% [markdown]
# ##### Event 4: many news & alpha < -2%

# %%
class ManyNewsAlphaSmallerThanMinus2pct(NewsEvent):
    def triggers(self):
        if self.has_many_news and self.alpha_is_smaller_than_minus_2pct:
            return True
        return False

# %%
detector4 = EventDetector(ManyNewsAlphaSmallerThanMinus2pct)

# %%
events4 = dict()
for entity_id, entity_data in DATA.items():
    if entity_id in most_covered_250:
        entity_events = detector4.run(entity_id, entity_data, UNI[entity_id])
        if len(entity_events) > 0:
            events4[entity_id] = entity_events

# %%
len(events4)
# Out:
# 230

# %%
list4 = EventList.from_dict(events4)

# %%
list4
# Out:
# EventList with 835 events

# %%
mean_test(list4, 'alpha', 20)
# Out:
# Mean: -0.0110954083614
# p_value: 0.00117227217803

# %% [markdown]
# ##### Event 4a: many news & alpha < -2% using old 250 entities (221 are the same)

# %%
from blvresearch.core.entity_list import USA_HIGH_NEWS_COVERAGE_250

# %%
detector4a = detector4

# %%
events4a = dict()
for entity_id, entity_data in DATA.items():
    if entity_id in USA_HIGH_NEWS_COVERAGE_250:
        entity_events = detector4a.run(entity_id, entity_data, UNI[entity_id])
        if len(entity_events) > 0:
            events4a[entity_id] = entity_events

# %%
len(events4a)
# Out:
# 222

# %%
list4a = EventList.from_dict(events4a)

# %%
list4a
# Out:
# EventList with 801 events

# %%
mean_test(list4a, 'alpha', 20)
# Out:
# Mean: -0.0091468007975
# p_value: 0.00675032256945

# %%
from concat.core.utils import save_object

# %%
save_object(events4a, 'usa_many_news_alpha_stm2pct_old_250_most_covered.pickle')
